# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/NLP/blob/main/Word-Level-Classification/Alphabet_Detector.ipynb)

# %%
# !pip install alphabet-detector
# Out:
# ...
#   Created wheel for alphabet-detector: filename=alphabet_detector-0.0.7-cp37-none-any.whl size=2446 sha256=3314499d7da8ade1d01b40b04d49bc1313dbb9287606dd5591c1477957be2a70
#   Stored in directory: /root/.cache/pip/wheels/75/a7/c3/faf515469622e565475fc96983418ba6e03f6a0f73755cd892
# Successfully built alphabet-detector
# ...

# %%
#alphabet-detector : https://github.com/EliFinkelshteyn/alphabet-detector


from alphabet_detector import AlphabetDetector
ad = AlphabetDetector()

print(ad.detect_alphabet(u'ఆడదాని బ్రతుకు ముళ్లమయం!'))
print(ad.detect_alphabet(u'PM की अपील पर बोले राकेश टिकैत- MSP पर कानून बना दो'))
# Out:
# {'TELUGU'}
# {'LATIN', 'DEVANAGARI'}

# %%
# detecting alphabets is an easy task if the two languages are not similar but it is a difficult task if the two languages are similar like hindi and marathi
