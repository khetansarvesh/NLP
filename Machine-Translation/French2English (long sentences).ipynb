# %% [markdown]
# https://github.com/spro/practical-pytorch/blob/master/seq2seq-translation/seq2seq-translation.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')

from __future__ import unicode_literals, print_function, division
import string
import random
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reading the dataset**
# ==================

# %%
data_path = "/content/drive/MyDrive/001 My Skills/002 CS Engineering   Automated Math (BPHC)/004 Data Science (DS)   Artificial Intelligence (AI)/005 Textual Data (Unstructured Data) (Sequential Data)/004 NLP Tasks/2. NLG Tasks (or Seq2Seq Tasks)/0. Machine Translation (MT)/1. MonoLingual Machine Translation (MT)/2. NMT/english_french_dataset.txt"
# you can download other sentence pair dataset from here - http://www.manythings.org/anki/
# or use WMT dataset - http://www.statmt.org/wmt16/

# %%
from io import open
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().strip().split('\n')

lines
# Out:
# ['Go.\tVa !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #1158250 (Wittydev)',
#  'Go.\tMarche.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8090732 (Micsmithel)',
#  'Go.\tBouge !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #9022935 (Micsmithel)',
#  'Hi.\tSalut !\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #509819 (Aiji)',
#  'Hi.\tSalut.\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #4320462 (gillux)',
#  'Run!\tCours\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #906331 (sacredceltic)',
#  'Run!\tCourez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #906332 (sacredceltic)',
#  'Run!\tPrenez vos jambes à vos cous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #2077449 (sacredceltic)',
#  'Run!\tFile !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #2077454 (sacredceltic)',
#  'Run!\tFilez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #2077455 (sacredceltic)',
#  'Run!\tCours !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #4580779 (franlexcois)',
#  'Run!\tFuyez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #7957917 (Micsmithel)',
#  'Run!\tFuyons !\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #7957918 (Micsmithel)',
#  'Run.\tCours\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #906331 (sacredceltic)',
#  'Run.\tCourez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #906332 (sacredceltic)',
#  'Run.\tPrenez vos jambes à vos cous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #2077449 (sacredceltic)',
#  'Run.\tFile !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #2077454 (sacredceltic)',
#  'Run.\tFilez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #2077455 (sacredceltic)',
#  'Run.\tCours !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #4580779 (franlexcois)',
#  'Run.\tFuyez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #7957917 (Micsmithel)',
#  'Run.\tFuyons !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #7957918 (Micsmithel)',
#  'Who?\tQui ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2083030 (CK) & #4366796 (gillux)',
#  'Wow!\tÇa alors\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #374631 (zmoo)',
#  'Duck!\tÀ terre\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #6288793 (Whidou)',
#  'Duck!\tBaisse-toi\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #6288797 (Whidou)',
#  'Duck!\tBaissez-vous\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #6288799 (Whidou)',
#  'Fire!\tAu feu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #4627939 (sacredceltic)',
#  "Help!\tÀ l'aide\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #128430 (sysko)",
#  'Hide.\tCache-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907581 (CK) & #9934893 (codl)',
#  'Hide.\tCachez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907581 (CK) & #9934894 (codl)',
#  'Jump!\tSaute.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1102981 (jamessilver) & #2416938 (Micsmithel)',
#  'Jump.\tSaute.\tCC-BY 2.0 (France) Attribution: tatoeba.org #631038 (Shishir) & #2416938 (Micsmithel)',
#  'Stop!\tÇa suffit\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (CM) & #516030 (Goofy)',
#  'Stop!\tStop\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (CM) & #626567 (U2FS)',
#  'Stop!\tArrête-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (CM) & #1157663 (sacredceltic)',
#  'Wait!\tAttends !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #1157682 (sacredceltic)',
#  'Wait!\tAttendez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #1157684 (sacredceltic)',
#  'Wait!\tAttendez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #7693749 (Micsmithel)',
#  'Wait.\tAttends !\tCC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #1157682 (sacredceltic)',
#  'Wait.\tAttendez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #1157684 (sacredceltic)',
#  'Wait.\tAttends.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #5137155 (gege_veggie)',
#  'Wait.\tAttendez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #7693749 (Micsmithel)',
#  'Begin.\tCommencez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #7956660 (Micsmithel)',
#  'Begin.\tCommence.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #7957931 (Micsmithel)',
#  'Go on.\tPoursuis.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #588132 (sacredceltic)',
#  'Go on.\tContinuez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6463161 (Aiji)',
#  'Go on.\tPoursuivez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6463162 (Aiji)',
#  'Hello!\tBonjour !\tCC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #373345 (Aiji)',
#  'Hello!\tSalut !\tCC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #509819 (Aiji)',
#  'I see.\tJe comprends.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #1511205 (Hikari)',
#  'I see.\tAha.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #8304768 (Micsmithel)',
#  "I try.\tJ'essaye.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #1133630 (nimfeo)",
#  "I won!\tJ'ai gagné !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #2005252 (sacredceltic)",
#  "I won!\tJe l'ai emporté !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #2005253 (sacredceltic)",
#  'I won.\tJ’ai gagné.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828608 (CK) & #7700885 (sacredceltic)',
#  'Oh no!\tOh non !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1299275 (CK) & #1299284 (sacredceltic)',
#  'Relax.\tCalme-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #458839 (sacredceltic)',
#  'Relax.\tDétends-toi\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #492000 (sacredceltic)',
#  'Relax.\tDétendez-vous\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #577646 (sacredceltic)',
#  'Relax.\tRelaxe, Max\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1042506 (sacredceltic)',
#  'Relax.\tCool, Raoul\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1042509 (sacredceltic)',
#  'Relax.\tDu calme\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1047578 (sacredceltic)',
#  'Relax.\tRelaxe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1083768 (sacredceltic)',
#  'Relax.\tCalmez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1158349 (sacredceltic)',
#  'Relax.\tDétends-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1555857 (sacredceltic)',
#  'Relax.\tDétends-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #1846151 (sacredceltic)',
#  'Relax.\tDu calme.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #7166556 (Micsmithel)',
#  'Relax.\tTranquille.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #9022929 (Micsmithel)',
#  'Smile.\tSouriez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #460976 (sacredceltic)',
#  'Smile.\tSouris pour la caméra.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #3430766 (Micsmithel)',
#  'Smile.\tSouriez\u2009!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #4890885 (sacredceltic)',
#  'Sorry?\tPardon ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #9020701 (Rawrren) & #4320357 (gillux)',
#  'Attack!\tAttaque !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #1973495 (sacredceltic)',
#  'Attack!\tAttaquez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #1973496 (sacredceltic)',
#  "Attack!\tÀ l'attaque !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #8982329 (Micsmithel)",
#  'Buy it.\tAchetez-la !\tCC-BY 2.0 (France) Attribution: tatoeba.org #10016573 (ddnktr) & #1084150 (nimfeo)',
#  'Buy it.\tAchète-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #10016573 (ddnktr) & #5800098 (Toynop)',
#  'Buy it.\tAchetez-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #10016573 (ddnktr) & #6739631 (GB3)',
#  'Buy it.\tAchète-la !\tCC-BY 2.0 (France) Attribution: tatoeba.org #10016573 (ddnktr) & #6739643 (GB3)',
#  'Cheers!\tSanté !\tCC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #9385 (sacredceltic)',
#  'Cheers!\tÀ votre santé !\tCC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #11581 (Lulantis)',
#  'Cheers!\tMerci !\tCC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #374826 (sysko)',
#  'Cheers!\tTchin-tchin !\tCC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #6036027 (PERCE_NEIGE)',
#  'Eat it.\tMangez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8974747 (Micsmithel)',
#  'Eat it.\tMange-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8974748 (Micsmithel)',
#  'Get up.\tLève-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #886122 (U2FS)',
#  'Get up.\tLève-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #1084156 (nimfeo)',
#  'Get up.\tDebout.\tCC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #7938998 (Micsmithel)',
#  'Go now.\tVa, maintenant.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #6468587 (Aiji)',
#  'Go now.\tAllez-y maintenant.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #6468588 (Aiji)',
#  'Go now.\tVas-y maintenant.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #6468589 (Aiji)',
#  "Got it!\tJ'ai pigé !\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #2368356 (sacredceltic)",
#  'Got it!\tCompris !\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #2368357 (sacredceltic)',
#  'Got it!\tAha !\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #8304762 (Micsmithel)',
#  'Got it?\tPigé\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #455358 (qdii)',
#  'Got it?\tCompris\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #455605 (chtof)',
#  "Got it?\tT'as capté\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #536561 (sacredceltic)",
#  'Hop in.\tMonte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #1111572 (sacredceltic)',
#  'Hop in.\tMontez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #1111573 (sacredceltic)',
#  'Hug me.\tSerre-moi dans tes bras !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846386 (sacredceltic)',
#  'Hug me.\tSerrez-moi dans vos bras !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846388 (sacredceltic)',
#  'I fell.\tJe suis tombée.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4678646 (sacredceltic)',
#  'I fell.\tJe suis tombé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4678647 (sacredceltic)',
#  "I fled.\tJ'ai fui.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8984443 (Micsmithel)",
#  'I knit.\tJe tricote.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828609 (CK) & #9556682 (Micsmithel)',
#  'I know.\tJe sais.\tCC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #134976 (sacredceltic)',
#  'I left.\tJe suis parti.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2307509 (erikspen) & #2307644 (sacredceltic)',
#  'I left.\tJe suis partie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2307509 (erikspen) & #2307645 (sacredceltic)',
#  "I lied.\tJ'ai menti.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3935374 (gianich73) & #7581897 (Micsmithel)",
#  "I lost.\tJ'ai perdu.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #4678706 (sacredceltic)",
#  'I paid.\tJe payais.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7563048 (Micsmithel)',
#  'I paid.\tJe payai.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7563049 (Micsmithel)',
#  'I paid.\tJ’ai payé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7700893 (sacredceltic)',
#  "I quit.\tJ'arrête.\tCC-BY 2.0 (France) Attribution: tatoeba.org #731636 (Eldad) & #7581976 (Micsmithel)",
#  "I quit.\tJ'ai arrêté.\tCC-BY 2.0 (France) Attribution: tatoeba.org #731636 (Eldad) & #10015091 (Micsmithel)",
#  "I'm 19.\tJ'ai 19 ans.\tCC-BY 2.0 (France) Attribution: tatoeba.org #442400 (sacredceltic) & #9994 (sacredceltic)",
#  "I'm OK.\tJe vais bien.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #488439 (Anthaus)",
#  "I'm OK.\tÇa va.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #744360 (Christiane)",
#  'Listen.\tÉcoutez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #827098 (sacredceltic)',
#  "No way!\tC'est pas possible\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3316 (trotter)",
#  'No way!\tImpossible\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3997 (TRANG)',
#  'No way!\tHors de question\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #9678 (sysko)',
#  'No way!\tEn aucun cas.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #553061 (sacredceltic)',
#  'No way!\tSans façons\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #560949 (sacredceltic)',
#  "No way!\tC'est hors de question !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1141489 (Rovo)",
#  "No way!\tIl n'en est pas question !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1481211 (Rovo)",
#  "No way!\tC'est exclu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1673264 (sacredceltic)",
#  'No way!\tEn aucune manière !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #2222344 (sacredceltic)',
#  'No way!\tHors de question !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3216912 (Dreamk33)',
#  'Really?\tVraiment\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #135244 (gillux)',
#  'Really?\tVrai ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #1158518 (sacredceltic)',
#  'Really?\tAh bon ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #4722682 (gillux)',
#  'Really?\tAh vraiment ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #7482694 (Micsmithel)',
#  'Really?\tVraiment ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #8619820 (Micsmithel)',
#  'Thanks!\tMerci !\tCC-BY 2.0 (France) Attribution: tatoeba.org #448645 (CK) & #374826 (sysko)',
#  'Thanks.\tMerci !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #374826 (sysko)',
#  'Thanks.\tMerci.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #2302907 (Joelle)',
#  'Try it.\tEssaie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #8690495 (Micsmithel)',
#  'Try it.\tEssayez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #8690496 (Micsmithel)',
#  'Try it.\tEssaye.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #9558833 (Micsmithel)',
#  'We try.\tOn essaye.\tCC-BY 2.0 (France) Attribution: tatoeba.org #247763 (CK) & #4533875 (pfpillon)',
#  'We won.\tNous avons gagné.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #2109514 (sacredceltic)',
#  'We won.\tNous gagnâmes.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #2109516 (sacredceltic)',
#  "We won.\tNous l'avons emporté.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #2109517 (sacredceltic)",
#  "We won.\tNous l'emportâmes.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #2109518 (sacredceltic)",
#  'Ask Tom.\tDemande à Tom.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1954263 (CK) & #2013783 (Sbgodin)',
#  'Ask him.\tDemande-lui.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3919925 (CH) & #9024940 (Micsmithel)',
#  'Awesome!\tFantastique\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #433512 (CK) & #10876 (sacredceltic)',
#  'Awesome!\tSensass !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433512 (CK) & #8690499 (Micsmithel)',
#  'Be calm.\tSois calme !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916317 (CK) & #1916590 (sacredceltic)',
#  'Be calm.\tSoyez calme !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916317 (CK) & #1916591 (sacredceltic)',
#  'Be calm.\tSoyez calmes !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916317 (CK) & #1916592 (sacredceltic)',
#  'Be cool.\tSois détendu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860752 (CK) & #2077411 (sacredceltic)',
#  'Be fair.\tSois juste !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916596 (sacredceltic)',
#  'Be fair.\tSoyez juste !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916597 (sacredceltic)',
#  'Be fair.\tSoyez justes !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916598 (sacredceltic)',
#  'Be fair.\tSois équitable !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916599 (sacredceltic)',
#  'Be fair.\tSoyez équitable !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916601 (sacredceltic)',
#  'Be fair.\tSoyez équitables !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #1916603 (sacredceltic)',
#  'Be fair.\tSois honnête.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #7355980 (Micsmithel)',
#  'Be fair.\tSois sincère.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #7355982 (Micsmithel)',
#  'Be fair.\tSoyez honnêtes.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #7355994 (Micsmithel)',
#  'Be kind.\tSois gentil.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916315 (CK) & #1916607 (sacredceltic)',
#  'Be nice.\tSois gentil !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077412 (sacredceltic)',
#  'Be nice.\tSois gentille !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077413 (sacredceltic)',
#  'Be nice.\tSoyez gentil !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077414 (sacredceltic)',
#  'Be nice.\tSoyez gentille !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077415 (sacredceltic)',
#  'Be nice.\tSoyez gentils !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077416 (sacredceltic)',
#  'Be nice.\tSoyez gentilles !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #2077417 (sacredceltic)',
#  'Beat it.\tVa te faire foutre !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #403910 (trotter)',
#  'Beat it.\tDégage\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #844993 (Corvus)',
#  'Beat it.\tCasse-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #956472 (sysko)',
#  'Beat it.\tPars !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1157650 (sacredceltic)',
#  'Beat it.\tFoutez le camp !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1183768 (sacredceltic)',
#  'Beat it.\tFous le camp !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1183772 (sacredceltic)',
#  "Beat it.\tPars d'ici.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1226673 (rene1596)",
#  "Beat it.\tVa t'en !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1271062 (sacredceltic)",
#  'Beat it.\tDisparais !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #1312667 (sacredceltic)',
#  'Beat it.\tFiche le camp.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #2981662 (Blabla)',
#  'Beat it.\tTire-toi de là.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #3093606 (Blabla)',
#  'Beat it.\tCasse-toi de là.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #3136982 (gillux)',
#  'Beat it.\tOust !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #4321747 (gillux)',
#  'Beat it.\tDégage.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #5824885 (EvaFranska)',
#  "Beat it.\tFiche le camp d'ici.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #7044291 (Blabla)",
#  'Beat it.\tDéguerpissez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #8090737 (Micsmithel)',
#  'Beat it.\tBouge !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #9022935 (Micsmithel)',
#  'Beat it.\tDécampe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #9025685 (Micsmithel)',
#  'Burn it.\tBrûlez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049387 (mailohilohi) & #9252740 (Micsmithel)',
#  'Burn it.\tBrûlez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049387 (mailohilohi) & #9252742 (Micsmithel)',
#  'Burn it.\tBrûle-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049387 (mailohilohi) & #9252744 (Micsmithel)',
#  'Burn it.\tBrûle-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049387 (mailohilohi) & #9252747 (Micsmithel)',
#  'Bury it.\tEnterrez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049389 (mailohilohi) & #9252781 (Micsmithel)',
#  'Bury it.\tEnterre-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049389 (mailohilohi) & #9252785 (Micsmithel)',
#  'Bury it.\tEnterrez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049389 (mailohilohi) & #9252786 (Micsmithel)',
#  'Bury it.\tEnterre-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049389 (mailohilohi) & #9252788 (Micsmithel)',
#  'Call me.\tAppelle-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1553532 (CK) & #1803391 (sacredceltic)',
#  'Call me.\tAppelez-moi\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1553532 (CK) & #1803394 (sacredceltic)',
#  'Call us.\tAppelle-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916313 (CK) & #1922165 (sacredceltic)',
#  'Call us.\tAppelez-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1916313 (CK) & #1922168 (sacredceltic)',
#  'Come in.\tEntrez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #440075 (franzmimm)',
#  'Come in.\tEntre.\tCC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #585174 (sacredceltic)',
#  'Come in.\tEntre !\tCC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #1157671 (sacredceltic)',
#  'Come in.\tEntrez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #1157672 (sacredceltic)',
#  'Come on!\tAllez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #11608 (qdii)',
#  'Come on!\tEn avant\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #975195 (sacredceltic)',
#  "Come on!\tC'est pas vrai, dis !\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #1473678 (Rovo)",
#  'Come on!\tViens\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #1996169 (sacredceltic)',
#  'Come on!\tVenez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #2077418 (sacredceltic)',
#  'Come on!\tSecouez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #8676632 (Julien_PDC)',
#  'Come on!\tSecoue-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #8676633 (Julien_PDC)',
#  'Come on.\tAllez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1954266 (CK) & #1996167 (sacredceltic)',
#  'Come on.\tViens\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1954266 (CK) & #1996169 (sacredceltic)',
#  'Come on.\tVenez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1954266 (CK) & #2077418 (sacredceltic)',
#  'Drop it!\tLaisse tomber !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972621 (CK) & #1973430 (sacredceltic)',
#  'Drop it!\tLaissez tomber !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972621 (CK) & #1973431 (sacredceltic)',
#  'Drop it!\tLaisse-le tomber !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972621 (CK) & #1973433 (sacredceltic)',
#  'Drop it!\tLaissez-le tomber !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972621 (CK) & #1973434 (sacredceltic)',
#  'Get Tom.\tVa chercher Tom.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972633 (CK) & #7413924 (lbdx)',
#  'Get out!\tSors.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #9480 (sysko)',
#  'Get out!\tSortez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #128393 (Archibald)',
#  'Get out!\tDégage\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #844993 (Corvus)',
#  'Get out!\tDisparais\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #883768 (sacredceltic)',
#  'Get out!\tCasse-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #956472 (sysko)',
#  'Get out!\tDégagez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #1112432 (sacredceltic)',
#  'Get out!\tSors !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #1157665 (sacredceltic)',
#  'Get out!\tSortez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #1157669 (sacredceltic)',
#  'Get out!\tDégage !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #1183771 (sacredceltic)',
#  'Get out!\tDisparais !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #1312667 (sacredceltic)',
#  'Get out!\tDu balai !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #2271433 (sacredceltic)',
#  'Get out!\tFiche le camp.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #2981662 (Blabla)',
#  'Get out!\tOust !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #4321747 (gillux)',
#  "Get out!\tVers l'extérieur !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #4627841 (sacredceltic)",
#  'Get out!\tFichez le camp !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #6071041 (Blabla)',
#  'Get out!\tSortez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #7166325 (Micsmithel)',
#  'Get out!\tDécampez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #9025684 (Micsmithel)',
#  'Get out!\tDécampe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #9025685 (Micsmithel)',
#  'Get out.\tSors.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #9480 (sysko)',
#  'Get out.\tSortez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #128393 (Archibald)',
#  'Get out.\tDégage\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #844993 (Corvus)',
#  'Get out.\tDisparais\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #883768 (sacredceltic)',
#  'Get out.\tCasse-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #956472 (sysko)',
#  'Get out.\tDégagez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #1112432 (sacredceltic)',
#  'Get out.\tSors !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #1157665 (sacredceltic)',
#  'Get out.\tSortez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #1157669 (sacredceltic)',
#  'Get out.\tDisparais !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #1312667 (sacredceltic)',
#  'Get out.\tFiche le camp.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #2981662 (Blabla)',
#  'Get out.\tOust !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #4321747 (gillux)',
#  'Get out.\tSortez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #7166325 (Micsmithel)',
#  'Get out.\tBouge !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #9022935 (Micsmithel)',
#  'Get out.\tDécampez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #9025684 (Micsmithel)',
#  'Get out.\tDécampe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #9025685 (Micsmithel)',
#  'Go away!\tDégage\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #844993 (Corvus)',
#  'Go away!\tPars !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #1157650 (sacredceltic)',
#  'Go away!\tAllez-vous en !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #1407068 (sacredceltic)',
#  'Go away!\tDéguerpissez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #8090737 (Micsmithel)',
#  'Go away!\tCassez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #8090738 (Micsmithel)',
#  'Go away!\tBouge !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #9022935 (Micsmithel)',
#  'Go away!\tDécampez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #9025684 (Micsmithel)',
#  'Go away!\tDécampe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #9025685 (Micsmithel)',
#  'Go away.\tVa te faire foutre !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #403910 (trotter)',
#  'Go away.\tPars !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1157650 (sacredceltic)',
#  'Go away.\tDégage !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1183771 (sacredceltic)',
#  'Go away.\tFous le camp !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1183772 (sacredceltic)',
#  "Go away.\tPars d'ici.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1226673 (rene1596)",
#  "Go away.\tVa t'en !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1271062 (sacredceltic)",
#  'Go away.\tDisparais !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1312667 (sacredceltic)',
#  'Go away.\tDéguerpissez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #8090737 (Micsmithel)',
#  'Go away.\tCassez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #8090738 (Micsmithel)',
#  'Go away.\tBouge !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #9022935 (Micsmithel)',
#  'Go away.\tDécampez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #9025684 (Micsmithel)',
#  'Go away.\tDécampe !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #9025685 (Micsmithel)',
#  'Go back.\tRecule.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7765354 (sharris123) & #8739037 (Micsmithel)',
#  'Go home.\tRentrez à la maison.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230769 (CK) & #180836 (Romira)',
#  'Go home.\tRentre à la maison.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230769 (CK) & #972709 (NomadSoul)',
#  'Go home.\tRentre chez toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230769 (CK) & #7166299 (Micsmithel)',
#  'Go home.\tRentrez chez vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230769 (CK) & #7166300 (Micsmithel)',
#  'Go slow.\tVa doucement !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2254627 (_undertoad) & #5049993 (sacredceltic)',
#  'Go slow.\tAllez doucement !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2254627 (_undertoad) & #5049994 (sacredceltic)',
#  'Goodbye!\tAdieu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #1143424 (sacredceltic)',
#  'Goodbye!\tÀ la revoyure.\tCC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #1409984 (sysko)',
#  'Goodbye!\tCiao.\tCC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #7704052 (Micsmithel)',
#  'Hang on!\tAttends un peu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #1849920 (sacredceltic)',
#  'Hang on!\tAttendez un peu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #1849921 (sacredceltic)',
#  'Hang on!\tAttendez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #7693749 (Micsmithel)',
#  'Hang on.\tTiens bon !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972640 (CK) & #1973294 (sacredceltic)',
#  'Hang on.\tTenez bon !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972640 (CK) & #1973295 (sacredceltic)',
#  'Hang on.\tAttendez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972640 (CK) & #7693749 (Micsmithel)',
#  'He left.\tIl est parti.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3259071 (CH) & #432700 (qdii)',
#  'He quit.\tIl laissa tomber.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1580339 (sam_m) & #896698 (sacredceltic)',
#  'He quit.\tIl a laissé tomber.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1580339 (sam_m) & #1580438 (sacredceltic)',
#  'He runs.\tIl court.\tCC-BY 2.0 (France) Attribution: tatoeba.org #672254 (CK) & #672262 (gillux)',
#  'Help me!\tAide-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1126684 (CK) & #1602205 (Petrus)',
#  "Help me.\tÀ l'aide\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #128430 (sysko)",
#  'Help me.\tAide-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #428130 (dominiko)',
#  'Help me.\tAidez-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #463521 (sacredceltic)',
#  'Help me.\tAide-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #1602205 (Petrus)',
#  'Help us.\tAidez-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2187193 (CK) & #2190377 (sacredceltic)',
#  'Help us.\tAide-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2187193 (CK) & #2190378 (sacredceltic)',
#  'Hold it!\tNe bouge plus !\tCC-BY 2.0 (France) Attribution: tatoeba.org #280203 (CK) & #4533882 (pfpillon)',
#  'Hold it!\tNe bougez plus !\tCC-BY 2.0 (France) Attribution: tatoeba.org #280203 (CK) & #7369972 (Micsmithel)',
#  'Hold it!\tRestez où vous êtes !\tCC-BY 2.0 (France) Attribution: tatoeba.org #280203 (CK) & #7369974 (Micsmithel)',
#  'Hold it!\tAttendez.\tCC-BY 2.0 (France) Attribution: tatoeba.org #280203 (CK) & #7693749 (Micsmithel)',
#  'Hold on.\tNe quittez pas.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357000 (sacredceltic) & #722690 (qdii)',
#  'Hold on.\tNe quitte pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357000 (sacredceltic) & #7166571 (Micsmithel)',
#  'Hug Tom.\tFais un câlin à Tom.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2203860 (CK) & #6463239 (Aiji)',
#  'I agree.\tJe suis du même avis.\tCC-BY 2.0 (France) Attribution: tatoeba.org #436281 (lukaszpp) & #2300035 (nimfeo)',
#  "I cried.\tJ'ai pleuré.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828613 (CK) & #7092208 (felix63)",
#  'I dozed.\tJe me suis assoupi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828614 (CK) & #7711334 (sacredceltic)',
#  'I dozed.\tJe me suis assoupie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828614 (CK) & #7711335 (sacredceltic)',
#  'I drive.\tJe conduis.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828615 (CK) & #2285485 (sacredceltic)',
#  'I drove.\tJe conduisis.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828616 (CK) & #7369856 (Micsmithel)',
#  "I fired.\tJ'ai tiré.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397691 (CK) & #8984442 (Micsmithel)",
#  'I froze.\tJe me suis figé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397692 (CK) & #8984440 (Micsmithel)',
#  'I froze.\tJe me suis figée.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397692 (CK) & #8984441 (Micsmithel)',
#  'I smoke.\tJe fume.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7538184 (CK) & #7713683 (sacredceltic)',
#  'I snore.\tJe ronfle.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828618 (CK) & #4863031 (Julien_PDC)',
#  'I stink.\tJe pue.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7538186 (CK) & #7713672 (sacredceltic)',
#  'I stood.\tJe me suis tenu debout.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828619 (CK) & #7711307 (sacredceltic)',
#  'I stood.\tJe me suis tenue debout.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828619 (CK) & #7711308 (sacredceltic)',
#  'I swore.\tJ’ai promis.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828620 (CK) & #7711337 (sacredceltic)',
#  'I swore.\tJ’ai juré.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828620 (CK) & #7711338 (sacredceltic)',
#  "I tried.\tJ'essayai.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2283721 (CK) & #2285505 (sacredceltic)",
#  "I tried.\tJ'ai essayé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2283721 (CK) & #2285506 (sacredceltic)",
#  "I tried.\tJ'ai tenté.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2283721 (CK) & #2285508 (sacredceltic)",
#  'I waved.\tJ’ai fait signe.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828621 (CK) & #7711358 (sacredceltic)',
#  "I'll go.\tJ'irai.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1174876 (CK) & #3640827 (sacredceltic)",
#  "I'm Tom.\tJe suis Tom.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2283732 (CK) & #3344396 (Aiji)",
#  "I'm fat.\tJe suis gras.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1120816 (cntrational) & #1121071 (sacredceltic)",
#  "I'm fat.\tJe suis gros.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1120816 (cntrational) & #1121073 (sacredceltic)",
#  "I'm fit.\tJe suis en forme.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3330525 (CK) & #2802689 (nimfeo)",
#  "I'm hit!\tJe suis touché !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829472 (Spamster) & #1830978 (sacredceltic)",
#  "I'm hit!\tJe suis touchée !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829472 (Spamster) & #1830979 (sacredceltic)",
#  "I'm ill.\tJe suis malade.\tCC-BY 2.0 (France) Attribution: tatoeba.org #448236 (CK) & #459031 (sacredceltic)",
#  "I'm sad.\tJe suis triste.\tCC-BY 2.0 (France) Attribution: tatoeba.org #317741 (CK) & #333733 (sysko)",
#  "I'm sad.\tJ'ai un coup de cafard.\tCC-BY 2.0 (France) Attribution: tatoeba.org #317741 (CK) & #7044248 (Micsmithel)",
#  "I'm sad.\tJe suis malheureux.\tCC-BY 2.0 (France) Attribution: tatoeba.org #317741 (CK) & #7044249 (Micsmithel)",
#  "I'm shy.\tJe suis timide.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2203346 (CK) & #2708372 (Aiji)",
#  "I'm wet.\tJe suis mouillé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1780075 (Spamster) & #1783817 (sacredceltic)",
#  "I'm wet.\tJe suis mouillée.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1780075 (Spamster) & #1783818 (sacredceltic)",
#  "It's me!\tC'est bibi\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1349952 (sacredceltic) & #819121 (U2FS)",
#  'Join us.\tJoignez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1745546 (belgavox) & #881120 (sacredceltic)',
#  'Join us.\tJoignez-vous à nous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1745546 (belgavox) & #882091 (sacredceltic)',
#  'Keep it.\tGarde-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913087 (CK) & #1927913 (sacredceltic)',
#  'Keep it.\tGardez-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913087 (CK) & #1927914 (sacredceltic)',
#  'Kick it.\tDonne-lui un coup de pied.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049383 (mailohilohi) & #9252765 (Micsmithel)',
#  'Kick it.\tDonnez-lui un coup de pied.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049383 (mailohilohi) & #9252767 (Micsmithel)',
#  'Kill it.\tTuez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049388 (mailohilohi) & #9252660 (Micsmithel)',
#  'Kill it.\tTue-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049388 (mailohilohi) & #9252733 (Micsmithel)',
#  'Kill it.\tTue-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049388 (mailohilohi) & #9252737 (Micsmithel)',
#  'Kill it.\tTuez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049388 (mailohilohi) & #9252738 (Micsmithel)',
#  'Kiss me.\tEmbrasse-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #565931 (Fish) & #565943 (Archibald)',
#  'Kiss me.\tEmbrassez-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #565931 (Fish) & #565954 (Archibald)',
#  'Lie low.\tÀ terre !\tCC-BY 2.0 (France) Attribution: tatoeba.org #7966956 (CK) & #7089960 (Micsmithel)',
#  'Lie low.\tAu sol !\tCC-BY 2.0 (France) Attribution: tatoeba.org #7966956 (CK) & #8718853 (Micsmithel)',
#  'Lock it.\tVerrouillez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5350433 (mailohilohi) & #10046291 (Micsmithel)',
#  'Lock it.\tVerrouille-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5350433 (mailohilohi) & #10046292 (Micsmithel)',
#  'Lock it.\tVerrouillez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5350433 (mailohilohi) & #10046293 (Micsmithel)',
#  'Lock it.\tVerrouille-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5350433 (mailohilohi) & #10046296 (Micsmithel)',
#  'Me, too.\tMoi aussi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #321985 (CK) & #433586 (jerom)',
#  'Move on.\tPassez à autre chose.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907613 (CK) & #9025620 (Micsmithel)',
#  'Move on.\tPasse à autre chose.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907613 (CK) & #9025621 (Micsmithel)',
#  'Open it.\tOuvrez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8316002 (ritualesatanum) & #8984473 (Micsmithel)',
#  'Open it.\tOuvre-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8316002 (ritualesatanum) & #8984474 (Micsmithel)',
#  'Open it.\tOuvre-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8316002 (ritualesatanum) & #8999130 (Micsmithel)',
#  'Open it.\tOuvrez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8316002 (ritualesatanum) & #8999132 (Micsmithel)',
#  'Open up.\tOuvre-moi\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #22061 (CM) & #14216 (gillux)',
#  'Open up.\tOuvre.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22061 (CM) & #862202 (U2FS)',
#  'Pair up.\tFaites équipe.\tCC-BY 2.0 (France) Attribution: tatoeba.org #9630611 (shekitten) & #9987369 (Micsmithel)',
#  'Perfect!\tParfait\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #374568 (blay_paul) & #13107 (gillux)',
#  'Pull it.\tTirez dessus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049384 (mailohilohi) & #8739188 (Micsmithel)',
#  'Pull it.\tTire dessus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049384 (mailohilohi) & #8739189 (Micsmithel)',
#  'Push it.\tAppuie dessus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #8739186 (Micsmithel)',
#  'Push it.\tPoussez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #9252750 (Micsmithel)',
#  'Push it.\tPousse-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #9252751 (Micsmithel)',
#  'Push it.\tPoussez-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #9252752 (Micsmithel)',
#  'Push it.\tPousse-la.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #9252753 (Micsmithel)',
#  'See you!\tÀ plus tard !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357251 (Eldad) & #12709 (sacredceltic)',
#  'See you!\tÀ bientôt !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357251 (Eldad) & #337862 (sysko)',
#  'See you!\tÀ la prochaine !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357251 (Eldad) & #591489 (qdii)',
#  'See you!\tCiao.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357251 (Eldad) & #7704052 (Micsmithel)',
#  'See you.\tÀ plus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1151432 (Roggy) & #13446 (sysko)',
#  'See you.\tCiao.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1151432 (Roggy) & #7704052 (Micsmithel)',
#  'Show me.\tMontre-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972649 (CK) & #1973011 (sacredceltic)',
#  'Show me.\tMontrez-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972649 (CK) & #1973012 (sacredceltic)',
#  'Shut up!\tTaisez-vous\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #354356 (bourdu)',
#  'Shut up!\tFerme-la\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #543127 (sacredceltic)',
#  'Shut up!\tTais-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #1158442 (sacredceltic)',
#  'Shut up!\tFerme-la !\tCC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #1170083 (sacredceltic)',
#  'Shut up!\tLa ferme !\tCC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #1652396 (sacredceltic)',
#  'Sign up.\tInscrivez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907663 (CK) & #9025618 (Micsmithel)',
#  'Sign up.\tInscris-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907663 (CK) & #9025619 (Micsmithel)',
#  'Skip it.\tPas grave.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1953076 (ozzie) & #3469077 (Lulantis)',
#  'So long.\tÀ plus tard !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2267731 (_undertoad) & #12709 (sacredceltic)',
#  'Take it.\tPrends-le\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #939377 (sacredceltic)',
#  'Take it.\tPrenez-le\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #939379 (sacredceltic)',
#  'Take it.\tPrends-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #1927909 (sacredceltic)',
#  'Take it.\tPrenez-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #1927910 (sacredceltic)',
#  'Take it.\tPrenez-le.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #8984356 (Micsmithel)',
#  'Tell me.\tDis-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913090 (CK) & #1927907 (sacredceltic)',
#  'Tell me.\tDites-moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913090 (CK) & #1927908 (sacredceltic)',
#  'Tom won.\tTom a gagné.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005191 (CK) & #4765913 (Doremi391)',
#  'Wake up!\tRéveille-toi\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #332233 (TRANG)',
#  'Wake up!\tRéveille-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #1650813 (sacredceltic)',
#  'Wake up!\tRéveillez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #1650814 (sacredceltic)',
#  'Wake up.\tRéveille-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1850243 (CK) & #1650813 (sacredceltic)',
#  'Wake up.\tRéveillez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1850243 (CK) & #1650814 (sacredceltic)',
#  'Wash up.\tLave-toi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #20763 (CK) & #579761 (sacredceltic)',
#  'Wash up.\tLavez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #20763 (CK) & #579762 (sacredceltic)',
#  'We know.\tNous savons.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1556167 (shanghainese) & #5265433 (pititnatole)',
#  'We lost.\tNous perdîmes.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109572 (sacredceltic)',
#  'We lost.\tNous avons perdu.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109573 (sacredceltic)',
#  'We lost.\tNous fûmes battus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109574 (sacredceltic)',
#  'We lost.\tNous fûmes battues.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109575 (sacredceltic)',
#  'We lost.\tNous fûmes défaits.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109576 (sacredceltic)',
#  'We lost.\tNous fûmes défaites.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109578 (sacredceltic)',
#  'We lost.\tNous avons été défaits.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109581 (sacredceltic)',
#  'We lost.\tNous avons été défaites.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109582 (sacredceltic)',
#  'We lost.\tNous avons été battus.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109584 (sacredceltic)',
#  'We lost.\tNous avons été battues.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #2109585 (sacredceltic)',
#  'Welcome.\tBienvenue\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #138919 (CM) & #373296 (Aiji)',
#  'Welcome.\tSoyez le bienvenu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #138919 (CM) & #7897776 (felix63)',
#  'Who ran?\tQui courrait ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2203765 (CK) & #7704150 (Micsmithel)',
#  'Who won?\tQui a gagné ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005190 (CK) & #2005254 (sacredceltic)',
#  "Who won?\tQui l'a emporté ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005190 (CK) & #2005256 (sacredceltic)",
#  'You run.\tTu cours.\tCC-BY 2.0 (France) Attribution: tatoeba.org #672252 (CK) & #4533885 (pfpillon)',
#  'You win.\tVous avez gagné.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8645635 (hamsolo474) & #9025536 (Micsmithel)',
#  'Aim high.\tVisez haut.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8768675 (fishda) & #9030031 (Micsmithel)',
#  'Aim high.\tVise haut.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8768675 (fishda) & #9030032 (Micsmithel)',
#  'Am I fat?\tSuis-je gros ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2214296 (Hybrid) & #2215243 (sacredceltic)',
#  'Am I fat?\tSuis-je grosse ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2214296 (Hybrid) & #2215245 (sacredceltic)',
# ...
#  'Come over.\tVenez chez nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972617 (CK) & #1973458 (sacredceltic)',
#  'Come over.\tViens chez moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972617 (CK) & #1973459 (sacredceltic)',
#  'Come over.\tVenez chez moi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972617 (CK) & #1973460 (sacredceltic)',
#  'Come soon.\tViens bientôt !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972619 (CK) & #1973444 (sacredceltic)',
#  'Come soon.\tVenez bientôt !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972619 (CK) & #1973445 (sacredceltic)',
#  'Cool down.\tCalmez-vous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860739 (CK) & #1158349 (sacredceltic)',
#  'Did I win?\tAi-je gagné ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005189 (CK) & #2005257 (sacredceltic)',
#  "Did I win?\tL'ai-je emporté ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005189 (CK) & #2005259 (sacredceltic)",
#  'Did I win?\tEst-ce moi qui ai gagné ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005189 (CK) & #4221826 (sacredceltic)',
#  'Do it now.\tFaites-le maintenant.\tCC-BY 2.0 (France) Attribution: tatoeba.org #435763 (CK) & #6463423 (Aiji)',
#  'Dogs bark.\tDes chiens aboient.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357070 (sacredceltic) & #934632 (sacredceltic)',
#  'Dogs bark.\tLes chiens aboient.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1357070 (sacredceltic) & #934633 (sacredceltic)',
#  "Don't ask.\tNe demande pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #320080 (CM) & #4963427 (sacredceltic)",
#  "Don't cry.\tNe pleure pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #953247 (CK) & #2144545 (Dreamk33)",
#  "Don't die.\tNe meurs pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860499 (CK) & #1996239 (sacredceltic)",
#  "Don't die.\tNe mourez pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860499 (CK) & #1996241 (sacredceltic)",
#  "Don't lie.\tNe mens pas.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111913 (CK) & #967179 (sacredceltic)",
#  "Don't lie.\tNe mens pas !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111913 (CK) & #7477636 (Micsmithel)",
#  "Don't run.\tNe courez pas.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111907 (CK) & #5576646 (Aiji)",
#  "Don't run.\tNe cours pas.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111907 (CK) & #5576647 (Aiji)",
#  'Excuse me.\tExcuse-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433504 (CK) & #10459 (sacredceltic)',
#  'Excuse me.\tExcusez-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433504 (CK) & #499087 (Aiji)',
#  'Excuse me?\tPardon\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #434704 (lukaszpp) & #9675 (sacredceltic)',
#  'Excuse me?\tJe vous demande pardon\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #434704 (lukaszpp) & #9677 (sysko)',
#  'Excuse me?\tPlaît-il\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #434704 (lukaszpp) & #496981 (sacredceltic)',
#  'Excuse me?\tPlait-il\u202f?\tCC-BY 2.0 (France) Attribution: tatoeba.org #434704 (lukaszpp) & #692676 (U2FS)',
#  'Excuse me?\tPardon ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #434704 (lukaszpp) & #4320357 (gillux)',
#  'Fantastic!\tFantastique\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #433511 (CK) & #10876 (sacredceltic)',
#  'Fantastic!\tFantastique\xa0!\tCC-BY 2.0 (France) Attribution: tatoeba.org #433511 (CK) & #7412242 (lbdx)',
#  'Fantastic!\tSensass !\tCC-BY 2.0 (France) Attribution: tatoeba.org #433511 (CK) & #8690499 (Micsmithel)',
#  'Feel this.\tSens ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972624 (CK) & #1973414 (sacredceltic)',
#  'Feel this.\tSentez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972624 (CK) & #1973415 (sacredceltic)',
#  'Feel this.\tTouche ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972624 (CK) & #1973416 (sacredceltic)',
#  'Feel this.\tTouchez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972624 (CK) & #1973417 (sacredceltic)',
#  'Film this.\tFilmez ceci.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8908217 (CK) & #9025596 (Micsmithel)',
#  'Film this.\tFilme ceci.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8908217 (CK) & #9025597 (Micsmithel)',
#  'Follow me.\tSuis-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #250135 (CK) & #991614 (sacredceltic)',
#  'Follow us.\tSuis-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972627 (CK) & #1973401 (sacredceltic)',
#  'Follow us.\tSuivez-nous !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972627 (CK) & #1973402 (sacredceltic)',
#  'Forget it!\tOublie !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #1181613 (sacredceltic)',
#  'Forget it!\tOublie-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #1181614 (sacredceltic)',
#  'Forget it!\tOubliez !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #1181615 (sacredceltic)',
#  'Forget it!\tOubliez-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #1181616 (sacredceltic)',
#  'Forget it!\tLaissez tomber.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #7166347 (Micsmithel)',
#  'Forget it!\tOubliez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1178694 (CK) & #8593840 (Micsmithel)',
#  'Forget it.\tLaisse tomber.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20398 (Eldad) & #400311 (qdii)',
#  'Forget it.\tOublie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20398 (Eldad) & #495892 (sacredceltic)',
#  'Forget it.\tOublie-le !\tCC-BY 2.0 (France) Attribution: tatoeba.org #20398 (Eldad) & #1181614 (sacredceltic)',
#  'Forget it.\tLaissez tomber.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20398 (Eldad) & #7166347 (Micsmithel)',
#  'Forget it.\tOubliez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #20398 (Eldad) & #8593840 (Micsmithel)',
#  'Forget me.\tOublie-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1512159 (CM) & #7938897 (Micsmithel)',
#  'Forget me.\tOubliez-moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1512159 (CM) & #7938898 (Micsmithel)',
#  'Get a job.\tTrouve un emploi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972630 (CK) & #1973318 (sacredceltic)',
#  'Get a job.\tTrouve un boulot !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972630 (CK) & #1973319 (sacredceltic)',
#  'Get a job.\tTrouvez un emploi !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972630 (CK) & #1973320 (sacredceltic)',
#  'Get a job.\tTrouvez un boulot !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972630 (CK) & #1973321 (sacredceltic)',
#  'Get going.\tVas-y.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #12815 (Archibald)',
#  'Get going.\tAllez-y.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #477558 (sacredceltic)',
#  'Get going.\tMarche.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #8090732 (Micsmithel)',
#  'Get going.\tAvance.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #8090733 (Micsmithel)',
#  'Get going.\tEn avant.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #8304754 (Micsmithel)',
#  'Get going.\tDéplace-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #8739083 (Micsmithel)',
#  'Get going.\tDéplacez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #8977847 (Micsmithel)',
#  'Get going.\tEn route.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7466026 (megamanenm) & #9392221 (Micsmithel)',
#  'Get ready.\tPrépare-toi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1989588 (CK) & #4767854 (Doremi391)',
#  'Get ready.\tPréparez-vous.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1989588 (CK) & #4767855 (Doremi391)',
#  'Go faster.\tVa plus vite.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6576266 (Eccles17) & #6576615 (GB3)',
#  'Go faster.\tAllez plus vite.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6576266 (Eccles17) & #6576616 (GB3)',
#  'Go get it.\tVa le chercher !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972634 (CK) & #1973303 (sacredceltic)',
#  'Go get it.\tAllez le chercher !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972634 (CK) & #1973304 (sacredceltic)',
#  'Go inside.\tEntrez\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2428954 (CK) & #440075 (franzmimm)',
#  'Go to bed.\tVa dormir\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #679463 (Paiooooo)',
#  'Go to bed.\tVa au lit !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #3640834 (sacredceltic)',
#  'Go to bed.\tAu lit !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #3640835 (sacredceltic)',
#  'Go to bed.\tAllez au lit !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #3640836 (sacredceltic)',
#  'Go to bed.\tFile au lit !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #6600629 (felix63)',
#  'Go to bed.\tAu dodo !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #7957936 (Micsmithel)',
#  'Go to bed.\tVa te coucher !\tCC-BY 2.0 (France) Attribution: tatoeba.org #2649250 (CK) & #8549726 (felix63)',
#  'Good luck.\tBonne chance\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #239431 (sacredceltic) & #8744 (sacredceltic)',
#  'Good luck.\tBonne chance.\tCC-BY 2.0 (France) Attribution: tatoeba.org #239431 (sacredceltic) & #966399 (sacredceltic)',
#  'Good luck.\tBonne continuation !\tCC-BY 2.0 (France) Attribution: tatoeba.org #239431 (sacredceltic) & #6774267 (Micsmithel)',
#  'Grab that.\tAttrape ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972635 (CK) & #1973297 (sacredceltic)',
#  'Grab that.\tAttrapez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972635 (CK) & #1973298 (sacredceltic)',
#  'Grab that.\tSaisis-toi de ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972635 (CK) & #2077440 (sacredceltic)',
#  'Grab that.\tSaisissez-vous de ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972635 (CK) & #2077441 (sacredceltic)',
#  'Grab this.\tAttrape ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972637 (CK) & #1973297 (sacredceltic)',
#  'Grab this.\tAttrapez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972637 (CK) & #1973298 (sacredceltic)',
#  'Hands off.\tPas touche\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #268620 (CM) & #14672 (sacredceltic)',
#  'Hands off.\tNe touche pas à ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #268620 (CM) & #1684605 (sacredceltic)',
#  'Have some.\tPrenez-en.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111823 (CK) & #9252806 (Micsmithel)',
#  'Have some.\tPrends-en.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111823 (CK) & #9252808 (Micsmithel)',
#  'He is ill.\tIl est malade.\tCC-BY 2.0 (France) Attribution: tatoeba.org #371409 (saeb) & #133247 (sacredceltic)',
#  'He is old.\tIl est vieux.\tCC-BY 2.0 (France) Attribution: tatoeba.org #302334 (CK) & #821565 (sacredceltic)',
#  "He's a DJ.\tIl est DJ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1383444 (CK) & #181146 (Aiji)",
#  "He's good.\tIl est bon.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1855193 (Spamster) & #1858319 (sacredceltic)",
#  "He's lazy.\tIl est paresseux.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2030108 (Spamster) & #837592 (sacredceltic)",
#  "He's mine.\tIl est à moi.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3140708 (CM) & #7919522 (hennebert)",
#  "He's rich.\tIl est riche.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1790802 (Spamster) & #1791449 (sacredceltic)",
#  "He's sexy.\tIl est sexy.\tCC-BY 2.0 (France) Attribution: tatoeba.org #288007 (CM) & #7477696 (theachaean)",
#  "Head east.\tDirigez-vous vers l'est.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8102686 (CK) & #8984252 (Micsmithel)",
#  "Head east.\tDirige-toi vers l'est.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8102686 (CK) & #8984253 (Micsmithel)",
#  "Head west.\tDirigez-vous vers l'ouest.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8102688 (CK) & #8984250 (Micsmithel)",
#  "Head west.\tDirige-toi vers l'ouest.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8102688 (CK) & #8984251 (Micsmithel)",
#  'Here I am.\tMe voici.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1540806 (CK) & #1112332 (sacredceltic)',
#  "Here's $5.\tVoilà cinq dollars.\tCC-BY 2.0 (France) Attribution: tatoeba.org #72539 (CS) & #181335 (hortusdei)",
#  'Hold fire.\tHalte au feu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972642 (CK) & #1973288 (sacredceltic)',
#  'Hold fire.\tCessez le feu !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972642 (CK) & #1973289 (sacredceltic)',
#  'Hold this.\tTiens ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972645 (CK) & #1973023 (sacredceltic)',
#  'Hold this.\tTenez ça !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972645 (CK) & #1973024 (sacredceltic)',
#  'Hold this.\tTenez ceci !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972645 (CK) & #1973025 (sacredceltic)',
#  'Hold this.\tTiens ceci !\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972645 (CK) & #1973026 (sacredceltic)',
#  "How awful!\tC'est affreux\u202f!\tCC-BY 2.0 (France) Attribution: tatoeba.org #72077 (CM) & #10149 (Bruno)",
#  "How awful!\tC'est horrible !\tCC-BY 2.0 (France) Attribution: tatoeba.org #72077 (CM) & #7957934 (Micsmithel)",
#  "How weird!\tComme c'est bizarre !\tCC-BY 2.0 (France) Attribution: tatoeba.org #4462562 (CK) & #7074422 (Micsmithel)",
#  "How's Tom?\tComment Tom va-t-il ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005177 (CK) & #4767874 (Doremi391)",
#  "How's Tom?\tComment va Tom ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005177 (CK) & #4767876 (Doremi391)",
#  'Humor Tom.\tMettez Tom de bonne humeur.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2203861 (CK) & #9416642 (Micsmithel)',
#  'Humor Tom.\tMets Tom de bonne humeur.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2203861 (CK) & #9416643 (Micsmithel)',
#  "I am cold.\tJ'ai froid.\tCC-BY 2.0 (France) Attribution: tatoeba.org #436325 (lukaszpp) & #469786 (mamat)",
#  'I am good.\tJe suis bon.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1120792 (cntrational) & #1121151 (sacredceltic)',
#  'I am here.\tJe suis ici.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2778806 (CK) & #4579521 (sacredceltic)',
#  'I am okay.\tJe vais bien.\tCC-BY 2.0 (France) Attribution: tatoeba.org #376402 (saeb) & #488439 (Anthaus)',
#  'I am sick.\tJe suis malade.\tCC-BY 2.0 (France) Attribution: tatoeba.org #436427 (lukaszpp) & #459031 (sacredceltic)',
#  'I am sure.\tJe suis sûr.\tCC-BY 2.0 (France) Attribution: tatoeba.org #436433 (lukaszpp) & #460762 (sacredceltic)',
#  'I am sure.\tJe suis certain.\tCC-BY 2.0 (France) Attribution: tatoeba.org #436433 (lukaszpp) & #1181577 (sacredceltic)',
#  'I am weak.\tJe suis faible.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2681118 (CM) & #5063522 (sacredceltic)',
#  'I beg you.\tJe vous en prie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #797290 (U2FS) & #477559 (sacredceltic)',
#  'I beg you.\tJe vous en conjure.\tCC-BY 2.0 (France) Attribution: tatoeba.org #797290 (U2FS) & #797289 (U2FS)',
#  'I beg you.\tJe vous en supplie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #797290 (U2FS) & #797291 (U2FS)',
#  'I beg you.\tJe te prie.\tCC-BY 2.0 (France) Attribution: tatoeba.org #797290 (U2FS) & #4479755 (Wemix)',
#  "I blinked.\tJ'ai cligné des yeux.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828657 (CK) & #10046286 (Micsmithel)",
#  'I can fly.\tJe sais voler.\tCC-BY 2.0 (France) Attribution: tatoeba.org #774825 (marloncori) & #2477538 (Micsmithel)',
#  'I can run.\tJe sais courir.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1173661 (CK) & #1313541 (sacredceltic)',
#  'I can ski.\tJe sais skier.\tCC-BY 2.0 (France) Attribution: tatoeba.org #52315 (CK) & #7209 (Cocorico)',
#  "I cheated.\tJ'ai triché.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828659 (CK) & #10046284 (Micsmithel)",
#  "I cheered.\tJ'acclamais.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828660 (CK) & #7938739 (Micsmithel)",
#  'I crashed.\tJe suis tombée.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828662 (CK) & #4678646 (sacredceltic)',
#  'I crashed.\tJe suis tombé.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828662 (CK) & #4678647 (sacredceltic)',
#  ...]

# %% [markdown]
# **Data Preprocessing**
# ==================

# %%
# The files are all in Unicode, to simplify we will turn Unicode characters to ASCII
import unicodedata
def unicodeToAscii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)if unicodedata.category(c) != 'Mn')

# Make everything in lowercase and trim all the punctuations, and remove non-letter characters
import re
def normalizeString(s):
  s = unicodeToAscii(s.lower().strip())
  s = re.sub(r"([.!?])", r" \1", s)
  s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
  return s

# Split every line into pairs and normalize
pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
pairs
# Out:
# [['go .', 'va !', 'cc by . france attribution tatoeba .org cm wittydev '],
#  ['go .',
#   'marche .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['go .', 'bouge !', 'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['hi .', 'salut !', 'cc by . france attribution tatoeba .org cm aiji '],
#  ['hi .', 'salut .', 'cc by . france attribution tatoeba .org cm gillux '],
#  ['run !',
#   'cours !',
#   'cc by . france attribution tatoeba .org papabear sacredceltic '],
#  ['run !',
#   'courez !',
#   'cc by . france attribution tatoeba .org papabear sacredceltic '],
#  ['run !',
#   'prenez vos jambes a vos cous !',
#   'cc by . france attribution tatoeba .org papabear sacredceltic '],
#  ['run !',
#   'file !',
#   'cc by . france attribution tatoeba .org papabear sacredceltic '],
#  ['run !',
#   'filez !',
#   'cc by . france attribution tatoeba .org papabear sacredceltic '],
#  ['run !',
#   'cours !',
#   'cc by . france attribution tatoeba .org papabear franlexcois '],
#  ['run !',
#   'fuyez !',
#   'cc by . france attribution tatoeba .org papabear micsmithel '],
#  ['run !',
#   'fuyons !',
#   'cc by . france attribution tatoeba .org papabear micsmithel '],
#  ['run .',
#   'cours !',
#   'cc by . france attribution tatoeba .org jsakuragi sacredceltic '],
#  ['run .',
#   'courez !',
#   'cc by . france attribution tatoeba .org jsakuragi sacredceltic '],
#  ['run .',
#   'prenez vos jambes a vos cous !',
#   'cc by . france attribution tatoeba .org jsakuragi sacredceltic '],
#  ['run .',
#   'file !',
#   'cc by . france attribution tatoeba .org jsakuragi sacredceltic '],
#  ['run .',
#   'filez !',
#   'cc by . france attribution tatoeba .org jsakuragi sacredceltic '],
#  ['run .',
#   'cours !',
#   'cc by . france attribution tatoeba .org jsakuragi franlexcois '],
#  ['run .',
#   'fuyez !',
#   'cc by . france attribution tatoeba .org jsakuragi micsmithel '],
#  ['run .',
#   'fuyons !',
#   'cc by . france attribution tatoeba .org jsakuragi micsmithel '],
#  ['who ?', 'qui ?', 'cc by . france attribution tatoeba .org ck gillux '],
#  ['wow !',
#   'ca alors !',
#   'cc by . france attribution tatoeba .org zifre zmoo '],
#  ['duck !', 'a terre !', 'cc by . france attribution tatoeba .org cm whidou '],
#  ['duck !',
#   'baisse toi !',
#   'cc by . france attribution tatoeba .org cm whidou '],
#  ['duck !',
#   'baissez vous !',
#   'cc by . france attribution tatoeba .org cm whidou '],
#  ['fire !',
#   'au feu !',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['help !',
#   'a l aide !',
#   'cc by . france attribution tatoeba .org lukaszpp sysko '],
#  ['hide .', 'cache toi .', 'cc by . france attribution tatoeba .org ck codl '],
#  ['hide .',
#   'cachez vous .',
#   'cc by . france attribution tatoeba .org ck codl '],
#  ['jump !',
#   'saute .',
#   'cc by . france attribution tatoeba .org jamessilver micsmithel '],
#  ['jump .',
#   'saute .',
#   'cc by . france attribution tatoeba .org shishir micsmithel '],
#  ['stop !',
#   'ca suffit !',
#   'cc by . france attribution tatoeba .org cm goofy '],
#  ['stop !', 'stop !', 'cc by . france attribution tatoeba .org cm u fs '],
#  ['stop !',
#   'arrete toi !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['wait !',
#   'attends !',
#   'cc by . france attribution tatoeba .org belgavox sacredceltic '],
#  ['wait !',
#   'attendez !',
#   'cc by . france attribution tatoeba .org belgavox sacredceltic '],
#  ['wait !',
#   'attendez .',
#   'cc by . france attribution tatoeba .org belgavox micsmithel '],
#  ['wait .',
#   'attends !',
#   'cc by . france attribution tatoeba .org camilozeta sacredceltic '],
#  ['wait .',
#   'attendez !',
#   'cc by . france attribution tatoeba .org camilozeta sacredceltic '],
#  ['wait .',
#   'attends .',
#   'cc by . france attribution tatoeba .org camilozeta gege veggie '],
#  ['wait .',
#   'attendez .',
#   'cc by . france attribution tatoeba .org camilozeta micsmithel '],
#  ['begin .',
#   'commencez .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['begin .',
#   'commence .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['go on .',
#   'poursuis .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go on .',
#   'continuez .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['go on .',
#   'poursuivez .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['hello !', 'bonjour !', 'cc by . france attribution tatoeba .org ck aiji '],
#  ['hello !', 'salut !', 'cc by . france attribution tatoeba .org ck aiji '],
#  ['i see .',
#   'je comprends .',
#   'cc by . france attribution tatoeba .org ck hikari '],
#  ['i see .',
#   'aha .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i try .',
#   'j essaye .',
#   'cc by . france attribution tatoeba .org ck nimfeo '],
#  ['i won !',
#   'j ai gagne !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i won !',
#   'je l ai emporte !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i won .',
#   'j ai gagne .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['oh no !',
#   'oh non !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['relax .',
#   'calme toi .',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'detends toi !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'detendez vous !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'relaxe max !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'cool raoul !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'du calme !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'relaxe !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'calmez vous !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'detends toi .',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'detends toi !',
#   'cc by . france attribution tatoeba .org shanghainese sacredceltic '],
#  ['relax .',
#   'du calme .',
#   'cc by . france attribution tatoeba .org shanghainese micsmithel '],
#  ['relax .',
#   'tranquille .',
#   'cc by . france attribution tatoeba .org shanghainese micsmithel '],
#  ['smile .',
#   'souriez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['smile .',
#   'souris pour la camera .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['smile .',
#   'souriez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['sorry ?',
#   'pardon ?',
#   'cc by . france attribution tatoeba .org rawrren gillux '],
#  ['attack !',
#   'attaque !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['attack !',
#   'attaquez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['attack !',
#   'a l attaque !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['buy it .',
#   'achetez la !',
#   'cc by . france attribution tatoeba .org ddnktr nimfeo '],
#  ['buy it .',
#   'achete le !',
#   'cc by . france attribution tatoeba .org ddnktr toynop '],
#  ['buy it .',
#   'achetez le !',
#   'cc by . france attribution tatoeba .org ddnktr gb '],
#  ['buy it .',
#   'achete la !',
#   'cc by . france attribution tatoeba .org ddnktr gb '],
#  ['cheers !',
#   'sante !',
#   'cc by . france attribution tatoeba .org human sacredceltic '],
#  ['cheers !',
#   'a votre sante !',
#   'cc by . france attribution tatoeba .org human lulantis '],
#  ['cheers !',
#   'merci !',
#   'cc by . france attribution tatoeba .org human sysko '],
#  ['cheers !',
#   'tchin tchin !',
#   'cc by . france attribution tatoeba .org human perce neige '],
#  ['eat it .',
#   'mangez le .',
#   'cc by . france attribution tatoeba .org garborg micsmithel '],
#  ['eat it .',
#   'mange le .',
#   'cc by . france attribution tatoeba .org garborg micsmithel '],
#  ['get up .',
#   'leve toi .',
#   'cc by . france attribution tatoeba .org pauldhunt u fs '],
#  ['get up .',
#   'leve toi !',
#   'cc by . france attribution tatoeba .org pauldhunt nimfeo '],
#  ['get up .',
#   'debout .',
#   'cc by . france attribution tatoeba .org pauldhunt micsmithel '],
#  ['go now .',
#   'va maintenant .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['go now .',
#   'allez y maintenant .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['go now .',
#   'vas y maintenant .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['got it !',
#   'j ai pige !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['got it !',
#   'compris !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['got it !',
#   'aha !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['got it ?', 'pige ?', 'cc by . france attribution tatoeba .org cm qdii '],
#  ['got it ?',
#   'compris ?',
#   'cc by . france attribution tatoeba .org cm chtof '],
#  ['got it ?',
#   't as capte ?',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['hop in .',
#   'monte .',
#   'cc by . france attribution tatoeba .org scott sacredceltic '],
#  ['hop in .',
#   'montez .',
#   'cc by . france attribution tatoeba .org scott sacredceltic '],
#  ['hug me .',
#   'serre moi dans tes bras !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hug me .',
#   'serrez moi dans vos bras !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i fell .',
#   'je suis tombee .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i fell .',
#   'je suis tombe .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i fled .',
#   'j ai fui .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i knit .',
#   'je tricote .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i know .',
#   'je sais .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i left .',
#   'je suis parti .',
#   'cc by . france attribution tatoeba .org erikspen sacredceltic '],
#  ['i left .',
#   'je suis partie .',
#   'cc by . france attribution tatoeba .org erikspen sacredceltic '],
#  ['i lied .',
#   'j ai menti .',
#   'cc by . france attribution tatoeba .org gianich micsmithel '],
#  ['i lost .',
#   'j ai perdu .',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['i paid .',
#   'je payais .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i paid .',
#   'je payai .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i paid .',
#   'j ai paye .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i quit .',
#   'j arrete .',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['i quit .',
#   'j ai arrete .',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['i m .',
#   'j ai ans .',
#   'cc by . france attribution tatoeba .org sacredceltic sacredceltic '],
#  ['i m ok .',
#   'je vais bien .',
#   'cc by . france attribution tatoeba .org ck anthaus '],
#  ['i m ok .',
#   'ca va .',
#   'cc by . france attribution tatoeba .org ck christiane '],
#  ['listen .',
#   'ecoutez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['no way !',
#   'c est pas possible !',
#   'cc by . france attribution tatoeba .org cs trotter '],
#  ['no way !',
#   'impossible !',
#   'cc by . france attribution tatoeba .org cs trang '],
#  ['no way !',
#   'hors de question !',
#   'cc by . france attribution tatoeba .org cs sysko '],
#  ['no way !',
#   'en aucun cas .',
#   'cc by . france attribution tatoeba .org cs sacredceltic '],
#  ['no way !',
#   'sans facons !',
#   'cc by . france attribution tatoeba .org cs sacredceltic '],
#  ['no way !',
#   'c est hors de question !',
#   'cc by . france attribution tatoeba .org cs rovo '],
#  ['no way !',
#   'il n en est pas question !',
#   'cc by . france attribution tatoeba .org cs rovo '],
#  ['no way !',
#   'c est exclu !',
#   'cc by . france attribution tatoeba .org cs sacredceltic '],
#  ['no way !',
#   'en aucune maniere !',
#   'cc by . france attribution tatoeba .org cs sacredceltic '],
#  ['no way !',
#   'hors de question !',
#   'cc by . france attribution tatoeba .org cs dreamk '],
#  ['really ?',
#   'vraiment ?',
#   'cc by . france attribution tatoeba .org kotobaboke gillux '],
#  ['really ?',
#   'vrai ?',
#   'cc by . france attribution tatoeba .org kotobaboke sacredceltic '],
#  ['really ?',
#   'ah bon ?',
#   'cc by . france attribution tatoeba .org kotobaboke gillux '],
#  ['really ?',
#   'ah vraiment ?',
#   'cc by . france attribution tatoeba .org kotobaboke micsmithel '],
#  ['really ?',
#   'vraiment ?',
#   'cc by . france attribution tatoeba .org kotobaboke micsmithel '],
#  ['thanks !', 'merci !', 'cc by . france attribution tatoeba .org ck sysko '],
#  ['thanks .',
#   'merci !',
#   'cc by . france attribution tatoeba .org nava sysko '],
#  ['thanks .',
#   'merci .',
#   'cc by . france attribution tatoeba .org nava joelle '],
#  ['try it .',
#   'essaie .',
#   'cc by . france attribution tatoeba .org cairnhead micsmithel '],
#  ['try it .',
#   'essayez .',
#   'cc by . france attribution tatoeba .org cairnhead micsmithel '],
#  ['try it .',
#   'essaye .',
#   'cc by . france attribution tatoeba .org cairnhead micsmithel '],
#  ['we try .',
#   'on essaye .',
#   'cc by . france attribution tatoeba .org ck pfpillon '],
#  ['we won .',
#   'nous avons gagne .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we won .',
#   'nous gagnames .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we won .',
#   'nous l avons emporte .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we won .',
#   'nous l emportames .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['ask tom .',
#   'demande a tom .',
#   'cc by . france attribution tatoeba .org ck sbgodin '],
#  ['ask him .',
#   'demande lui .',
#   'cc by . france attribution tatoeba .org ch micsmithel '],
#  ['awesome !',
#   'fantastique !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['awesome !',
#   'sensass !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be calm .',
#   'sois calme !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be calm .',
#   'soyez calme !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be calm .',
#   'soyez calmes !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be cool .',
#   'sois detendu !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'sois juste !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'soyez juste !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'soyez justes !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'sois equitable !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'soyez equitable !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'soyez equitables !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be fair .',
#   'sois honnete .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be fair .',
#   'sois sincere .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be fair .',
#   'soyez honnetes .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be kind .',
#   'sois gentil .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'sois gentil !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'sois gentille !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'soyez gentil !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'soyez gentille !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'soyez gentils !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be nice .',
#   'soyez gentilles !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['beat it .',
#   'va te faire foutre !',
#   'cc by . france attribution tatoeba .org cm trotter '],
#  ['beat it .',
#   'degage !',
#   'cc by . france attribution tatoeba .org cm corvus '],
#  ['beat it .',
#   'casse toi .',
#   'cc by . france attribution tatoeba .org cm sysko '],
#  ['beat it .',
#   'pars !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['beat it .',
#   'foutez le camp !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['beat it .',
#   'fous le camp !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['beat it .',
#   'pars d ici .',
#   'cc by . france attribution tatoeba .org cm rene '],
#  ['beat it .',
#   'va t en !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['beat it .',
#   'disparais !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['beat it .',
#   'fiche le camp .',
#   'cc by . france attribution tatoeba .org cm blabla '],
#  ['beat it .',
#   'tire toi de la .',
#   'cc by . france attribution tatoeba .org cm blabla '],
#  ['beat it .',
#   'casse toi de la .',
#   'cc by . france attribution tatoeba .org cm gillux '],
#  ['beat it .', 'oust !', 'cc by . france attribution tatoeba .org cm gillux '],
#  ['beat it .',
#   'degage .',
#   'cc by . france attribution tatoeba .org cm evafranska '],
#  ['beat it .',
#   'fiche le camp d ici .',
#   'cc by . france attribution tatoeba .org cm blabla '],
#  ['beat it .',
#   'deguerpissez .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['beat it .',
#   'bouge !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['beat it .',
#   'decampe !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['burn it .',
#   'brulez le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['burn it .',
#   'brulez la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['burn it .',
#   'brule la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['burn it .',
#   'brule le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['bury it .',
#   'enterrez le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['bury it .',
#   'enterre le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['bury it .',
#   'enterrez la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['bury it .',
#   'enterre la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['call me .',
#   'appelle moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['call me .',
#   'appelez moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['call us .',
#   'appelle nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['call us .',
#   'appelez nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come in .',
#   'entrez !',
#   'cc by . france attribution tatoeba .org hertz franzmimm '],
#  ['come in .',
#   'entre .',
#   'cc by . france attribution tatoeba .org hertz sacredceltic '],
#  ['come in .',
#   'entre !',
#   'cc by . france attribution tatoeba .org hertz sacredceltic '],
#  ['come in .',
#   'entrez !',
#   'cc by . france attribution tatoeba .org hertz sacredceltic '],
#  ['come on !', 'allez !', 'cc by . france attribution tatoeba .org ck qdii '],
#  ['come on !',
#   'en avant !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come on !',
#   'c est pas vrai dis !',
#   'cc by . france attribution tatoeba .org ck rovo '],
#  ['come on !',
#   'viens !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come on !',
#   'venez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come on !',
#   'secouez vous !',
#   'cc by . france attribution tatoeba .org ck julien pdc '],
#  ['come on !',
#   'secoue toi !',
#   'cc by . france attribution tatoeba .org ck julien pdc '],
#  ['come on .',
#   'allez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come on .',
#   'viens !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come on .',
#   'venez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drop it !',
#   'laisse tomber !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drop it !',
#   'laissez tomber !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drop it !',
#   'laisse le tomber !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drop it !',
#   'laissez le tomber !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get tom .',
#   'va chercher tom .',
#   'cc by . france attribution tatoeba .org ck lbdx '],
#  ['get out !', 'sors .', 'cc by . france attribution tatoeba .org ck sysko '],
#  ['get out !',
#   'sortez !',
#   'cc by . france attribution tatoeba .org ck archibald '],
#  ['get out !',
#   'degage !',
#   'cc by . france attribution tatoeba .org ck corvus '],
#  ['get out !',
#   'disparais !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'casse toi .',
#   'cc by . france attribution tatoeba .org ck sysko '],
#  ['get out !',
#   'degagez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'sors !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'sortez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'degage !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'disparais !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'du balai !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'fiche le camp .',
#   'cc by . france attribution tatoeba .org ck blabla '],
#  ['get out !', 'oust !', 'cc by . france attribution tatoeba .org ck gillux '],
#  ['get out !',
#   'vers l exterieur !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get out !',
#   'fichez le camp !',
#   'cc by . france attribution tatoeba .org ck blabla '],
#  ['get out !',
#   'sortez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['get out !',
#   'decampez !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['get out !',
#   'decampe !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['get out .',
#   'sors .',
#   'cc by . france attribution tatoeba .org eldad sysko '],
#  ['get out .',
#   'sortez !',
#   'cc by . france attribution tatoeba .org eldad archibald '],
#  ['get out .',
#   'degage !',
#   'cc by . france attribution tatoeba .org eldad corvus '],
#  ['get out .',
#   'disparais !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['get out .',
#   'casse toi .',
#   'cc by . france attribution tatoeba .org eldad sysko '],
#  ['get out .',
#   'degagez !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['get out .',
#   'sors !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['get out .',
#   'sortez !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['get out .',
#   'disparais !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['get out .',
#   'fiche le camp .',
#   'cc by . france attribution tatoeba .org eldad blabla '],
#  ['get out .',
#   'oust !',
#   'cc by . france attribution tatoeba .org eldad gillux '],
#  ['get out .',
#   'sortez .',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['get out .',
#   'bouge !',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['get out .',
#   'decampez !',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['get out .',
#   'decampe !',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['go away !',
#   'degage !',
#   'cc by . france attribution tatoeba .org ck corvus '],
#  ['go away !',
#   'pars !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away !',
#   'allez vous en !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away !',
#   'deguerpissez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away !',
#   'cassez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away !',
#   'bouge !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away !',
#   'decampez !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away !',
#   'decampe !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away .',
#   'va te faire foutre !',
#   'cc by . france attribution tatoeba .org ck trotter '],
#  ['go away .',
#   'pars !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away .',
#   'degage !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away .',
#   'fous le camp !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away .',
#   'pars d ici .',
#   'cc by . france attribution tatoeba .org ck rene '],
#  ['go away .',
#   'va t en !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away .',
#   'disparais !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go away .',
#   'deguerpissez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away .',
#   'cassez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away .',
#   'bouge !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away .',
#   'decampez !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go away .',
#   'decampe !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go back .',
#   'recule .',
#   'cc by . france attribution tatoeba .org sharris micsmithel '],
#  ['go home .',
#   'rentrez a la maison .',
#   'cc by . france attribution tatoeba .org ck romira '],
#  ['go home .',
#   'rentre a la maison .',
#   'cc by . france attribution tatoeba .org ck nomadsoul '],
#  ['go home .',
#   'rentre chez toi .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go home .',
#   'rentrez chez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go slow .',
#   'va doucement !',
#   'cc by . france attribution tatoeba .org undertoad sacredceltic '],
#  ['go slow .',
#   'allez doucement !',
#   'cc by . france attribution tatoeba .org undertoad sacredceltic '],
#  ['goodbye !',
#   'adieu !',
#   'cc by . france attribution tatoeba .org minshirui sacredceltic '],
#  ['goodbye !',
#   'a la revoyure .',
#   'cc by . france attribution tatoeba .org minshirui sysko '],
#  ['goodbye !',
#   'ciao .',
#   'cc by . france attribution tatoeba .org minshirui micsmithel '],
#  ['hang on !',
#   'attends un peu !',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['hang on !',
#   'attendez un peu !',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['hang on !',
#   'attendez .',
#   'cc by . france attribution tatoeba .org spamster micsmithel '],
#  ['hang on .',
#   'tiens bon !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hang on .',
#   'tenez bon !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hang on .',
#   'attendez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['he left .',
#   'il est parti .',
#   'cc by . france attribution tatoeba .org ch qdii '],
#  ['he quit .',
#   'il laissa tomber .',
#   'cc by . france attribution tatoeba .org sam m sacredceltic '],
#  ['he quit .',
#   'il a laisse tomber .',
#   'cc by . france attribution tatoeba .org sam m sacredceltic '],
#  ['he runs .',
#   'il court .',
#   'cc by . france attribution tatoeba .org ck gillux '],
#  ['help me !',
#   'aide moi !',
#   'cc by . france attribution tatoeba .org ck petrus '],
#  ['help me .',
#   'a l aide !',
#   'cc by . france attribution tatoeba .org zifre sysko '],
#  ['help me .',
#   'aide moi .',
#   'cc by . france attribution tatoeba .org zifre dominiko '],
#  ['help me .',
#   'aidez moi .',
#   'cc by . france attribution tatoeba .org zifre sacredceltic '],
#  ['help me .',
#   'aide moi !',
#   'cc by . france attribution tatoeba .org zifre petrus '],
#  ['help us .',
#   'aidez nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['help us .',
#   'aide nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold it !',
#   'ne bouge plus !',
#   'cc by . france attribution tatoeba .org ck pfpillon '],
#  ['hold it !',
#   'ne bougez plus !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['hold it !',
#   'restez ou vous etes !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['hold it !',
#   'attendez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['hold on .',
#   'ne quittez pas .',
#   'cc by . france attribution tatoeba .org sacredceltic qdii '],
#  ['hold on .',
#   'ne quitte pas !',
#   'cc by . france attribution tatoeba .org sacredceltic micsmithel '],
#  ['hug tom .',
#   'fais un calin a tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['i agree .',
#   'je suis du meme avis .',
#   'cc by . france attribution tatoeba .org lukaszpp nimfeo '],
#  ['i cried .',
#   'j ai pleure .',
#   'cc by . france attribution tatoeba .org ck felix '],
#  ['i dozed .',
#   'je me suis assoupi .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i dozed .',
#   'je me suis assoupie .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i drive .',
#   'je conduis .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i drove .',
#   'je conduisis .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i fired .',
#   'j ai tire .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i froze .',
#   'je me suis fige .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i froze .',
#   'je me suis figee .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i smoke .',
#   'je fume .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i snore .',
#   'je ronfle .',
#   'cc by . france attribution tatoeba .org ck julien pdc '],
#  ['i stink .',
#   'je pue .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i stood .',
#   'je me suis tenu debout .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i stood .',
#   'je me suis tenue debout .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i swore .',
#   'j ai promis .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i swore .',
#   'j ai jure .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i tried .',
#   'j essayai .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i tried .',
#   'j ai essaye .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i tried .',
#   'j ai tente .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i waved .',
#   'j ai fait signe .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i ll go .',
#   'j irai .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i m tom .',
#   'je suis tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['i m fat .',
#   'je suis gras .',
#   'cc by . france attribution tatoeba .org cntrational sacredceltic '],
#  ['i m fat .',
#   'je suis gros .',
#   'cc by . france attribution tatoeba .org cntrational sacredceltic '],
#  ['i m fit .',
#   'je suis en forme .',
#   'cc by . france attribution tatoeba .org ck nimfeo '],
#  ['i m hit !',
#   'je suis touche !',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['i m hit !',
#   'je suis touchee !',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['i m ill .',
#   'je suis malade .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i m sad .',
#   'je suis triste .',
#   'cc by . france attribution tatoeba .org ck sysko '],
#  ['i m sad .',
#   'j ai un coup de cafard .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i m sad .',
#   'je suis malheureux .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i m shy .',
#   'je suis timide .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['i m wet .',
#   'je suis mouille .',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['i m wet .',
#   'je suis mouillee .',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['it s me !',
#   'c est bibi !',
#   'cc by . france attribution tatoeba .org sacredceltic u fs '],
#  ['join us .',
#   'joignez vous .',
#   'cc by . france attribution tatoeba .org belgavox sacredceltic '],
#  ['join us .',
#   'joignez vous a nous .',
#   'cc by . france attribution tatoeba .org belgavox sacredceltic '],
#  ['keep it .',
#   'garde le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['keep it .',
#   'gardez le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['kick it .',
#   'donne lui un coup de pied .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kick it .',
#   'donnez lui un coup de pied .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kill it .',
#   'tuez le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kill it .',
#   'tue le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kill it .',
#   'tue la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kill it .',
#   'tuez la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['kiss me .',
#   'embrasse moi .',
#   'cc by . france attribution tatoeba .org fish archibald '],
#  ['kiss me .',
#   'embrassez moi .',
#   'cc by . france attribution tatoeba .org fish archibald '],
#  ['lie low .',
#   'a terre !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['lie low .',
#   'au sol !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['lock it .',
#   'verrouillez le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['lock it .',
#   'verrouille le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['lock it .',
#   'verrouillez la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['lock it .',
#   'verrouille la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['me too .',
#   'moi aussi .',
#   'cc by . france attribution tatoeba .org ck jerom '],
#  ['move on .',
#   'passez a autre chose .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['move on .',
#   'passe a autre chose .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['open it .',
#   'ouvrez le .',
#   'cc by . france attribution tatoeba .org ritualesatanum micsmithel '],
#  ['open it .',
#   'ouvre le .',
#   'cc by . france attribution tatoeba .org ritualesatanum micsmithel '],
#  ['open it .',
#   'ouvre la .',
#   'cc by . france attribution tatoeba .org ritualesatanum micsmithel '],
#  ['open it .',
#   'ouvrez la .',
#   'cc by . france attribution tatoeba .org ritualesatanum micsmithel '],
#  ['open up .',
#   'ouvre moi !',
#   'cc by . france attribution tatoeba .org cm gillux '],
#  ['open up .', 'ouvre .', 'cc by . france attribution tatoeba .org cm u fs '],
#  ['pair up .',
#   'faites equipe .',
#   'cc by . france attribution tatoeba .org shekitten micsmithel '],
#  ['perfect !',
#   'parfait !',
#   'cc by . france attribution tatoeba .org blay paul gillux '],
#  ['pull it .',
#   'tirez dessus .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['pull it .',
#   'tire dessus .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['push it .',
#   'appuie dessus .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['push it .',
#   'poussez le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['push it .',
#   'pousse le .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['push it .',
#   'poussez la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['push it .',
#   'pousse la .',
#   'cc by . france attribution tatoeba .org mailohilohi micsmithel '],
#  ['see you !',
#   'a plus tard !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['see you !',
#   'a bientot !',
#   'cc by . france attribution tatoeba .org eldad sysko '],
#  ['see you !',
#   'a la prochaine !',
#   'cc by . france attribution tatoeba .org eldad qdii '],
#  ['see you !',
#   'ciao .',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['see you .',
#   'a plus .',
#   'cc by . france attribution tatoeba .org roggy sysko '],
#  ['see you .',
#   'ciao .',
#   'cc by . france attribution tatoeba .org roggy micsmithel '],
#  ['show me .',
#   'montre moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['show me .',
#   'montrez moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['shut up !',
#   'taisez vous !',
#   'cc by . france attribution tatoeba .org lukaszpp bourdu '],
#  ['shut up !',
#   'ferme la !',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['shut up !',
#   'tais toi !',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['shut up !',
#   'ferme la !',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['shut up !',
#   'la ferme !',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['sign up .',
#   'inscrivez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['sign up .',
#   'inscris toi .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['skip it .',
#   'pas grave .',
#   'cc by . france attribution tatoeba .org ozzie lulantis '],
#  ['so long .',
#   'a plus tard !',
#   'cc by . france attribution tatoeba .org undertoad sacredceltic '],
#  ['take it .',
#   'prends le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['take it .',
#   'prenez le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['take it .',
#   'prends le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['take it .',
#   'prenez le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['take it .',
#   'prenez le .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['tell me .',
#   'dis moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['tell me .',
#   'dites moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['tom won .',
#   'tom a gagne .',
#   'cc by . france attribution tatoeba .org ck doremi '],
#  ['wake up !',
#   'reveille toi !',
#   'cc by . france attribution tatoeba .org ck trang '],
#  ['wake up !',
#   'reveille toi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['wake up !',
#   'reveillez vous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['wake up .',
#   'reveille toi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['wake up .',
#   'reveillez vous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['wash up .',
#   'lave toi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['wash up .',
#   'lavez vous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we know .',
#   'nous savons .',
#   'cc by . france attribution tatoeba .org shanghainese pititnatole '],
#  ['we lost .',
#   'nous perdimes .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous avons perdu .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous fumes battus .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous fumes battues .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous fumes defaits .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous fumes defaites .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous avons ete defaits .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous avons ete defaites .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous avons ete battus .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['we lost .',
#   'nous avons ete battues .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['welcome .',
#   'bienvenue !',
#   'cc by . france attribution tatoeba .org cm aiji '],
#  ['welcome .',
#   'soyez le bienvenu !',
#   'cc by . france attribution tatoeba .org cm felix '],
#  ['who ran ?',
#   'qui courrait ?',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['who won ?',
#   'qui a gagne ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['who won ?',
#   'qui l a emporte ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['you run .',
#   'tu cours .',
#   'cc by . france attribution tatoeba .org ck pfpillon '],
#  ['you win .',
#   'vous avez gagne .',
#   'cc by . france attribution tatoeba .org hamsolo micsmithel '],
#  ['aim high .',
#   'visez haut .',
#   'cc by . france attribution tatoeba .org fishda micsmithel '],
#  ['aim high .',
#   'vise haut .',
#   'cc by . france attribution tatoeba .org fishda micsmithel '],
#  ['am i fat ?',
#   'suis je gros ?',
#   'cc by . france attribution tatoeba .org hybrid sacredceltic '],
#  ['am i fat ?',
#   'suis je grosse ?',
#   'cc by . france attribution tatoeba .org hybrid sacredceltic '],
#  ['ask them .',
#   'demande leur .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['ask them .',
#   'demandez leur .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['back off !',
#   'recule !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off !',
#   'reculez .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off !',
#   'cassez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['back off .',
#   'recule !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off .',
#   'reculez .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off .',
#   'retire toi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off .',
#   'retirez vous .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['back off .',
#   'cassez vous .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be a man .',
#   'sois un homme !',
#   'cc by . france attribution tatoeba .org hybrid sacredceltic '],
#  ['be a man .',
#   'soyez un homme !',
#   'cc by . france attribution tatoeba .org hybrid sacredceltic '],
#  ['be brave .',
#   'soyez courageux !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be brief .',
#   'soyez bref .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be brief .',
#   'sois bref .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be brief .',
#   'sois breve .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be brief .',
#   'soyez breve .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be brief .',
#   'soyez brefs .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be brief .',
#   'soyez breves .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['be still .',
#   'sois calme !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be still .',
#   'soyez calme !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['be still .',
#   'soyez calmes !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['beats me .',
#   'aucune idee .',
#   'cc by . france attribution tatoeba .org blay paul sacredceltic '],
#  ['beats me .',
#   'j en sais foutre rien .',
#   'cc by . france attribution tatoeba .org blay paul sacredceltic '],
#  ['call tom .',
#   'appelle tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['call tom .',
#   'appelez tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['cheer up !',
#   'courage !',
#   'cc by . france attribution tatoeba .org cm cocorico '],
#  ['cool off !',
#   'detends toi !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['cuff him .',
#   'menottez le .',
#   'cc by . france attribution tatoeba .org ck pititnatole '],
#  ['drive on .',
#   'avance !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drive on .',
#   'avancez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drive on .',
#   'continue a rouler !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['drive on .',
#   'continuez a rouler !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['find tom .',
#   'trouve tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['find tom .',
#   'trouvez tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['fix this .',
#   'reparez ceci .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['fix this .',
#   'repare ca .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['get away !',
#   'degage !',
#   'cc by . france attribution tatoeba .org cm corvus '],
#  ['get away !',
#   'casse toi .',
#   'cc by . france attribution tatoeba .org cm sysko '],
#  ['get away !',
#   'pars !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'degage !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'fous le camp !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'pars d ici .',
#   'cc by . france attribution tatoeba .org cm rene '],
#  ['get away !',
#   'va t en !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'ecarte toi !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'disparais !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'allez vous en !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get away !',
#   'fiche le camp .',
#   'cc by . france attribution tatoeba .org cm blabla '],
#  ['get away !',
#   'tire toi de la .',
#   'cc by . france attribution tatoeba .org cm blabla '],
#  ['get away !',
#   'degage .',
#   'cc by . france attribution tatoeba .org cm evafranska '],
#  ['get away !',
#   'va t en !',
#   'cc by . france attribution tatoeba .org cm felix '],
#  ['get away !',
#   'criss ton camp d icit !',
#   'cc by . france attribution tatoeba .org cm marioo '],
#  ['get away !',
#   'fichez le camp .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'deguerpissez .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'cassez vous .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'barrez vous .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'barre toi .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'va t en !',
#   'cc by . france attribution tatoeba .org cm julien pdc '],
#  ['get away !',
#   'bouge !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'decampez !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away !',
#   'decampe !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get away .',
#   'pars .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['get away .',
#   'partez .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['get down !',
#   'lache toi !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['get down !',
#   'a terre !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get down !',
#   'au sol !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get down !',
#   'descends .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get down .',
#   'descends !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get down .',
#   'descendez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get down .',
#   'lache toi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get down .',
#   'lachez vous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get down .',
# ...
#  ['calm down !',
#   'tranquille .',
#   'cc by . france attribution tatoeba .org scott micsmithel '],
#  ['calm down .',
#   'calme toi .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['calm down .',
#   'du calme .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['calm down .',
#   'tranquille .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['can we go ?',
#   'pouvons nous partir ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['can we go ?',
#   'pouvons nous nous en aller ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['can we go ?',
#   'pouvons nous y aller ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['catch tom .',
#   'attrape tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['catch tom .',
#   'attrapez tom .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['catch him .',
#   'attrape le !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['catch him .',
#   'rattrape le .',
#   'cc by . france attribution tatoeba .org ck pfpillon '],
#  ['chill out .',
#   'calme toi .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['chill out .',
#   'tranquille .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['choose me .',
#   'choisis moi !',
#   'cc by . france attribution tatoeba .org osohombre micsmithel '],
#  ['come back .',
#   'reviens !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come back .',
#   'revenez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come here .',
#   'viens ici .',
#   'cc by . france attribution tatoeba .org swift qdii '],
#  ['come here .',
#   'venez la .',
#   'cc by . france attribution tatoeba .org swift thuret '],
#  ['come over !',
#   'viens !',
#   'cc by . france attribution tatoeba .org blay paul sacredceltic '],
#  ['come over !',
#   'venez !',
#   'cc by . france attribution tatoeba .org blay paul sacredceltic '],
#  ['come over .',
#   'venez ici !',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['come over .',
#   'viens chez nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come over .',
#   'venez chez nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come over .',
#   'viens chez moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come over .',
#   'venez chez moi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come soon .',
#   'viens bientot !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['come soon .',
#   'venez bientot !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['cool down .',
#   'calmez vous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['did i win ?',
#   'ai je gagne ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['did i win ?',
#   'l ai je emporte ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['did i win ?',
#   'est ce moi qui ai gagne ?',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['do it now .',
#   'faites le maintenant .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['dogs bark .',
#   'des chiens aboient .',
#   'cc by . france attribution tatoeba .org sacredceltic sacredceltic '],
#  ['dogs bark .',
#   'les chiens aboient .',
#   'cc by . france attribution tatoeba .org sacredceltic sacredceltic '],
#  ['don t ask .',
#   'ne demande pas !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['don t cry .',
#   'ne pleure pas !',
#   'cc by . france attribution tatoeba .org ck dreamk '],
#  ['don t die .',
#   'ne meurs pas !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['don t die .',
#   'ne mourez pas !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['don t lie .',
#   'ne mens pas .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['don t lie .',
#   'ne mens pas !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['don t run .',
#   'ne courez pas .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['don t run .',
#   'ne cours pas .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['excuse me .',
#   'excuse moi .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['excuse me .',
#   'excusez moi .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['excuse me ?',
#   'pardon ?',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['excuse me ?',
#   'je vous demande pardon ?',
#   'cc by . france attribution tatoeba .org lukaszpp sysko '],
#  ['excuse me ?',
#   'plait il ?',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['excuse me ?',
#   'plait il ?',
#   'cc by . france attribution tatoeba .org lukaszpp u fs '],
#  ['excuse me ?',
#   'pardon ?',
#   'cc by . france attribution tatoeba .org lukaszpp gillux '],
#  ['fantastic !',
#   'fantastique !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['fantastic !',
#   'fantastique !',
#   'cc by . france attribution tatoeba .org ck lbdx '],
#  ['fantastic !',
#   'sensass !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['feel this .',
#   'sens ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['feel this .',
#   'sentez ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['feel this .',
#   'touche ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['feel this .',
#   'touchez ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['film this .',
#   'filmez ceci .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['film this .',
#   'filme ceci .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['follow me .',
#   'suis moi .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['follow us .',
#   'suis nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['follow us .',
#   'suivez nous !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['forget it !',
#   'oublie !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['forget it !',
#   'oublie le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['forget it !',
#   'oubliez !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['forget it !',
#   'oubliez le !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['forget it !',
#   'laissez tomber .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['forget it !',
#   'oubliez ca !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['forget it .',
#   'laisse tomber .',
#   'cc by . france attribution tatoeba .org eldad qdii '],
#  ['forget it .',
#   'oublie .',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['forget it .',
#   'oublie le !',
#   'cc by . france attribution tatoeba .org eldad sacredceltic '],
#  ['forget it .',
#   'laissez tomber .',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['forget it .',
#   'oubliez ca !',
#   'cc by . france attribution tatoeba .org eldad micsmithel '],
#  ['forget me .',
#   'oublie moi .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['forget me .',
#   'oubliez moi .',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['get a job .',
#   'trouve un emploi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get a job .',
#   'trouve un boulot !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get a job .',
#   'trouvez un emploi !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get a job .',
#   'trouvez un boulot !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['get going .',
#   'vas y .',
#   'cc by . france attribution tatoeba .org megamanenm archibald '],
#  ['get going .',
#   'allez y .',
#   'cc by . france attribution tatoeba .org megamanenm sacredceltic '],
#  ['get going .',
#   'marche .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get going .',
#   'avance .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get going .',
#   'en avant .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get going .',
#   'deplace toi .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get going .',
#   'deplacez vous .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get going .',
#   'en route .',
#   'cc by . france attribution tatoeba .org megamanenm micsmithel '],
#  ['get ready .',
#   'prepare toi .',
#   'cc by . france attribution tatoeba .org ck doremi '],
#  ['get ready .',
#   'preparez vous .',
#   'cc by . france attribution tatoeba .org ck doremi '],
#  ['go faster .',
#   'va plus vite .',
#   'cc by . france attribution tatoeba .org eccles gb '],
#  ['go faster .',
#   'allez plus vite .',
#   'cc by . france attribution tatoeba .org eccles gb '],
#  ['go get it .',
#   'va le chercher !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go get it .',
#   'allez le chercher !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go inside .',
#   'entrez !',
#   'cc by . france attribution tatoeba .org ck franzmimm '],
#  ['go to bed .',
#   'va dormir !',
#   'cc by . france attribution tatoeba .org ck paiooooo '],
#  ['go to bed .',
#   'va au lit !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go to bed .',
#   'au lit !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go to bed .',
#   'allez au lit !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['go to bed .',
#   'file au lit !',
#   'cc by . france attribution tatoeba .org ck felix '],
#  ['go to bed .',
#   'au dodo !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['go to bed .',
#   'va te coucher !',
#   'cc by . france attribution tatoeba .org ck felix '],
#  ['good luck .',
#   'bonne chance !',
#   'cc by . france attribution tatoeba .org sacredceltic sacredceltic '],
#  ['good luck .',
#   'bonne chance .',
#   'cc by . france attribution tatoeba .org sacredceltic sacredceltic '],
#  ['good luck .',
#   'bonne continuation !',
#   'cc by . france attribution tatoeba .org sacredceltic micsmithel '],
#  ['grab that .',
#   'attrape ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['grab that .',
#   'attrapez ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['grab that .',
#   'saisis toi de ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['grab that .',
#   'saisissez vous de ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['grab this .',
#   'attrape ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['grab this .',
#   'attrapez ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hands off .',
#   'pas touche !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['hands off .',
#   'ne touche pas a ca !',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['have some .',
#   'prenez en .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['have some .',
#   'prends en .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['he is ill .',
#   'il est malade .',
#   'cc by . france attribution tatoeba .org saeb sacredceltic '],
#  ['he is old .',
#   'il est vieux .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['he s a dj .',
#   'il est dj .',
#   'cc by . france attribution tatoeba .org ck aiji '],
#  ['he s good .',
#   'il est bon .',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['he s lazy .',
#   'il est paresseux .',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['he s mine .',
#   'il est a moi .',
#   'cc by . france attribution tatoeba .org cm hennebert '],
#  ['he s rich .',
#   'il est riche .',
#   'cc by . france attribution tatoeba .org spamster sacredceltic '],
#  ['he s sexy .',
#   'il est sexy .',
#   'cc by . france attribution tatoeba .org cm theachaean '],
#  ['head east .',
#   'dirigez vous vers l est .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['head east .',
#   'dirige toi vers l est .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['head west .',
#   'dirigez vous vers l ouest .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['head west .',
#   'dirige toi vers l ouest .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['here i am .',
#   'me voici .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['here s .',
#   'voila cinq dollars .',
#   'cc by . france attribution tatoeba .org cs hortusdei '],
#  ['hold fire .',
#   'halte au feu !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold fire .',
#   'cessez le feu !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold this .',
#   'tiens ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold this .',
#   'tenez ca !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold this .',
#   'tenez ceci !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['hold this .',
#   'tiens ceci !',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['how awful !',
#   'c est affreux !',
#   'cc by . france attribution tatoeba .org cm bruno '],
#  ['how awful !',
#   'c est horrible !',
#   'cc by . france attribution tatoeba .org cm micsmithel '],
#  ['how weird !',
#   'comme c est bizarre !',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['how s tom ?',
#   'comment tom va t il ?',
#   'cc by . france attribution tatoeba .org ck doremi '],
#  ['how s tom ?',
#   'comment va tom ?',
#   'cc by . france attribution tatoeba .org ck doremi '],
#  ['humor tom .',
#   'mettez tom de bonne humeur .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['humor tom .',
#   'mets tom de bonne humeur .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i am cold .',
#   'j ai froid .',
#   'cc by . france attribution tatoeba .org lukaszpp mamat '],
#  ['i am good .',
#   'je suis bon .',
#   'cc by . france attribution tatoeba .org cntrational sacredceltic '],
#  ['i am here .',
#   'je suis ici .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i am okay .',
#   'je vais bien .',
#   'cc by . france attribution tatoeba .org saeb anthaus '],
#  ['i am sick .',
#   'je suis malade .',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['i am sure .',
#   'je suis sur .',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['i am sure .',
#   'je suis certain .',
#   'cc by . france attribution tatoeba .org lukaszpp sacredceltic '],
#  ['i am weak .',
#   'je suis faible .',
#   'cc by . france attribution tatoeba .org cm sacredceltic '],
#  ['i beg you .',
#   'je vous en prie .',
#   'cc by . france attribution tatoeba .org u fs sacredceltic '],
#  ['i beg you .',
#   'je vous en conjure .',
#   'cc by . france attribution tatoeba .org u fs u fs '],
#  ['i beg you .',
#   'je vous en supplie .',
#   'cc by . france attribution tatoeba .org u fs u fs '],
#  ['i beg you .',
#   'je te prie .',
#   'cc by . france attribution tatoeba .org u fs wemix '],
#  ['i blinked .',
#   'j ai cligne des yeux .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i can fly .',
#   'je sais voler .',
#   'cc by . france attribution tatoeba .org marloncori micsmithel '],
#  ['i can run .',
#   'je sais courir .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i can ski .',
#   'je sais skier .',
#   'cc by . france attribution tatoeba .org ck cocorico '],
#  ['i cheated .',
#   'j ai triche .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i cheered .',
#   'j acclamais .',
#   'cc by . france attribution tatoeba .org ck micsmithel '],
#  ['i crashed .',
#   'je suis tombee .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ['i crashed .',
#   'je suis tombe .',
#   'cc by . france attribution tatoeba .org ck sacredceltic '],
#  ...]

# %%
print("Read %s sentence pairs" % len(pairs))
# Out:
# Read 190206 sentence pairs

# %%
# now since the original dataset is english to french but we need french to english language pair, we need to reverse it
pairs = [list(reversed(p)) for p in pairs]
pairs
# Out:
# [['cc by . france attribution tatoeba .org cm wittydev ', 'va !', 'go .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'marche .',
#   'go .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ', 'bouge !', 'go .'],
#  ['cc by . france attribution tatoeba .org cm aiji ', 'salut !', 'hi .'],
#  ['cc by . france attribution tatoeba .org cm gillux ', 'salut .', 'hi .'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'cours !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'courez !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'prenez vos jambes a vos cous !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'file !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'filez !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear franlexcois ',
#   'cours !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear micsmithel ',
#   'fuyez !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org papabear micsmithel ',
#   'fuyons !',
#   'run !'],
#  ['cc by . france attribution tatoeba .org jsakuragi sacredceltic ',
#   'cours !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi sacredceltic ',
#   'courez !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi sacredceltic ',
#   'prenez vos jambes a vos cous !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi sacredceltic ',
#   'file !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi sacredceltic ',
#   'filez !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi franlexcois ',
#   'cours !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi micsmithel ',
#   'fuyez !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org jsakuragi micsmithel ',
#   'fuyons !',
#   'run .'],
#  ['cc by . france attribution tatoeba .org ck gillux ', 'qui ?', 'who ?'],
#  ['cc by . france attribution tatoeba .org zifre zmoo ',
#   'ca alors !',
#   'wow !'],
#  ['cc by . france attribution tatoeba .org cm whidou ', 'a terre !', 'duck !'],
#  ['cc by . france attribution tatoeba .org cm whidou ',
#   'baisse toi !',
#   'duck !'],
#  ['cc by . france attribution tatoeba .org cm whidou ',
#   'baissez vous !',
#   'duck !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'au feu !',
#   'fire !'],
#  ['cc by . france attribution tatoeba .org lukaszpp sysko ',
#   'a l aide !',
#   'help !'],
#  ['cc by . france attribution tatoeba .org ck codl ', 'cache toi .', 'hide .'],
#  ['cc by . france attribution tatoeba .org ck codl ',
#   'cachez vous .',
#   'hide .'],
#  ['cc by . france attribution tatoeba .org jamessilver micsmithel ',
#   'saute .',
#   'jump !'],
#  ['cc by . france attribution tatoeba .org shishir micsmithel ',
#   'saute .',
#   'jump .'],
#  ['cc by . france attribution tatoeba .org cm goofy ',
#   'ca suffit !',
#   'stop !'],
#  ['cc by . france attribution tatoeba .org cm u fs ', 'stop !', 'stop !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'arrete toi !',
#   'stop !'],
#  ['cc by . france attribution tatoeba .org belgavox sacredceltic ',
#   'attends !',
#   'wait !'],
#  ['cc by . france attribution tatoeba .org belgavox sacredceltic ',
#   'attendez !',
#   'wait !'],
#  ['cc by . france attribution tatoeba .org belgavox micsmithel ',
#   'attendez .',
#   'wait !'],
#  ['cc by . france attribution tatoeba .org camilozeta sacredceltic ',
#   'attends !',
#   'wait .'],
#  ['cc by . france attribution tatoeba .org camilozeta sacredceltic ',
#   'attendez !',
#   'wait .'],
#  ['cc by . france attribution tatoeba .org camilozeta gege veggie ',
#   'attends .',
#   'wait .'],
#  ['cc by . france attribution tatoeba .org camilozeta micsmithel ',
#   'attendez .',
#   'wait .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'commencez .',
#   'begin .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'commence .',
#   'begin .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'poursuis .',
#   'go on .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'continuez .',
#   'go on .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'poursuivez .',
#   'go on .'],
#  ['cc by . france attribution tatoeba .org ck aiji ', 'bonjour !', 'hello !'],
#  ['cc by . france attribution tatoeba .org ck aiji ', 'salut !', 'hello !'],
#  ['cc by . france attribution tatoeba .org ck hikari ',
#   'je comprends .',
#   'i see .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'aha .',
#   'i see .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'j essaye .',
#   'i try .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai gagne !',
#   'i won !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je l ai emporte !',
#   'i won !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai gagne .',
#   'i won .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'oh non !',
#   'oh no !'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'calme toi .',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'detends toi !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'detendez vous !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'relaxe max !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'cool raoul !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'du calme !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'relaxe !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'calmez vous !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'detends toi .',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese sacredceltic ',
#   'detends toi !',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese micsmithel ',
#   'du calme .',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org shanghainese micsmithel ',
#   'tranquille .',
#   'relax .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'souriez !',
#   'smile .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'souris pour la camera .',
#   'smile .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'souriez !',
#   'smile .'],
#  ['cc by . france attribution tatoeba .org rawrren gillux ',
#   'pardon ?',
#   'sorry ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attaque !',
#   'attack !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attaquez !',
#   'attack !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'a l attaque !',
#   'attack !'],
#  ['cc by . france attribution tatoeba .org ddnktr nimfeo ',
#   'achetez la !',
#   'buy it .'],
#  ['cc by . france attribution tatoeba .org ddnktr toynop ',
#   'achete le !',
#   'buy it .'],
#  ['cc by . france attribution tatoeba .org ddnktr gb ',
#   'achetez le !',
#   'buy it .'],
#  ['cc by . france attribution tatoeba .org ddnktr gb ',
#   'achete la !',
#   'buy it .'],
#  ['cc by . france attribution tatoeba .org human sacredceltic ',
#   'sante !',
#   'cheers !'],
#  ['cc by . france attribution tatoeba .org human lulantis ',
#   'a votre sante !',
#   'cheers !'],
#  ['cc by . france attribution tatoeba .org human sysko ',
#   'merci !',
#   'cheers !'],
#  ['cc by . france attribution tatoeba .org human perce neige ',
#   'tchin tchin !',
#   'cheers !'],
#  ['cc by . france attribution tatoeba .org garborg micsmithel ',
#   'mangez le .',
#   'eat it .'],
#  ['cc by . france attribution tatoeba .org garborg micsmithel ',
#   'mange le .',
#   'eat it .'],
#  ['cc by . france attribution tatoeba .org pauldhunt u fs ',
#   'leve toi .',
#   'get up .'],
#  ['cc by . france attribution tatoeba .org pauldhunt nimfeo ',
#   'leve toi !',
#   'get up .'],
#  ['cc by . france attribution tatoeba .org pauldhunt micsmithel ',
#   'debout .',
#   'get up .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'va maintenant .',
#   'go now .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'allez y maintenant .',
#   'go now .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'vas y maintenant .',
#   'go now .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'j ai pige !',
#   'got it !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'compris !',
#   'got it !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'aha !',
#   'got it !'],
#  ['cc by . france attribution tatoeba .org cm qdii ', 'pige ?', 'got it ?'],
#  ['cc by . france attribution tatoeba .org cm chtof ',
#   'compris ?',
#   'got it ?'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   't as capte ?',
#   'got it ?'],
#  ['cc by . france attribution tatoeba .org scott sacredceltic ',
#   'monte .',
#   'hop in .'],
#  ['cc by . france attribution tatoeba .org scott sacredceltic ',
#   'montez .',
#   'hop in .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'serre moi dans tes bras !',
#   'hug me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'serrez moi dans vos bras !',
#   'hug me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tombee .',
#   'i fell .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tombe .',
#   'i fell .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai fui .',
#   'i fled .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je tricote .',
#   'i knit .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je sais .',
#   'i know .'],
#  ['cc by . france attribution tatoeba .org erikspen sacredceltic ',
#   'je suis parti .',
#   'i left .'],
#  ['cc by . france attribution tatoeba .org erikspen sacredceltic ',
#   'je suis partie .',
#   'i left .'],
#  ['cc by . france attribution tatoeba .org gianich micsmithel ',
#   'j ai menti .',
#   'i lied .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'j ai perdu .',
#   'i lost .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je payais .',
#   'i paid .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je payai .',
#   'i paid .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai paye .',
#   'i paid .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'j arrete .',
#   'i quit .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'j ai arrete .',
#   'i quit .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'j ai ans .',
#   'i m .'],
#  ['cc by . france attribution tatoeba .org ck anthaus ',
#   'je vais bien .',
#   'i m ok .'],
#  ['cc by . france attribution tatoeba .org ck christiane ',
#   'ca va .',
#   'i m ok .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ecoutez !',
#   'listen .'],
#  ['cc by . france attribution tatoeba .org cs trotter ',
#   'c est pas possible !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs trang ',
#   'impossible !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs sysko ',
#   'hors de question !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs sacredceltic ',
#   'en aucun cas .',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs sacredceltic ',
#   'sans facons !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs rovo ',
#   'c est hors de question !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs rovo ',
#   'il n en est pas question !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs sacredceltic ',
#   'c est exclu !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs sacredceltic ',
#   'en aucune maniere !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org cs dreamk ',
#   'hors de question !',
#   'no way !'],
#  ['cc by . france attribution tatoeba .org kotobaboke gillux ',
#   'vraiment ?',
#   'really ?'],
#  ['cc by . france attribution tatoeba .org kotobaboke sacredceltic ',
#   'vrai ?',
#   'really ?'],
#  ['cc by . france attribution tatoeba .org kotobaboke gillux ',
#   'ah bon ?',
#   'really ?'],
#  ['cc by . france attribution tatoeba .org kotobaboke micsmithel ',
#   'ah vraiment ?',
#   'really ?'],
#  ['cc by . france attribution tatoeba .org kotobaboke micsmithel ',
#   'vraiment ?',
#   'really ?'],
#  ['cc by . france attribution tatoeba .org ck sysko ', 'merci !', 'thanks !'],
#  ['cc by . france attribution tatoeba .org nava sysko ',
#   'merci !',
#   'thanks .'],
#  ['cc by . france attribution tatoeba .org nava joelle ',
#   'merci .',
#   'thanks .'],
#  ['cc by . france attribution tatoeba .org cairnhead micsmithel ',
#   'essaie .',
#   'try it .'],
#  ['cc by . france attribution tatoeba .org cairnhead micsmithel ',
#   'essayez .',
#   'try it .'],
#  ['cc by . france attribution tatoeba .org cairnhead micsmithel ',
#   'essaye .',
#   'try it .'],
#  ['cc by . france attribution tatoeba .org ck pfpillon ',
#   'on essaye .',
#   'we try .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons gagne .',
#   'we won .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous gagnames .',
#   'we won .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous l avons emporte .',
#   'we won .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous l emportames .',
#   'we won .'],
#  ['cc by . france attribution tatoeba .org ck sbgodin ',
#   'demande a tom .',
#   'ask tom .'],
#  ['cc by . france attribution tatoeba .org ch micsmithel ',
#   'demande lui .',
#   'ask him .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'fantastique !',
#   'awesome !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sensass !',
#   'awesome !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois calme !',
#   'be calm .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez calme !',
#   'be calm .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez calmes !',
#   'be calm .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois detendu !',
#   'be cool .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois juste !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez juste !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez justes !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois equitable !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez equitable !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez equitables !',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sois honnete .',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sois sincere .',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'soyez honnetes .',
#   'be fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois gentil .',
#   'be kind .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois gentil !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois gentille !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez gentil !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez gentille !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez gentils !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez gentilles !',
#   'be nice .'],
#  ['cc by . france attribution tatoeba .org cm trotter ',
#   'va te faire foutre !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm corvus ',
#   'degage !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sysko ',
#   'casse toi .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'pars !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'foutez le camp !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'fous le camp !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm rene ',
#   'pars d ici .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'va t en !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'disparais !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm blabla ',
#   'fiche le camp .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm blabla ',
#   'tire toi de la .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm gillux ',
#   'casse toi de la .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm gillux ', 'oust !', 'beat it .'],
#  ['cc by . france attribution tatoeba .org cm evafranska ',
#   'degage .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm blabla ',
#   'fiche le camp d ici .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'deguerpissez .',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'bouge !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'decampe !',
#   'beat it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'brulez le .',
#   'burn it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'brulez la .',
#   'burn it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'brule la .',
#   'burn it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'brule le .',
#   'burn it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'enterrez le .',
#   'bury it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'enterre le .',
#   'bury it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'enterrez la .',
#   'bury it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'enterre la .',
#   'bury it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'appelle moi !',
#   'call me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'appelez moi !',
#   'call me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'appelle nous !',
#   'call us .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'appelez nous !',
#   'call us .'],
#  ['cc by . france attribution tatoeba .org hertz franzmimm ',
#   'entrez !',
#   'come in .'],
#  ['cc by . france attribution tatoeba .org hertz sacredceltic ',
#   'entre .',
#   'come in .'],
#  ['cc by . france attribution tatoeba .org hertz sacredceltic ',
#   'entre !',
#   'come in .'],
#  ['cc by . france attribution tatoeba .org hertz sacredceltic ',
#   'entrez !',
#   'come in .'],
#  ['cc by . france attribution tatoeba .org ck qdii ', 'allez !', 'come on !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'en avant !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'c est pas vrai dis !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'viens !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'venez !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'secouez vous !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'secoue toi !',
#   'come on !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'allez !',
#   'come on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'viens !',
#   'come on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'venez !',
#   'come on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'laisse tomber !',
#   'drop it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'laissez tomber !',
#   'drop it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'laisse le tomber !',
#   'drop it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'laissez le tomber !',
#   'drop it !'],
#  ['cc by . france attribution tatoeba .org ck lbdx ',
#   'va chercher tom .',
#   'get tom .'],
#  ['cc by . france attribution tatoeba .org ck sysko ', 'sors .', 'get out !'],
#  ['cc by . france attribution tatoeba .org ck archibald ',
#   'sortez !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck corvus ',
#   'degage !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'disparais !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'casse toi .',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'degagez !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sors !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sortez !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'degage !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'disparais !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'du balai !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck blabla ',
#   'fiche le camp .',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck gillux ', 'oust !', 'get out !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vers l exterieur !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck blabla ',
#   'fichez le camp !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sortez .',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampez !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampe !',
#   'get out !'],
#  ['cc by . france attribution tatoeba .org eldad sysko ',
#   'sors .',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad archibald ',
#   'sortez !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad corvus ',
#   'degage !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'disparais !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sysko ',
#   'casse toi .',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'degagez !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'sors !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'sortez !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'disparais !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad blabla ',
#   'fiche le camp .',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad gillux ',
#   'oust !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'sortez .',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'bouge !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'decampez !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'decampe !',
#   'get out .'],
#  ['cc by . france attribution tatoeba .org ck corvus ',
#   'degage !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'pars !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'allez vous en !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'deguerpissez .',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'cassez vous .',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'bouge !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampez !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampe !',
#   'go away !'],
#  ['cc by . france attribution tatoeba .org ck trotter ',
#   'va te faire foutre !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'pars !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'degage !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'fous le camp !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck rene ',
#   'pars d ici .',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'va t en !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'disparais !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'deguerpissez .',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'cassez vous .',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'bouge !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampez !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'decampe !',
#   'go away .'],
#  ['cc by . france attribution tatoeba .org sharris micsmithel ',
#   'recule .',
#   'go back .'],
#  ['cc by . france attribution tatoeba .org ck romira ',
#   'rentrez a la maison .',
#   'go home .'],
#  ['cc by . france attribution tatoeba .org ck nomadsoul ',
#   'rentre a la maison .',
#   'go home .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'rentre chez toi .',
#   'go home .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'rentrez chez vous .',
#   'go home .'],
#  ['cc by . france attribution tatoeba .org undertoad sacredceltic ',
#   'va doucement !',
#   'go slow .'],
#  ['cc by . france attribution tatoeba .org undertoad sacredceltic ',
#   'allez doucement !',
#   'go slow .'],
#  ['cc by . france attribution tatoeba .org minshirui sacredceltic ',
#   'adieu !',
#   'goodbye !'],
#  ['cc by . france attribution tatoeba .org minshirui sysko ',
#   'a la revoyure .',
#   'goodbye !'],
#  ['cc by . france attribution tatoeba .org minshirui micsmithel ',
#   'ciao .',
#   'goodbye !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'attends un peu !',
#   'hang on !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'attendez un peu !',
#   'hang on !'],
#  ['cc by . france attribution tatoeba .org spamster micsmithel ',
#   'attendez .',
#   'hang on !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tiens bon !',
#   'hang on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tenez bon !',
#   'hang on .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'attendez .',
#   'hang on .'],
#  ['cc by . france attribution tatoeba .org ch qdii ',
#   'il est parti .',
#   'he left .'],
#  ['cc by . france attribution tatoeba .org sam m sacredceltic ',
#   'il laissa tomber .',
#   'he quit .'],
#  ['cc by . france attribution tatoeba .org sam m sacredceltic ',
#   'il a laisse tomber .',
#   'he quit .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'il court .',
#   'he runs .'],
#  ['cc by . france attribution tatoeba .org ck petrus ',
#   'aide moi !',
#   'help me !'],
#  ['cc by . france attribution tatoeba .org zifre sysko ',
#   'a l aide !',
#   'help me .'],
#  ['cc by . france attribution tatoeba .org zifre dominiko ',
#   'aide moi .',
#   'help me .'],
#  ['cc by . france attribution tatoeba .org zifre sacredceltic ',
#   'aidez moi .',
#   'help me .'],
#  ['cc by . france attribution tatoeba .org zifre petrus ',
#   'aide moi !',
#   'help me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'aidez nous !',
#   'help us .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'aide nous !',
#   'help us .'],
#  ['cc by . france attribution tatoeba .org ck pfpillon ',
#   'ne bouge plus !',
#   'hold it !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ne bougez plus !',
#   'hold it !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'restez ou vous etes !',
#   'hold it !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'attendez .',
#   'hold it !'],
#  ['cc by . france attribution tatoeba .org sacredceltic qdii ',
#   'ne quittez pas .',
#   'hold on .'],
#  ['cc by . france attribution tatoeba .org sacredceltic micsmithel ',
#   'ne quitte pas !',
#   'hold on .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'fais un calin a tom .',
#   'hug tom .'],
#  ['cc by . france attribution tatoeba .org lukaszpp nimfeo ',
#   'je suis du meme avis .',
#   'i agree .'],
#  ['cc by . france attribution tatoeba .org ck felix ',
#   'j ai pleure .',
#   'i cried .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me suis assoupi .',
#   'i dozed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me suis assoupie .',
#   'i dozed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je conduis .',
#   'i drive .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je conduisis .',
#   'i drove .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai tire .',
#   'i fired .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je me suis fige .',
#   'i froze .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je me suis figee .',
#   'i froze .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je fume .',
#   'i smoke .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'je ronfle .',
#   'i snore .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je pue .',
#   'i stink .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me suis tenu debout .',
#   'i stood .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me suis tenue debout .',
#   'i stood .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai promis .',
#   'i swore .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai jure .',
#   'i swore .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j essayai .',
#   'i tried .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai essaye .',
#   'i tried .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai tente .',
#   'i tried .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai fait signe .',
#   'i waved .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j irai .',
#   'i ll go .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis tom .',
#   'i m tom .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis gras .',
#   'i m fat .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis gros .',
#   'i m fat .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'je suis en forme .',
#   'i m fit .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis touche !',
#   'i m hit !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis touchee !',
#   'i m hit !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis malade .',
#   'i m ill .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'je suis triste .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai un coup de cafard .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis malheureux .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis timide .',
#   'i m shy .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis mouille .',
#   'i m wet .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis mouillee .',
#   'i m wet .'],
#  ['cc by . france attribution tatoeba .org sacredceltic u fs ',
#   'c est bibi !',
#   'it s me !'],
#  ['cc by . france attribution tatoeba .org belgavox sacredceltic ',
#   'joignez vous .',
#   'join us .'],
#  ['cc by . france attribution tatoeba .org belgavox sacredceltic ',
#   'joignez vous a nous .',
#   'join us .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'garde le !',
#   'keep it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'gardez le !',
#   'keep it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'donne lui un coup de pied .',
#   'kick it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'donnez lui un coup de pied .',
#   'kick it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tuez le .',
#   'kill it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tue le .',
#   'kill it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tue la .',
#   'kill it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tuez la .',
#   'kill it .'],
#  ['cc by . france attribution tatoeba .org fish archibald ',
#   'embrasse moi .',
#   'kiss me .'],
#  ['cc by . france attribution tatoeba .org fish archibald ',
#   'embrassez moi .',
#   'kiss me .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'a terre !',
#   'lie low .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'au sol !',
#   'lie low .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'verrouillez le .',
#   'lock it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'verrouille le .',
#   'lock it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'verrouillez la .',
#   'lock it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'verrouille la .',
#   'lock it .'],
#  ['cc by . france attribution tatoeba .org ck jerom ',
#   'moi aussi .',
#   'me too .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'passez a autre chose .',
#   'move on .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'passe a autre chose .',
#   'move on .'],
#  ['cc by . france attribution tatoeba .org ritualesatanum micsmithel ',
#   'ouvrez le .',
#   'open it .'],
#  ['cc by . france attribution tatoeba .org ritualesatanum micsmithel ',
#   'ouvre le .',
#   'open it .'],
#  ['cc by . france attribution tatoeba .org ritualesatanum micsmithel ',
#   'ouvre la .',
#   'open it .'],
#  ['cc by . france attribution tatoeba .org ritualesatanum micsmithel ',
#   'ouvrez la .',
#   'open it .'],
#  ['cc by . france attribution tatoeba .org cm gillux ',
#   'ouvre moi !',
#   'open up .'],
#  ['cc by . france attribution tatoeba .org cm u fs ', 'ouvre .', 'open up .'],
#  ['cc by . france attribution tatoeba .org shekitten micsmithel ',
#   'faites equipe .',
#   'pair up .'],
#  ['cc by . france attribution tatoeba .org blay paul gillux ',
#   'parfait !',
#   'perfect !'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tirez dessus .',
#   'pull it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'tire dessus .',
#   'pull it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'appuie dessus .',
#   'push it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'poussez le .',
#   'push it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'pousse le .',
#   'push it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'poussez la .',
#   'push it .'],
#  ['cc by . france attribution tatoeba .org mailohilohi micsmithel ',
#   'pousse la .',
#   'push it .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'a plus tard !',
#   'see you !'],
#  ['cc by . france attribution tatoeba .org eldad sysko ',
#   'a bientot !',
#   'see you !'],
#  ['cc by . france attribution tatoeba .org eldad qdii ',
#   'a la prochaine !',
#   'see you !'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'ciao .',
#   'see you !'],
#  ['cc by . france attribution tatoeba .org roggy sysko ',
#   'a plus .',
#   'see you .'],
#  ['cc by . france attribution tatoeba .org roggy micsmithel ',
#   'ciao .',
#   'see you .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'montre moi !',
#   'show me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'montrez moi !',
#   'show me .'],
#  ['cc by . france attribution tatoeba .org lukaszpp bourdu ',
#   'taisez vous !',
#   'shut up !'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'ferme la !',
#   'shut up !'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'tais toi !',
#   'shut up !'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'ferme la !',
#   'shut up !'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'la ferme !',
#   'shut up !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'inscrivez vous .',
#   'sign up .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'inscris toi .',
#   'sign up .'],
#  ['cc by . france attribution tatoeba .org ozzie lulantis ',
#   'pas grave .',
#   'skip it .'],
#  ['cc by . france attribution tatoeba .org undertoad sacredceltic ',
#   'a plus tard !',
#   'so long .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'prends le !',
#   'take it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'prenez le !',
#   'take it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'prends le !',
#   'take it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'prenez le !',
#   'take it .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'prenez le .',
#   'take it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'dis moi !',
#   'tell me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'dites moi !',
#   'tell me .'],
#  ['cc by . france attribution tatoeba .org ck doremi ',
#   'tom a gagne .',
#   'tom won .'],
#  ['cc by . france attribution tatoeba .org ck trang ',
#   'reveille toi !',
#   'wake up !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reveille toi !',
#   'wake up !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reveillez vous !',
#   'wake up !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reveille toi !',
#   'wake up .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reveillez vous !',
#   'wake up .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'lave toi !',
#   'wash up .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'lavez vous !',
#   'wash up .'],
#  ['cc by . france attribution tatoeba .org shanghainese pititnatole ',
#   'nous savons .',
#   'we know .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous perdimes .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons perdu .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous fumes battus .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous fumes battues .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous fumes defaits .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous fumes defaites .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons ete defaits .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons ete defaites .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons ete battus .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons ete battues .',
#   'we lost .'],
#  ['cc by . france attribution tatoeba .org cm aiji ',
#   'bienvenue !',
#   'welcome .'],
#  ['cc by . france attribution tatoeba .org cm felix ',
#   'soyez le bienvenu !',
#   'welcome .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'qui courrait ?',
#   'who ran ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'qui a gagne ?',
#   'who won ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'qui l a emporte ?',
#   'who won ?'],
#  ['cc by . france attribution tatoeba .org ck pfpillon ',
#   'tu cours .',
#   'you run .'],
#  ['cc by . france attribution tatoeba .org hamsolo micsmithel ',
#   'vous avez gagne .',
#   'you win .'],
#  ['cc by . france attribution tatoeba .org fishda micsmithel ',
#   'visez haut .',
#   'aim high .'],
#  ['cc by . france attribution tatoeba .org fishda micsmithel ',
#   'vise haut .',
#   'aim high .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'suis je gros ?',
#   'am i fat ?'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'suis je grosse ?',
#   'am i fat ?'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'demande leur .',
#   'ask them .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'demandez leur .',
#   'ask them .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'recule !',
#   'back off !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reculez .',
#   'back off !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'cassez vous .',
#   'back off !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'recule !',
#   'back off .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reculez .',
#   'back off .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'retire toi !',
#   'back off .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'retirez vous .',
#   'back off .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'cassez vous .',
#   'back off .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'sois un homme !',
#   'be a man .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'soyez un homme !',
#   'be a man .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez courageux !',
#   'be brave .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'soyez bref .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sois bref .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sois breve .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'soyez breve .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'soyez brefs .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'soyez breves .',
#   'be brief .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sois calme !',
#   'be still .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez calme !',
#   'be still .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'soyez calmes !',
#   'be still .'],
#  ['cc by . france attribution tatoeba .org blay paul sacredceltic ',
#   'aucune idee .',
#   'beats me .'],
#  ['cc by . france attribution tatoeba .org blay paul sacredceltic ',
#   'j en sais foutre rien .',
#   'beats me .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'appelle tom .',
#   'call tom .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'appelez tom .',
#   'call tom .'],
#  ['cc by . france attribution tatoeba .org cm cocorico ',
#   'courage !',
#   'cheer up !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'detends toi !',
#   'cool off !'],
#  ['cc by . france attribution tatoeba .org ck pititnatole ',
#   'menottez le .',
#   'cuff him .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'avance !',
#   'drive on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'avancez !',
#   'drive on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'continue a rouler !',
#   'drive on .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'continuez a rouler !',
#   'drive on .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'trouve tom .',
#   'find tom .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'trouvez tom .',
#   'find tom .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'reparez ceci .',
#   'fix this .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'repare ca .',
#   'fix this .'],
#  ['cc by . france attribution tatoeba .org cm corvus ',
#   'degage !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sysko ',
#   'casse toi .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'pars !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'degage !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'fous le camp !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm rene ',
#   'pars d ici .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'va t en !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'ecarte toi !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'disparais !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'allez vous en !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm blabla ',
#   'fiche le camp .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm blabla ',
#   'tire toi de la .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm evafranska ',
#   'degage .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm felix ',
#   'va t en !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm marioo ',
#   'criss ton camp d icit !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'fichez le camp .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'deguerpissez .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'cassez vous .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'barrez vous .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'barre toi .',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm julien pdc ',
#   'va t en !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'bouge !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'decampez !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'decampe !',
#   'get away !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'pars .',
#   'get away .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'partez .',
#   'get away .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'lache toi !',
#   'get down !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'a terre !',
#   'get down !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'au sol !',
#   'get down !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'descends .',
#   'get down !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'descends !',
#   'get down .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'descendez !',
#   'get down .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'lache toi !',
#   'get down .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'lachez vous !',
#   'get down .'],
# ...
#  ['cc by . france attribution tatoeba .org scott micsmithel ',
#   'tranquille .',
#   'calm down !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'calme toi .',
#   'calm down .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'du calme .',
#   'calm down .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'tranquille .',
#   'calm down .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'pouvons nous partir ?',
#   'can we go ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'pouvons nous nous en aller ?',
#   'can we go ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'pouvons nous y aller ?',
#   'can we go ?'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'attrape tom .',
#   'catch tom .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'attrapez tom .',
#   'catch tom .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'attrape le !',
#   'catch him .'],
#  ['cc by . france attribution tatoeba .org ck pfpillon ',
#   'rattrape le .',
#   'catch him .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'calme toi .',
#   'chill out .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'tranquille .',
#   'chill out .'],
#  ['cc by . france attribution tatoeba .org osohombre micsmithel ',
#   'choisis moi !',
#   'choose me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'reviens !',
#   'come back .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'revenez !',
#   'come back .'],
#  ['cc by . france attribution tatoeba .org swift qdii ',
#   'viens ici .',
#   'come here .'],
#  ['cc by . france attribution tatoeba .org swift thuret ',
#   'venez la .',
#   'come here .'],
#  ['cc by . france attribution tatoeba .org blay paul sacredceltic ',
#   'viens !',
#   'come over !'],
#  ['cc by . france attribution tatoeba .org blay paul sacredceltic ',
#   'venez !',
#   'come over !'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'venez ici !',
#   'come over .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'viens chez nous !',
#   'come over .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'venez chez nous !',
#   'come over .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'viens chez moi !',
#   'come over .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'venez chez moi !',
#   'come over .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'viens bientot !',
#   'come soon .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'venez bientot !',
#   'come soon .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'calmez vous !',
#   'cool down .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ai je gagne ?',
#   'did i win ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'l ai je emporte ?',
#   'did i win ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'est ce moi qui ai gagne ?',
#   'did i win ?'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'faites le maintenant .',
#   'do it now .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'des chiens aboient .',
#   'dogs bark .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'les chiens aboient .',
#   'dogs bark .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'ne demande pas !',
#   'don t ask .'],
#  ['cc by . france attribution tatoeba .org ck dreamk ',
#   'ne pleure pas !',
#   'don t cry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ne meurs pas !',
#   'don t die .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ne mourez pas !',
#   'don t die .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ne mens pas .',
#   'don t lie .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ne mens pas !',
#   'don t lie .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'ne courez pas .',
#   'don t run .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'ne cours pas .',
#   'don t run .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'excuse moi .',
#   'excuse me .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'excusez moi .',
#   'excuse me .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'pardon ?',
#   'excuse me ?'],
#  ['cc by . france attribution tatoeba .org lukaszpp sysko ',
#   'je vous demande pardon ?',
#   'excuse me ?'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'plait il ?',
#   'excuse me ?'],
#  ['cc by . france attribution tatoeba .org lukaszpp u fs ',
#   'plait il ?',
#   'excuse me ?'],
#  ['cc by . france attribution tatoeba .org lukaszpp gillux ',
#   'pardon ?',
#   'excuse me ?'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'fantastique !',
#   'fantastic !'],
#  ['cc by . france attribution tatoeba .org ck lbdx ',
#   'fantastique !',
#   'fantastic !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'sensass !',
#   'fantastic !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sens ca !',
#   'feel this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'sentez ca !',
#   'feel this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'touche ca !',
#   'feel this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'touchez ca !',
#   'feel this .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'filmez ceci .',
#   'film this .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'filme ceci .',
#   'film this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'suis moi .',
#   'follow me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'suis nous !',
#   'follow us .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'suivez nous !',
#   'follow us .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'oublie !',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'oublie le !',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'oubliez !',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'oubliez le !',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'laissez tomber .',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'oubliez ca !',
#   'forget it !'],
#  ['cc by . france attribution tatoeba .org eldad qdii ',
#   'laisse tomber .',
#   'forget it .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'oublie .',
#   'forget it .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'oublie le !',
#   'forget it .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'laissez tomber .',
#   'forget it .'],
#  ['cc by . france attribution tatoeba .org eldad micsmithel ',
#   'oubliez ca !',
#   'forget it .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'oublie moi .',
#   'forget me .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'oubliez moi .',
#   'forget me .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'trouve un emploi !',
#   'get a job .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'trouve un boulot !',
#   'get a job .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'trouvez un emploi !',
#   'get a job .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'trouvez un boulot !',
#   'get a job .'],
#  ['cc by . france attribution tatoeba .org megamanenm archibald ',
#   'vas y .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm sacredceltic ',
#   'allez y .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'marche .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'avance .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'en avant .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'deplace toi .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'deplacez vous .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org megamanenm micsmithel ',
#   'en route .',
#   'get going .'],
#  ['cc by . france attribution tatoeba .org ck doremi ',
#   'prepare toi .',
#   'get ready .'],
#  ['cc by . france attribution tatoeba .org ck doremi ',
#   'preparez vous .',
#   'get ready .'],
#  ['cc by . france attribution tatoeba .org eccles gb ',
#   'va plus vite .',
#   'go faster .'],
#  ['cc by . france attribution tatoeba .org eccles gb ',
#   'allez plus vite .',
#   'go faster .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'va le chercher !',
#   'go get it .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'allez le chercher !',
#   'go get it .'],
#  ['cc by . france attribution tatoeba .org ck franzmimm ',
#   'entrez !',
#   'go inside .'],
#  ['cc by . france attribution tatoeba .org ck paiooooo ',
#   'va dormir !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'va au lit !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'au lit !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'allez au lit !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck felix ',
#   'file au lit !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'au dodo !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org ck felix ',
#   'va te coucher !',
#   'go to bed .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'bonne chance !',
#   'good luck .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'bonne chance .',
#   'good luck .'],
#  ['cc by . france attribution tatoeba .org sacredceltic micsmithel ',
#   'bonne continuation !',
#   'good luck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attrape ca !',
#   'grab that .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attrapez ca !',
#   'grab that .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'saisis toi de ca !',
#   'grab that .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'saisissez vous de ca !',
#   'grab that .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attrape ca !',
#   'grab this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'attrapez ca !',
#   'grab this .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'pas touche !',
#   'hands off .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'ne touche pas a ca !',
#   'hands off .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'prenez en .',
#   'have some .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'prends en .',
#   'have some .'],
#  ['cc by . france attribution tatoeba .org saeb sacredceltic ',
#   'il est malade .',
#   'he is ill .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est vieux .',
#   'he is old .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'il est dj .',
#   'he s a dj .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est bon .',
#   'he s good .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est paresseux .',
#   'he s lazy .'],
#  ['cc by . france attribution tatoeba .org cm hennebert ',
#   'il est a moi .',
#   'he s mine .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est riche .',
#   'he s rich .'],
#  ['cc by . france attribution tatoeba .org cm theachaean ',
#   'il est sexy .',
#   'he s sexy .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'dirigez vous vers l est .',
#   'head east .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'dirige toi vers l est .',
#   'head east .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'dirigez vous vers l ouest .',
#   'head west .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'dirige toi vers l ouest .',
#   'head west .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'me voici .',
#   'here i am .'],
#  ['cc by . france attribution tatoeba .org cs hortusdei ',
#   'voila cinq dollars .',
#   'here s .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'halte au feu !',
#   'hold fire .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'cessez le feu !',
#   'hold fire .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tiens ca !',
#   'hold this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tenez ca !',
#   'hold this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tenez ceci !',
#   'hold this .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tiens ceci !',
#   'hold this .'],
#  ['cc by . france attribution tatoeba .org cm bruno ',
#   'c est affreux !',
#   'how awful !'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'c est horrible !',
#   'how awful !'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'comme c est bizarre !',
#   'how weird !'],
#  ['cc by . france attribution tatoeba .org ck doremi ',
#   'comment tom va t il ?',
#   'how s tom ?'],
#  ['cc by . france attribution tatoeba .org ck doremi ',
#   'comment va tom ?',
#   'how s tom ?'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'mettez tom de bonne humeur .',
#   'humor tom .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'mets tom de bonne humeur .',
#   'humor tom .'],
#  ['cc by . france attribution tatoeba .org lukaszpp mamat ',
#   'j ai froid .',
#   'i am cold .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis bon .',
#   'i am good .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ici .',
#   'i am here .'],
#  ['cc by . france attribution tatoeba .org saeb anthaus ',
#   'je vais bien .',
#   'i am okay .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis malade .',
#   'i am sick .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis sur .',
#   'i am sure .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis certain .',
#   'i am sure .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis faible .',
#   'i am weak .'],
#  ['cc by . france attribution tatoeba .org u fs sacredceltic ',
#   'je vous en prie .',
#   'i beg you .'],
#  ['cc by . france attribution tatoeba .org u fs u fs ',
#   'je vous en conjure .',
#   'i beg you .'],
#  ['cc by . france attribution tatoeba .org u fs u fs ',
#   'je vous en supplie .',
#   'i beg you .'],
#  ['cc by . france attribution tatoeba .org u fs wemix ',
#   'je te prie .',
#   'i beg you .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai cligne des yeux .',
#   'i blinked .'],
#  ['cc by . france attribution tatoeba .org marloncori micsmithel ',
#   'je sais voler .',
#   'i can fly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je sais courir .',
#   'i can run .'],
#  ['cc by . france attribution tatoeba .org ck cocorico ',
#   'je sais skier .',
#   'i can ski .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai triche .',
#   'i cheated .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j acclamais .',
#   'i cheered .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tombee .',
#   'i crashed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tombe .',
#   'i crashed .'],
#  ...]

# %%
'''
Since there are a lot of example sentences and we want to train something quickly, we'll trim the data set to only relatively short and
simple sentences. Here the maximum length is 10 words (that includes ending punctuation) and we're filtering to sentences that translate to
the form "I am" or "He is" etc. (accounting for apostrophes replaced earlier).
'''

MAX_LENGTH = 10
eng_prefixes = ("i am ", "i m ","he is", "he s ","she is", "she s ","you are", "you re ","we are", "we re ","they are", "they re ")

def filterPair(p):
  return len(p[1].split(' ')) < MAX_LENGTH and len(p[2].split(' ')) < MAX_LENGTH and p[2].startswith(eng_prefixes)

def filterPairs(pairs):
  return [pair for pair in pairs if filterPair(pair)]

pairs = filterPairs(pairs)
pairs
# Out:
# [['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'j ai ans .',
#   'i m .'],
#  ['cc by . france attribution tatoeba .org ck anthaus ',
#   'je vais bien .',
#   'i m ok .'],
#  ['cc by . france attribution tatoeba .org ck christiane ',
#   'ca va .',
#   'i m ok .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis tom .',
#   'i m tom .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis gras .',
#   'i m fat .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis gros .',
#   'i m fat .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'je suis en forme .',
#   'i m fit .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis touche !',
#   'i m hit !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis touchee !',
#   'i m hit !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis malade .',
#   'i m ill .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'je suis triste .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'j ai un coup de cafard .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis malheureux .',
#   'i m sad .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis timide .',
#   'i m shy .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis mouille .',
#   'i m wet .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis mouillee .',
#   'i m wet .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est mouille .',
#   'he s wet .'],
#  ['cc by . france attribution tatoeba .org cm aiji ',
#   'je suis tom .',
#   'i am tom .'],
#  ['cc by . france attribution tatoeba .org darinmex qdii ',
#   'je suis revenu .',
#   'i m back .'],
#  ['cc by . france attribution tatoeba .org darinmex dreamk ',
#   'me revoila .',
#   'i m back .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis chauve .',
#   'i m bald .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis occupe .',
#   'i m busy .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'je suis occupee .',
#   'i m busy .'],
#  ['cc by . france attribution tatoeba .org joseph sacredceltic ',
#   'je suis calme .',
#   'i m calm .'],
#  ['cc by . france attribution tatoeba .org lukaszpp mamat ',
#   'j ai froid .',
#   'i m cold .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis detendu .',
#   'i m cool .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis detendue .',
#   'i m cool .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis sourd .',
#   'i m deaf .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis sourde .',
#   'i m deaf .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en ai fini .',
#   'i m done .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis juste .',
#   'i m fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai la peau claire .',
#   'i m fair .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai le teint clair .',
#   'i m fair .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis rapide .',
#   'i m fast .'],
#  ['cc by . france attribution tatoeba .org eldad sacredceltic ',
#   'tout va bien .',
#   'i m fine .'],
#  ['cc by . france attribution tatoeba .org eldad anthaus ',
#   'je vais bien .',
#   'i m fine .'],
#  ['cc by . france attribution tatoeba .org eldad christiane ',
#   'ca va .',
#   'i m fine .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'je suis libre !',
#   'i m free !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis libre .',
#   'i m free .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis disponible .',
#   'i m free .'],
#  ['cc by . france attribution tatoeba .org ck zmoo ',
#   'je suis repu !',
#   'i m full .'],
#  ['cc by . france attribution tatoeba .org ck pjer ',
#   'je suis rassasie !',
#   'i m full .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'j en suis .',
#   'i m game .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis de la partie .',
#   'i m game .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis content .',
#   'i m glad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis chez moi .',
#   'i m home .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en retard .',
#   'i m late .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis paresseux .',
#   'i m lazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis faineant .',
#   'i m lazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis paresseuse .',
#   'i m lazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis faineante .',
#   'i m lazy .'],
#  ['cc by . france attribution tatoeba .org lukaszpp blabla ',
#   'je suis paume .',
#   'i m lost .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis perdue .',
#   'i m lost .'],
#  ['cc by . france attribution tatoeba .org ck anthaus ',
#   'je vais bien .',
#   'i m okay .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me porte bien .',
#   'i m okay .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis riche .',
#   'i m rich .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en securite .',
#   'i m safe .'],
#  ['cc by . france attribution tatoeba .org vgigregg sacredceltic ',
#   'je suis malade .',
#   'i m sick .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en suis certain .',
#   'i m sure .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis certain .',
#   'i m sure .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en suis sur .',
#   'i m sure .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en suis sure .',
#   'i m sure .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis grande .',
#   'i m tall .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'je suis mince .',
#   'i m thin .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ordonne .',
#   'i m tidy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ordonnee .',
#   'i m tidy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis laid .',
#   'i m ugly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis laide .',
#   'i m ugly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis faible .',
#   'i m weak .'],
#  ['cc by . france attribution tatoeba .org stevegrant anthaus ',
#   'je vais bien .',
#   'i m well .'],
#  ['cc by . france attribution tatoeba .org stevegrant sacredceltic ',
#   'je me porte bien .',
#   'i m well .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous allons bien .',
#   'we re ok .'],
#  ['cc by . france attribution tatoeba .org saeb sacredceltic ',
#   'il est malade .',
#   'he is ill .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est vieux .',
#   'he is old .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'il est dj .',
#   'he s a dj .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est bon .',
#   'he s good .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est paresseux .',
#   'he s lazy .'],
#  ['cc by . france attribution tatoeba .org cm hennebert ',
#   'il est a moi .',
#   'he s mine .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est riche .',
#   'he s rich .'],
#  ['cc by . france attribution tatoeba .org cm theachaean ',
#   'il est sexy .',
#   'he s sexy .'],
#  ['cc by . france attribution tatoeba .org lukaszpp mamat ',
#   'j ai froid .',
#   'i am cold .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'je suis bon .',
#   'i am good .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ici .',
#   'i am here .'],
#  ['cc by . france attribution tatoeba .org saeb anthaus ',
#   'je vais bien .',
#   'i am okay .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis malade .',
#   'i am sick .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis sur .',
#   'i am sure .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis certain .',
#   'i am sure .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis faible .',
#   'i am weak .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis flic .',
#   'i m a cop .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis un homme .',
#   'i m a man .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis en vie .',
#   'i m alive .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis vivant .',
#   'i m alive .'],
#  ['cc by . france attribution tatoeba .org ck yemana ',
#   'je suis vivante .',
#   'i m alive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis seule .',
#   'i m alone .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis seul .',
#   'i m alone .'],
#  ['cc by . france attribution tatoeba .org callmath aiji ',
#   'je suis enerve .',
#   'i m angry .'],
#  ['cc by . france attribution tatoeba .org callmath aiji ',
#   'je suis en colere .',
#   'i m angry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis arme .',
#   'i m armed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis armee .',
#   'i m armed .'],
#  ['cc by . france attribution tatoeba .org ck rene ',
#   'je suis reveille .',
#   'i m awake .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis aveugle .',
#   'i m blind .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis courageux .',
#   'i m brave .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis courageuse .',
#   'i m brave .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis brave .',
#   'i m brave .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis fauche .',
#   'i m broke .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai decroche .',
#   'i m clean .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis propre .',
#   'i m clean .'],
#  ['cc by . france attribution tatoeba .org languageexpert sacredceltic ',
#   'je suis fou .',
#   'i m crazy .'],
#  ['cc by . france attribution tatoeba .org languageexpert sacredceltic ',
#   'je suis folle .',
#   'i m crazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis gueri .',
#   'i m cured .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis guerie .',
#   'i m cured .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis sale .',
#   'i m dirty .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai la tete qui tourne .',
#   'i m dizzy .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis saoul .',
#   'i m drunk .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis soul .',
#   'i m drunk .'],
#  ['cc by . france attribution tatoeba .org cm nomadsoul ',
#   'je suis ivre .',
#   'i m drunk .'],
#  ['cc by . france attribution tatoeba .org shishir sacredceltic ',
#   'je me meurs .',
#   'i m dying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en avance .',
#   'i m early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en premier .',
#   'i m first .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis difficile .',
#   'i m fussy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tatillon .',
#   'i m fussy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tatillonne .',
#   'i m fussy .'],
#  ['cc by . france attribution tatoeba .org adjusting sbgodin ',
#   'je pars maintenant .',
#   'i m going .'],
#  ['cc by . france attribution tatoeba .org adjusting qdii ',
#   'je me tire .',
#   'i m going .'],
#  ['cc by . france attribution tatoeba .org adjusting sysko ',
#   'j y vais .',
#   'i m going .'],
#  ['cc by . france attribution tatoeba .org adjusting sacredceltic ',
#   'je pars .',
#   'i m going .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis loyal .',
#   'i m loyal .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis loyale .',
#   'i m loyal .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis veinard .',
#   'i m lucky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis veinarde .',
#   'i m lucky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai du pot .',
#   'i m lucky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis chanceux .',
#   'i m lucky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis chanceuse .',
#   'i m lucky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de mentir .',
#   'i m lying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis nu .',
#   'i m naked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis nue .',
#   'i m naked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me trouve nu .',
#   'i m naked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me trouve nue .',
#   'i m naked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis a poil .',
#   'i m naked .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis dans le besoin .',
#   'i m needy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tranquille .',
#   'i m quiet .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis prete !',
#   'i m ready !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis pret !',
#   'i m ready !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis pret .',
#   'i m ready .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai raison .',
#   'i m right .'],
#  ['cc by . france attribution tatoeba .org cm micsmithel ',
#   'je suis petite .',
#   'i m short .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sobre .',
#   'i m sober .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'excuse moi .',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'desole .',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'excusez moi .',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'desole !',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck algideamygdale ',
#   'je suis desole .',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck algideamygdale ',
#   'je suis desolee .',
#   'i m sorry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis coincee .',
#   'i m stuck .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis timide .',
#   'i m timid .'],
#  ['cc by . france attribution tatoeba .org brauliobezerra le petit ane gris ',
#   'je suis fatigue !',
#   'i m tired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis dur .',
#   'i m tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis dure .',
#   'i m tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis dur a cuire .',
#   'i m tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis dure a cuire .',
#   'i m tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis a toi .',
#   'i m yours .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis a vous .',
#   'i m yours .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'elle est chaude .',
#   'she s hot .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'elle est tres attirante .',
#   'she s hot .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'nous avons chaud .',
#   'we re hot .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes tristes .',
#   'we re sad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes timides .',
#   'we re shy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu vas bien .',
#   'you re ok .'],
#  ['cc by . france attribution tatoeba .org dj saidez sacredceltic ',
#   'chat !',
#   'you re it !'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'il est dj .',
#   'he is a dj .'],
#  ['cc by . france attribution tatoeba .org sacredceltic sacredceltic ',
#   'il a a faire .',
#   'he is busy .'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'il est ici !',
#   'he is here !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est gentil .',
#   'he is kind .'],
#  ['cc by . france attribution tatoeba .org cm nimfeo ',
#   'il est en retard .',
#   'he is late .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'il est faineant .',
#   'he is lazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est paresseux .',
#   'he is lazy .'],
#  ['cc by . france attribution tatoeba .org kebukebu nimfeo ',
#   'il est pauvre .',
#   'he is poor .'],
#  ['cc by . france attribution tatoeba .org saeb sacredceltic ',
#   'il est malade .',
#   'he is sick .'],
#  ['cc by . france attribution tatoeba .org feudrenais qdii ',
#   'il est suisse .',
#   'he s swiss .'],
#  ['cc by . france attribution tatoeba .org feudrenais tras ',
#   'il est helvete .',
#   'he s swiss .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'il est ruine .',
#   'he s broke .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'il est fauche .',
#   'he s broke .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'il est intelligent .',
#   'he s smart .'],
#  ['cc by . france attribution tatoeba .org mouseneb sacredceltic ',
#   'je suis un homme .',
#   'i am a man .'],
#  ['cc by . france attribution tatoeba .org cm sysko ',
#   'j y vais .',
#   'i am going .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis humain .',
#   'i am human .'],
#  ['cc by . france attribution tatoeba .org lukaszpp sacredceltic ',
#   'je suis pret .',
#   'i am ready .'],
#  ['cc by . france attribution tatoeba .org vest sacredceltic ',
#   'j ai raison .',
#   'i am right .'],
#  ['cc by . france attribution tatoeba .org lukaszpp micsmithel ',
#   'je suis petite .',
#   'i am short .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis une fille .',
#   'i m a girl .'],
#  ['cc by . france attribution tatoeba .org ck dominiko ',
#   'je suis un heros .',
#   'i m a hero .'],
#  ['cc by . france attribution tatoeba .org amikema belgavox ',
#   'je suis un menteur .',
#   'i m a liar .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'j ai un jumeau .',
#   'i m a twin .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis amuse .',
#   'i m amused .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis amusee .',
#   'i m amused .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ca m amuse .',
#   'i m amused .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je cuis !',
#   'i m baking !'],
#  ['cc by . france attribution tatoeba .org firez sacredceltic ',
#   'je vais mieux .',
#   'i m better .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai un parti pris .',
#   'i m biased .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je paie .',
#   'i m buying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'c est moi qui paie .',
#   'i m buying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis grassouillet .',
#   'i m chubby .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis grassouillette .',
#   'i m chubby .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'j arrive .',
#   'i m coming .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'je suis direct .',
#   'i m direct .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'je suis directe .',
#   'i m direct .'],
#  ['cc by . france attribution tatoeba .org vortarulo sacredceltic ',
#   'je mange .',
#   'i m eating .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis connu .',
#   'i m famous .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis connue .',
#   'i m famous .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis plus rapide .',
#   'i m faster .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis flasque .',
#   'i m flabby .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis cupide .',
#   'i m greedy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis gourmand .',
#   'i m greedy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis gourmande .',
#   'i m greedy .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'je me cache .',
#   'i m hiding .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis honnete .',
#   'i m honest .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis humble .',
#   'i m humble .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai faim !',
#   'i m hungry !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai faim !',
#   'i m hungry .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis immunise .',
#   'i m immune .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis immunisee .',
#   'i m immune .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis au lit .',
#   'i m in bed .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis alite .',
#   'i m in bed .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'je suis alitee .',
#   'i m in bed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me trouve a l interieur .',
#   'i m inside .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis a l interieur .',
#   'i m inside .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'je rigole !',
#   'i m joking .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis saoul .',
#   'i m loaded .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je me sens seul .',
#   'i m lonely .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'je me sens seule .',
#   'i m lonely .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de perdre .',
#   'i m losing .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de demenager .',
#   'i m moving .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis normal .',
#   'i m normal .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'je suis normale .',
#   'i m normal .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'c est moi qui paie .',
#   'i m paying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de payer .',
#   'i m paying .'],
#  ['cc by . france attribution tatoeba .org baisong qdii ',
#   'je suis creve .',
#   'i m pooped .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis repose .',
#   'i m rested .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis reposee .',
#   'i m rested .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ruine .',
#   'i m ruined .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis ruinee .',
#   'i m ruined .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis remue .',
#   'i m shaken .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis remuee .',
#   'i m shaken .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis celibataire .',
#   'i m single .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis maigrichon .',
#   'i m skinny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis maigrichonne .',
#   'i m skinny .'],
#  ['cc by . france attribution tatoeba .org ck le petit ane gris ',
#   'je suis fatigue !',
#   'i m sleepy !'],
#  ['cc by . france attribution tatoeba .org ck trang ',
#   'j ai sommeil !',
#   'i m sleepy !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sournois .',
#   'i m sneaky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sournoise .',
#   'i m sneaky .'],
#  ['cc by . france attribution tatoeba .org zifre theachaean ',
#   'je suis tellement gros .',
#   'i m so fat .'],
#  ['cc by . france attribution tatoeba .org zifre sacredceltic ',
#   'je suis tellement grosse .',
#   'i m so fat .'],
#  ['cc by . france attribution tatoeba .org lucasmg sacredceltic ',
#   'je suis trempee .',
#   'i m soaked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis strict .',
#   'i m strict .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis stricte .',
#   'i m strict .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis fort .',
#   'i m strong .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis forte .',
#   'i m strong .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai trente ans .',
#   'i m thirty .'],
#  ['cc by . france attribution tatoeba .org ck nimfeo ',
#   'j essaye .',
#   'i m trying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j essaie .',
#   'i m trying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je m y essaie .',
#   'i m trying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis affaiblie .',
#   'i m wasted .'],
#  ['cc by . france attribution tatoeba .org boscowitch sacredceltic ',
#   'elle est vieille .',
#   'she is old .'],
#  ['cc by . france attribution tatoeba .org trailsend sacredceltic ',
#   'elle est occupee .',
#   'she s busy .'],
#  ['cc by . france attribution tatoeba .org cs gillux ',
#   'elle est gentille .',
#   'she s nice .'],
#  ['cc by . france attribution tatoeba .org ck minti ',
#   'nous sommes des hommes .',
#   'we are men .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes de retour .',
#   'we re back .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'nous sommes des garcons .',
#   'we re boys .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes occupes .',
#   'we re busy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes occupees .',
#   'we re busy .'],
#  ['cc by . france attribution tatoeba .org ck zarisi ',
#   'nous sommes calmes .',
#   'we re calm .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons fini .',
#   'we re done .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons termine .',
#   'we re done .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous en avons fini .',
#   'we re done .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous en avons termine .',
#   'we re done .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'nous sommes quittes .',
#   'we re even .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'nous sommes a egalite .',
#   'we re even .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous allons bien .',
#   'we re fine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes ici .',
#   'we re here .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes la .',
#   'we re here .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes chez nous .',
#   'we re home .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes en retard .',
#   'we re late .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'nous sommes paresseux .',
#   'we re lazy .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'nous sommes faineantes .',
#   'we re lazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes perdus .',
#   'we re lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes perdues .',
#   'we re lost .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes riches .',
#   'we re rich .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes en securite .',
#   'we re safe .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'on est foutu .',
#   'we re sunk .'],
#  ['cc by . france attribution tatoeba .org cm sacredceltic ',
#   'nous sommes foutus .',
#   'we re sunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes faibles .',
#   'we re weak .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es vilain .',
#   'you re bad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es grand .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es grande .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes grand .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes grande .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes grands .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes grandes .',
#   'you re big .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es marrante .',
#   'you re fun .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es marrant .',
#   'you re fun .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es bizarre .',
#   'you re odd .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes bizarre .',
#   'you re odd .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes bizarres .',
#   'you re odd .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es vieux .',
#   'you re old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es vieille .',
#   'you re old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes vieux .',
#   'you re old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes vieilles .',
#   'you re old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes vieille .',
#   'you re old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es triste .',
#   'you re sad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes triste .',
#   'you re sad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es timide .',
#   'you re shy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes timide .',
#   'you re shy .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'il a huit ans .',
#   'he is eight .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est hai .',
#   'he is hated .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'il est mechant .',
#   'he is nasty .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il est jeune .',
#   'he is young .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'c est un beau mec .',
#   'he s a hunk .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'c est un beau gosse .',
#   'he s a hunk .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'c est un pauvre type .',
#   'he s a jerk .'],
#  ['cc by . france attribution tatoeba .org erikspen thuret ',
#   'c est un menteur .',
#   'he s a liar .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'c est un binoclard .',
#   'he s a nerd .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'c est un flemmard .',
#   'he s a slob .'],
#  ['cc by . france attribution tatoeba .org gulliver sacredceltic ',
#   'il est endormi .',
#   'he s asleep .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il arrive .',
#   'he s coming .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il est en train d arriver .',
#   'he s coming .'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'il simule .',
#   'he s faking .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'il est blinde .',
#   'he s loaded .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'il est pete de thune .',
#   'he s loaded .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'il est plein aux as .',
#   'he s loaded .'],
#  ['cc by . france attribution tatoeba .org yessoos sacredceltic ',
#   'il a mon age .',
#   'he s my age .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il n est pas chez lui .',
#   'he s not in .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il n est pas a l interieur .',
#   'he s not in .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il n est pas la .',
#   'he s not in .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'il est puissant .',
#   'he s strong .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis cuisinier .',
#   'i am a cook .'],
#  ['cc by . france attribution tatoeba .org nasirbal petrus ',
#   'je suis un moine .',
#   'i am a monk .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'j ai un jumeau .',
#   'i am a twin .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je vais mieux .',
#   'i am better .'],
#  ['cc by . france attribution tatoeba .org ck dafp ',
#   'je suis mieux .',
#   'i am better .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'j arrive .',
#   'i am coming .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis plus grand .',
#   'i am taller .'],
#  ['cc by . france attribution tatoeba .org papabear sacredceltic ',
#   'j ai egalement dix sept ans .',
#   'i m too .'],
#  ['cc by . france attribution tatoeba .org ck trang ',
#   'je suis boulanger .',
#   'i m a baker .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'je suis boulangere .',
#   'i m a baker .'],
#  ['cc by . france attribution tatoeba .org cm petrus ',
#   'je suis un enfant .',
#   'i m a child .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis toubib .',
#   'i m a medic .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis veuve .',
#   'i m a widow .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tout a fait pret .',
#   'i m all set .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tout a fait prete .',
#   'i m all set .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai honte .',
#   'i m ashamed .'],
#  ['cc by . france attribution tatoeba .org zipangu sacredceltic ',
#   'je suis a la maison .',
#   'i m at home .'],
#  ['cc by . france attribution tatoeba .org zipangu sacredceltic ',
#   'je suis dans la maison .',
#   'i m at home .'],
#  ['cc by . france attribution tatoeba .org ck cronos ',
#   'je suis au travail .',
#   'i m at work .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis perplexe .',
#   'i m baffled .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis confus .',
#   'i m baffled .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis confuse .',
#   'i m baffled .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis beni .',
#   'i m blessed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis benie .',
#   'i m blessed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis prudent .',
#   'i m careful .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis prudente .',
#   'i m careful .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sur .',
#   'i m certain .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis certain .',
#   'i m certain .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai les foies .',
#   'i m chicken .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai les chocottes .',
#   'i m chicken .'],
#  ['cc by . france attribution tatoeba .org ck gb ',
#   'je cuisine .',
#   'i m cooking .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai raison .',
#   'i m correct .'],
#  ['cc by . france attribution tatoeba .org ck tcha ',
#   'je suis curieux .',
#   'i m curious .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'je suis curieuse .',
#   'i m curious .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de danser .',
#   'i m dancing .'],
#  ['cc by . france attribution tatoeba .org ck archibald ',
#   'je suis au regime .',
#   'i m dieting .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de conduire .',
#   'i m driving .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je conduis .',
#   'i m driving .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis fiance .',
#   'i m engaged .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis fiancee .',
#   'i m engaged .'],
#  ['cc by . france attribution tatoeba .org ck lulantis ',
#   'je suis excite .',
#   'i m excited .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis excitee .',
#   'i m excited .'],
#  ['cc by . france attribution tatoeba .org cntrational wittydev ',
#   'je tombe .',
#   'i m falling .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je fais la diete .',
#   'i m fasting .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis a la diete .',
#   'i m fasting .'],
#  ['cc by . france attribution tatoeba .org ck franlexcois ',
#   'je suis meticuleux .',
#   'i m finicky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis meticuleuse .',
#   'i m finicky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis affole .',
#   'i m frantic .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis affolee .',
#   'i m frantic .'],
#  ['cc by . france attribution tatoeba .org ck khirthash ',
#   'je suis furieux .',
#   'i m furious .'],
#  ['cc by . france attribution tatoeba .org ck dominiko ',
#   'je suis en bonne sante .',
#   'i m healthy .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'je fredonne .',
#   'i m humming .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis amoureux .',
#   'i m in love .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis amoureuse .',
#   'i m in love .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis veinard .',
#   'i m in luck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis veinarde .',
#   'i m in luck .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'je suis jalouse .',
#   'i m jealous .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai la frousse .',
#   'i m jittery .'],
#  ['cc by . france attribution tatoeba .org ck qdii ',
#   'je plaisante .',
#   'i m kidding .'],
#  ['cc by . france attribution tatoeba .org ck gillux ',
#   'je rigole !',
#   'i m kidding .'],
#  ['cc by . france attribution tatoeba .org human sacredceltic ',
#   'je pars .',
#   'i m leaving .'],
#  ['cc by . france attribution tatoeba .org ck rtroisgr ',
#   'je suis marie .',
#   'i m married .'],
#  ['cc by . france attribution tatoeba .org ck elgranjuego ',
#   'je suis mariee .',
#   'i m married .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis nerveux .',
#   'i m nervous .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis nerveuse .',
#   'i m nervous .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis neutre .',
#   'i m neutral .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas idiot .',
#   'i m no fool .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas une idiote .',
#   'i m no fool .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas un heros .',
#   'i m no hero .'],
#  ['cc by . france attribution tatoeba .org scott sacredceltic ',
#   'je ne suis pas un menteur .',
#   'i m no liar .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je ne suis pas tom .',
#   'i m not tom .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas gros .',
#   'i m not fat .'],
#  ['cc by . france attribution tatoeba .org ck couarail ',
#   'je ne suis pas fou .',
#   'i m not mad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas folle .',
#   'i m not mad .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas vieux .',
#   'i m not old .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je ne suis pas vieille .',
#   'i m not old .'],
#  ['cc by . france attribution tatoeba .org ck nomadsoul ',
#   'je ne suis pas triste .',
#   'i m not sad .'],
#  ['cc by . france attribution tatoeba .org hybrid sacredceltic ',
#   'je ne suis pas timide .',
#   'i m not shy .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis en service .',
#   'i m on duty .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis patiente .',
#   'i m patient .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis patient .',
#   'i m patient .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis populaire .',
#   'i m popular .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis prudent .',
#   'i m prudent .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis remonte .',
#   'i m psyched .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis voyant .',
#   'i m psychic .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis voyante .',
#   'i m psychic .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis perplexe .',
#   'i m puzzled .'],
#  ['cc by . france attribution tatoeba .org sacredceltic korekorin ',
#   'je lis .',
#   'i m reading .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis detendu .',
#   'i m relaxed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis detendue .',
#   'i m relaxed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis retraite .',
#   'i m retired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis retraitee .',
#   'i m retired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis pensionne .',
#   'i m retired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis pensionnee .',
#   'i m retired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis egoiste .',
#   'i m selfish .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis serieux .',
#   'i m serious .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis choque .',
#   'i m shocked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis choquee .',
#   'i m shocked .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sincere .',
#   'i m sincere .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis bourre .',
#   'i m sloshed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis bourree .',
#   'i m sloshed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis fracasse !',
#   'i m smashed .'],
#  ['cc by . france attribution tatoeba .org cm scorpionvenin ',
#   'j ai tellement froid .',
#   'i m so cold .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis tellement rassasie .',
#   'i m so full .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis si heureux .',
#   'i m so glad .'],
#  ['cc by . france attribution tatoeba .org ck le petit ane gris ',
#   'je meurs de faim !',
#   'i m starved .'],
#  ['cc by . france attribution tatoeba .org ck hortusdei ',
#   'j ai l estomac dans les talons .',
#   'i m starved .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'j ai la dalle .',
#   'i m starved .'],
#  ['cc by . france attribution tatoeba .org ck sysko ',
#   'j ai les crocs .',
#   'i m starved .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je reste .',
#   'i m staying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis gave .',
#   'i m stuffed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis gavee .',
#   'i m stuffed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sidere .',
#   'i m stunned .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis sideree .',
#   'i m stunned .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis en train de discuter .',
#   'i m talking .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je taquine .',
#   'i m teasing .'],
#  ['cc by . france attribution tatoeba .org ck trang ',
#   'j ai soif .',
#   'i m thirsty .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en ai fini .',
#   'i m through .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j en ai termine .',
#   'i m through .'],
#  ['cc by . france attribution tatoeba .org jared despear ',
#   'je suis trop gros .',
#   'i m too fat .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis touche .',
#   'i m touched .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis touchee .',
#   'i m touched .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis piegee .',
#   'i m trapped .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'je suis piege .',
#   'i m trapped .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis desarme .',
#   'i m unarmed .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis mecontent .',
#   'i m unhappy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'je suis mecontente .',
#   'i m unhappy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'j ai la schcoumoune .',
#   'i m unlucky .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis un poissard .',
#   'i m unlucky .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'je suis malchanceux .',
# ...
#   'they re gone .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'il n y en a plus .',
#   'they re gone .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils sont bons .',
#   'they re good .'],
#  ['cc by . france attribution tatoeba .org ck sbamsbamsbam ',
#   'ils sont la .',
#   'they re here .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'elles sont paresseuses .',
#   'they re lazy .'],
#  ['cc by . france attribution tatoeba .org ck anthaus ',
#   'ils sont a moi .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ils sont miens .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ce sont les miens .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'ce sont les miennes .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'elles sont miennes .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'elles sont a moi .',
#   'they re mine .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils sont riches .',
#   'they re rich .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'elles sont riches .',
#   'they re rich .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils vont bien .',
#   'they re safe .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils sont en securite .',
#   'they re safe .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'elles sont en securite .',
#   'they re safe .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils sont laids .',
#   'they re ugly .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'ils sont moches .',
#   'they re ugly .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'ils sont faibles .',
#   'they re weak .'],
#  ['cc by . france attribution tatoeba .org ck aiji ',
#   'elles sont faibles .',
#   'they re weak .'],
#  ['cc by . france attribution tatoeba .org saeb chtof ',
#   'nous sommes arabes .',
#   'we are arabs .'],
#  ['cc by . france attribution tatoeba .org ck franzmimm ',
#   'nous sommes heureux .',
#   'we are happy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes une equipe .',
#   'we re a team .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes des adultes .',
#   'we re adults .'],
#  ['cc by . france attribution tatoeba .org ck wakano ',
#   'nous allons tous bien .',
#   'we re all ok .'],
#  ['cc by . france attribution tatoeba .org ck dreamk ',
#   'nous sommes en guerre .',
#   'we re at war .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'notre point de vue est biaise .',
#   'we re biased .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous avons des prejuges .',
#   'we re biased .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'nous achetons .',
#   'we re buying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes fermes .',
#   'we re closed .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'nous venons .',
#   'we re coming .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'on arrive .',
#   'we re coming .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sortons ensemble .',
#   'we re dating .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'nous sommes directs .',
#   'we re direct .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes condamnes .',
#   'we re doomed .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'nous sommes des heros .',
#   'we re heroes .'],
#  ['cc by . france attribution tatoeba .org ck rovo ',
#   'nous nous cachons .',
#   'we re hiding .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'nous sommes honnetes .',
#   'we re honest .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes a l interieur .',
#   'we re inside .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous plaisantons .',
#   'we re joking .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous perdons .',
#   'we re losing .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes en train de perdre .',
#   'we re losing .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'nous sommes matures .',
#   'we re mature .'],
#  ['cc by . france attribution tatoeba .org ck julien pdc ',
#   'nous sommes mineurs .',
#   'we re minors .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes en train de bouger .',
#   'we re moving .'],
#  ['cc by . france attribution tatoeba .org ck pititnatole ',
#   'nous sommes normaux .',
#   'we re normal .'],
#  ['cc by . france attribution tatoeba .org ck pititnatole ',
#   'nous sommes normales .',
#   'we re normal .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes en train de payer .',
#   'we re paying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes creves .',
#   'we re pooped .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes crevees .',
#   'we re pooped .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes ruines .',
#   'we re ruined .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes ruinees .',
#   'we re ruined .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes remues .',
#   'we re shaken .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes remuees .',
#   'we re shaken .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes sournois .',
#   'we re sneaky .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes sournoises .',
#   'we re sneaky .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'nous sommes stricts .',
#   'we re strict .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes forts .',
#   'we re strong .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'nous sommes fortes .',
#   'we re strong .'],
#  ['cc by . france attribution tatoeba .org ck franlexcois ',
#   'nous essayons .',
#   'we re trying .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'vous etes bon .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'vous etes bonne .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'vous etes bons .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'vous etes bonnes .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'tu es bon .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org cntrational sacredceltic ',
#   'tu es bonne .',
#   'you are good .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es en retard .',
#   'you are late .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes en retard .',
#   'you are late .'],
#  ['cc by . france attribution tatoeba .org saeb sacredceltic ',
#   'vous etes riches .',
#   'you are rich .'],
#  ['cc by . france attribution tatoeba .org ck blabla ',
#   'tu es un porc .',
#   'you re a pig .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es un egoiste .',
#   'you re a pig .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es une egoiste .',
#   'you re a pig .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu joues au chef .',
#   'you re bossy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu fais le chef .',
#   'you re bossy .'],
#  ['cc by . france attribution tatoeba .org alanf us qdii ',
#   'tu es fou .',
#   'you re crazy .'],
#  ['cc by . france attribution tatoeba .org alanf us hikari ',
#   'tu es cingle .',
#   'you re crazy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es cruelle .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es cruel .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes cruelle .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes cruelles .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes cruel .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes cruels .',
#   'you re cruel .'],
#  ['cc by . france attribution tatoeba .org ck gb ',
#   'tu es sale .',
#   'you re dirty .'],
#  ['cc by . france attribution tatoeba .org ck gb ',
#   'vous etes sale .',
#   'you re dirty .'],
#  ['cc by . france attribution tatoeba .org ck gb ',
#   'vous etes sales .',
#   'you re dirty .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es saoul .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es saoule .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes saouls .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes saoules .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes saoul .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes saoule .',
#   'you re drunk .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu viens tot .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes matinal .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes matinale .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es matinal .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es matinale .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es en avance .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes en avance .',
#   'you re early .'],
#  ['cc by . france attribution tatoeba .org ck trang ',
#   'tu es vire .',
#   'you re fired .'],
#  ['cc by . france attribution tatoeba .org ck rene ',
#   'tu es licencie .',
#   'you re fired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es en premier .',
#   'you re first .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu passes en premier .',
#   'you re first .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes en premier .',
#   'you re first .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es marrante .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es marrant .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes marrants .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes marrantes .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes marrant .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes marrante .',
#   'you re funny .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es difficile .',
#   'you re fussy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu fais des manieres .',
#   'you re fussy .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous faites des manieres .',
#   'you re fussy .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   't assures .',
#   'you re great .'],
#  ['cc by . france attribution tatoeba .org methodgt gillux ',
#   'tu es malpoli !',
#   'you re gross !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'tu mens !',
#   'you re lying !'],
#  ['cc by . france attribution tatoeba .org spamster sacredceltic ',
#   'vous mentez !',
#   'you re lying !'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous mentez .',
#   'you re lying .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es lunatique .',
#   'you re moody .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es naif .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es naive .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes naif .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes naive .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes naifs .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes naives .',
#   'you re naive .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es calme .',
#   'you re quiet .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es tranquille .',
#   'you re quiet .'],
#  ['cc by . france attribution tatoeba .org alkrasnov trang ',
#   'tu as raison .',
#   'you re right .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es idiot .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes idiot .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes idiote .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es idiote .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes idiots .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes idiotes .',
#   'you re silly .'],
#  ['cc by . france attribution tatoeba .org ck felix ',
#   'tu es intelligent .',
#   'you re smart .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es plante .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   't es plantee .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes plantes .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes plantees .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes plantee .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes plante .',
#   'you re stuck .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'tu es fatigue .',
#   'you re tired .'],
#  ['cc by . france attribution tatoeba .org ck micsmithel ',
#   'tu es fatiguee .',
#   'you re tired .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es dure .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es dur .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes dur .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes dure .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes durs .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'vous etes dures .',
#   'you re tough .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es contrariee .',
#   'you re upset .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es contrarie .',
#   'you re upset .'],
#  ['cc by . france attribution tatoeba .org ck sacredceltic ',
#   'tu es bizarre .',
#   'you re weird .'],
#  ...]

# %%
print("Trimmed to %s sentence pairs" % len(pairs))
# Out:
# Trimmed to 13996 sentence pairs

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {} # Dictionary to store a unique index per word which will indicate the index where 1 will be present in the OHE of that word
        self.word2count = {} # dictionary to store count of each word in the corpus which will be used to replace rare words with the most frequent words later
        self.index2word = {0: "SOS", 1: "EOS"} # inverse dictionary which already has two words SOS and EOS 
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

input_lang = Lang('eng')
output_lang = Lang('fra')

# %%
for pair in pairs:
  input_lang.addSentence(pair[0])
  output_lang.addSentence(pair[1])

# %%
print(input_lang.name)
print(input_lang.word2index)
print(input_lang.word2count)
print(input_lang.index2word)
print(input_lang.n_words)
# Out:
# eng
# {'cc': 2, 'by': 3, '.': 4, 'france': 5, 'attribution': 6, 'tatoeba': 7, '.org': 8, 'sacredceltic': 9, '': 10, 'ck': 11, 'anthaus': 12, 'christiane': 13, 'aiji': 14, 'cntrational': 15, 'nimfeo': 16, 'spamster': 17, 'sysko': 18, 'micsmithel': 19, 'cm': 20, 'darinmex': 21, 'qdii': 22, 'dreamk': 23, 'gillux': 24, 'joseph': 25, 'lukaszpp': 26, 'mamat': 27, 'yemana': 28, 'eldad': 29, 'zmoo': 30, 'pjer': 31, 'blabla': 32, 'vgigregg': 33, 'stevegrant': 34, 'saeb': 35, 'hennebert': 36, 'theachaean': 37, 'callmath': 38, 'rene': 39, 'languageexpert': 40, 'nomadsoul': 41, 'shishir': 42, 'adjusting': 43, 'sbgodin': 44, 'algideamygdale': 45, 'brauliobezerra': 46, 'le': 47, 'petit': 48, 'ane': 49, 'gris': 50, 'dj': 51, 'saidez': 52, 'papabear': 53, 'kebukebu': 54, 'feudrenais': 55, 'tras': 56, 'mouseneb': 57, 'vest': 58, 'dominiko': 59, 'amikema': 60, 'belgavox': 61, 'rovo': 62, 'firez': 63, 'julien': 64, 'pdc': 65, 'vortarulo': 66, 'baisong': 67, 'trang': 68, 'zifre': 69, 'lucasmg': 70, 'boscowitch': 71, 'trailsend': 72, 'cs': 73, 'minti': 74, 'zarisi': 75, 'erikspen': 76, 'thuret': 77, 'gulliver': 78, 'hybrid': 79, 'yessoos': 80, 'nasirbal': 81, 'petrus': 82, 'dafp': 83, 'zipangu': 84, 'cronos': 85, 'gb': 86, 'tcha': 87, 'archibald': 88, 'lulantis': 89, 'wittydev': 90, 'franlexcois': 91, 'khirthash': 92, 'human': 93, 'rtroisgr': 94, 'elgranjuego': 95, 'scott': 96, 'couarail': 97, 'korekorin': 98, 'scorpionvenin': 99, 'hortusdei': 100, 'jared': 101, 'despear': 102, 'jerom': 103, 'lbdx': 104, 'franzmimm': 105, 'j': 106, 's': 107, 'cocorico': 108, 'melospawn': 109, 'u': 110, 'fs': 111, 'source': 112, 'voa': 113, 'tinacalysto': 114, 'doremi': 115, 'sharaf': 116, 'al': 117, 'ex': 118, 'an': 119, 'der': 120, 'hrin': 121, 'sctld': 122, 'goofy': 123, 'kieranjpball': 124, 'chrikaru': 125, 'serhiy': 126, 'trotter': 127, 'sbamsbamsbam': 128, 'chtof': 129, 'wakano': 130, 'pititnatole': 131, 'alanf': 132, 'us': 133, 'hikari': 134, 'methodgt': 135, 'alkrasnov': 136, 'felix': 137, 'etoile': 138, 'weihaiping': 139, 'bruno': 140, 'dorenda': 141, 'neko': 142, 'guilmaeire': 143, 'witbrock': 144, 'sciuro': 145, 'donkirkby': 146, 'tamsanh': 147, 'cn': 148, 'sestersparrow': 149, 'zgarbas': 150, 'thrash': 151, 'slomox': 152, 'ahmes': 153, 'soj': 154, 'l': 155, 'jakov': 156, 'fleur': 157, 'apollineb': 158, 'clockworkbred': 159, 'apex': 160, 'martin': 161, 'undertoad': 162, 'laghmanc': 163, 'mookeee': 164, 'gall': 165, 'mouche': 166, 'ninuzzo': 167, 'ibnubachir': 168, 'whidou': 169, 'shekitten': 170, 'sibelius': 171, 'arlene': 172, 'michelnialon': 173, 'keira': 174, 'n': 175, 'alec': 176, 'miflhanc': 177, 'pierrephi': 178, 'barbiche': 179, 'blay': 180, 'paul': 181, 'niceguydave': 182, 'mailtotib': 183, 'fcbond': 184, 'rockaround': 185, 'popolon': 186, 'lindoula': 187, 'marloncori': 188, 'doemaar': 189, 'toynop': 190, 'quazel': 191, 'martinshadock': 192, 'geebee': 193, 'caspian': 194, 'swift': 195, 'slist': 196, 'geez': 197, 'osohombre': 198, 'megamanenm': 199, 'deerhound': 200, 'ramses': 201, 'malape': 202, 'jcgillet': 203, 'valodnieks': 204, 'asma': 205, 'lapinhibou': 206, 'aikidave': 207, 'amastan': 208, 'piksea': 209, 'martha': 210, 'gulo': 211, 'luscus': 212, 'bigmouse': 213, 'nbrr': 214, 'objectivesea': 215, 'suzie': 216, 'wallebot': 217, 'dejo': 218, 'stephenmac': 219, 'magnificentgoddess': 220, 'thomas': 221, 'b': 222, 'mikedee': 223, 'stomate': 224, 'juliemdm': 225, 'paiooooo': 226, 'carlosalberto': 227, 'tsar': 228, 'lyagushka': 229, 'salutlolo': 230, 'iamgrim': 231, 'mayliu': 232, 'dany': 233, 'pl': 234, 'ludoviko': 235, 'saasmath': 236, 'bravesentry': 237, 'fanty': 238, 'prophete': 239, 'delapouite': 240, 'ingenius': 241, 'rafieyan': 242, 'cruzedu': 243, 'dess': 244, 'rpietri': 245, 'andresevargas': 246, 'artfanster': 247, 'avoidingrealwork': 248, 'turnips': 249, 'maxence': 250, 'keder': 251, 'siggg': 252, 'raspakrusto': 253, 'shiawase': 254, 'theocracy': 255, 'eccles': 256, 'drnm': 257, 'kitanokuma': 258, 'oschwimmer': 259, 'thayne': 260, 'balamax': 26 ...
# {'cc': 14012, 'by': 13996, '.': 13996, 'france': 13996, 'attribution': 13996, 'tatoeba': 13996, '.org': 13996, 'sacredceltic': 7818, '': 13996, 'ck': 10034, 'anthaus': 15, 'christiane': 7, 'aiji': 2227, 'cntrational': 63, 'nimfeo': 204, 'spamster': 920, 'sysko': 157, 'micsmithel': 652, 'cm': 794, 'darinmex': 44, 'qdii': 96, 'dreamk': 86, 'gillux': 64, 'joseph': 6, 'lukaszpp': 36, 'mamat': 52, 'yemana': 94, 'eldad': 50, 'zmoo': 31, 'pjer': 1, 'blabla': 30, 'vgigregg': 2, 'stevegrant': 2, 'saeb': 19, 'hennebert': 1, 'theachaean': 10, 'callmath': 2, 'rene': 74, 'languageexpert': 9, 'nomadsoul': 12, 'shishir': 4, 'adjusting': 12, 'sbgodin': 5, 'algideamygdale': 4, 'brauliobezerra': 3, 'le': 10, 'petit': 10, 'ane': 10, 'gris': 10, 'dj': 14, 'saidez': 14, 'papabear': 24, 'kebukebu': 14, 'feudrenais': 38, 'tras': 33, 'mouseneb': 5, 'vest': 1, 'dominiko': 54, 'amikema': 1, 'belgavox': 65, 'rovo': 62, 'firez': 6, 'julien': 258, 'pdc': 258, 'vortarulo': 5, 'baisong': 1, 'trang': 130, 'zifre': 48, 'lucasmg': 1, 'boscowitch': 1, 'trailsend': 2, 'cs': 13, 'minti': 10, 'zarisi': 5, 'erikspen': 24, 'thuret': 3, 'gulliver': 5, 'hybrid': 494, 'yessoos': 1, 'nasirbal': 1, 'petrus': 20, 'dafp': 3, 'zipangu': 2, 'cronos': 5, 'gb': 217, 'tcha': 4, 'archibald': 49, 'lulantis': 30, 'wittydev': 12, 'franlexcois': 27, 'khirthash': 4, 'human': 3, 'rtroisgr': 3, 'elgranjuego': 9, 'scott': 111, 'couarail': 3, 'korekorin': 3, 'scorpionvenin': 134, 'hortusdei': 57, 'jared': 2, 'despear': 3, 'jerom': 23, 'lbdx': 127, 'franzmimm': 12, 'j': 3, 's': 3, 'cocorico': 58, 'melospawn': 12, 'u': 78, 'fs': 78, 'source': 25, 'voa': 24, 'tinacalysto': 1, 'doremi': 5, 'sharaf': 2, 'al': 4, 'ex': 4, 'an': 4, 'der': 4, 'hrin': 7, 'sctld': 8, 'goofy': 19, 'kieranjpball': 1, 'chrikaru': 9, 'serhiy': 2, 'trotter': 6, 'sbamsbamsbam': 11, 'chtof': 15, 'wakano': 20, 'pititnatole': 51, 'alanf': 137, 'us': 137, 'hikari': 11, 'methodgt': 6, 'alkrasnov': 1, 'felix': 70, 'etoile': 7, 'weihaiping': 5, 'bruno': 23, 'dorenda': 2, 'neko': 2, 'guilmaeire': 1, 'witbrock': 9, 'sciuro': 5, 'donkirkby': 5, 'tamsanh': 3, 'cn': 2, 'sestersparrow': 3, 'zgarbas': 2, 'thrash': 1, 'slomox': 2, 'ahmes': 1, 'soj': 1, 'l': 1, 'jakov': 2, 'fleur': 3, 'apollineb': 1, 'clockworkbred': 1, 'apex': 12, 'martin': 28, 'undertoad': 36, 'laghmanc': 2, 'mookeee': 7, 'gall': 8, 'mouche': 16, 'ninuzzo': 1, 'ibnubachir': 1, 'whidou': 12, 'shekitten': 35, 'sibelius': 12, 'arlene': 1, 'michelnialon': 6, 'keira': 7, 'n': 8, 'alec': 3, 'miflhanc': 1, 'pierrephi': 10, 'barbiche': 26, 'blay': 34, 'paul': 34, 'niceguydave': 6, 'mailtotib': 1, 'fcbond': 3, 'rockaround': 35, 'popolon': 21, 'lindoula': 3, 'marloncori': 15, 'doemaar': 1, 'toynop': 34, 'quazel': 10, 'martinshadock': 6, 'geebee': 1, 'caspian': 1, 'swift': 19, 'slist': 6, 'geez': 20, 'osohombre': 11, 'megamanenm': 6, 'deerhound': 2, 'ramses': 4, 'malape': 4, 'jcgillet': 1, 'valodnieks': 1, 'asma': 2, 'lapinhibou': 3, 'aikidave': 2, 'amastan': 33, 'piksea': 16, 'martha': 1, 'gulo': 1, 'luscus': 1, 'bigmouse': 1, 'nbrr': 1, 'objectivesea': 2, 'suzie': 13, 'wallebot': 3, 'dejo': 15, 'stephenmac': 1, 'magnificentgoddess': 1, 'thomas': 1, 'b': 1, 'mikedee': 1, 'stomate': 2, 'juliemdm': 4, 'paiooooo': 6, 'carlosalberto': 1, 'tsar': 2, 'lyagushka': 2, 'salutlolo': 6, 'iamgrim': 6, 'mayliu': 8, 'dany': 1, 'pl': 1, 'ludoviko': 1, 'saasmath': 4, 'bravesentry': 1, 'fanty': 9, 'prophete': 1, 'delapouite': 6, 'ingenius': 1, 'rafieyan': 1, 'cruzedu': 2, 'dess': 4, 'rpietri': 4, 'andresevargas': 1, 'artfanster': 1, 'avoidingrealwork': 1, 'turnips': 1, 'maxence': 7, 'keder': 8, 'siggg': 2, 'raspakrusto': 15, 'shiawase': 11, 'theocracy': 4, 'eccles': 13, 'drnm': 1, 'kitanokuma': 4, 'oschwimmer': 3, 'thayne': 2, 'balamax': 3, 'kurisutofu': 3, 'halfb': 8, 't': 8, 'toutanmemtan': 2, 'adlerq': 4, 'dawnbreaksopen': 5, 'romira': 22, 'daga': 5, 'thowas': 4, 'duck': 1, 'fabimoto': 3, 'bourdu': 9, 'rike': 1, 'themiska': 1, 'sulijen': 1, 'ceriz': 4, 'popball': 2, 'vulgaris': 1, 'jaxhere' ...
# {0: 'SOS', 1: 'EOS', 2: 'cc', 3: 'by', 4: '.', 5: 'france', 6: 'attribution', 7: 'tatoeba', 8: '.org', 9: 'sacredceltic', 10: '', 11: 'ck', 12: 'anthaus', 13: 'christiane', 14: 'aiji', 15: 'cntrational', 16: 'nimfeo', 17: 'spamster', 18: 'sysko', 19: 'micsmithel', 20: 'cm', 21: 'darinmex', 22: 'qdii', 23: 'dreamk', 24: 'gillux', 25: 'joseph', 26: 'lukaszpp', 27: 'mamat', 28: 'yemana', 29: 'eldad', 30: 'zmoo', 31: 'pjer', 32: 'blabla', 33: 'vgigregg', 34: 'stevegrant', 35: 'saeb', 36: 'hennebert', 37: 'theachaean', 38: 'callmath', 39: 'rene', 40: 'languageexpert', 41: 'nomadsoul', 42: 'shishir', 43: 'adjusting', 44: 'sbgodin', 45: 'algideamygdale', 46: 'brauliobezerra', 47: 'le', 48: 'petit', 49: 'ane', 50: 'gris', 51: 'dj', 52: 'saidez', 53: 'papabear', 54: 'kebukebu', 55: 'feudrenais', 56: 'tras', 57: 'mouseneb', 58: 'vest', 59: 'dominiko', 60: 'amikema', 61: 'belgavox', 62: 'rovo', 63: 'firez', 64: 'julien', 65: 'pdc', 66: 'vortarulo', 67: 'baisong', 68: 'trang', 69: 'zifre', 70: 'lucasmg', 71: 'boscowitch', 72: 'trailsend', 73: 'cs', 74: 'minti', 75: 'zarisi', 76: 'erikspen', 77: 'thuret', 78: 'gulliver', 79: 'hybrid', 80: 'yessoos', 81: 'nasirbal', 82: 'petrus', 83: 'dafp', 84: 'zipangu', 85: 'cronos', 86: 'gb', 87: 'tcha', 88: 'archibald', 89: 'lulantis', 90: 'wittydev', 91: 'franlexcois', 92: 'khirthash', 93: 'human', 94: 'rtroisgr', 95: 'elgranjuego', 96: 'scott', 97: 'couarail', 98: 'korekorin', 99: 'scorpionvenin', 100: 'hortusdei', 101: 'jared', 102: 'despear', 103: 'jerom', 104: 'lbdx', 105: 'franzmimm', 106: 'j', 107: 's', 108: 'cocorico', 109: 'melospawn', 110: 'u', 111: 'fs', 112: 'source', 113: 'voa', 114: 'tinacalysto', 115: 'doremi', 116: 'sharaf', 117: 'al', 118: 'ex', 119: 'an', 120: 'der', 121: 'hrin', 122: 'sctld', 123: 'goofy', 124: 'kieranjpball', 125: 'chrikaru', 126: 'serhiy', 127: 'trotter', 128: 'sbamsbamsbam', 129: 'chtof', 130: 'wakano', 131: 'pititnatole', 132: 'alanf', 133: 'us', 134: 'hikari', 135: 'methodgt', 136: 'alkrasnov', 137: 'felix', 138: 'etoile', 139: 'weihaiping', 140: 'bruno', 141: 'dorenda', 142: 'neko', 143: 'guilmaeire', 144: 'witbrock', 145: 'sciuro', 146: 'donkirkby', 147: 'tamsanh', 148: 'cn', 149: 'sestersparrow', 150: 'zgarbas', 151: 'thrash', 152: 'slomox', 153: 'ahmes', 154: 'soj', 155: 'l', 156: 'jakov', 157: 'fleur', 158: 'apollineb', 159: 'clockworkbred', 160: 'apex', 161: 'martin', 162: 'undertoad', 163: 'laghmanc', 164: 'mookeee', 165: 'gall', 166: 'mouche', 167: 'ninuzzo', 168: 'ibnubachir', 169: 'whidou', 170: 'shekitten', 171: 'sibelius', 172: 'arlene', 173: 'michelnialon', 174: 'keira', 175: 'n', 176: 'alec', 177: 'miflhanc', 178: 'pierrephi', 179: 'barbiche', 180: 'blay', 181: 'paul', 182: 'niceguydave', 183: 'mailtotib', 184: 'fcbond', 185: 'rockaround', 186: 'popolon', 187: 'lindoula', 188: 'marloncori', 189: 'doemaar', 190: 'toynop', 191: 'quazel', 192: 'martinshadock', 193: 'geebee', 194: 'caspian', 195: 'swift', 196: 'slist', 197: 'geez', 198: 'osohombre', 199: 'megamanenm', 200: 'deerhound', 201: 'ramses', 202: 'malape', 203: 'jcgillet', 204: 'valodnieks', 205: 'asma', 206: 'lapinhibou', 207: 'aikidave', 208: 'amastan', 209: 'piksea', 210: 'martha', 211: 'gulo', 212: 'luscus', 213: 'bigmouse', 214: 'nbrr', 215: 'objectivesea', 216: 'suzie', 217: 'wallebot', 218: 'dejo', 219: 'stephenmac', 220: 'magnificentgoddess', 221: 'thomas', 222: 'b', 223: 'mikedee', 224: 'stomate', 225: 'juliemdm', 226: 'paiooooo', 227: 'carlosalberto', 228: 'tsar', 229: 'lyagushka', 230: 'salutlolo', 231: 'iamgrim', 232: 'mayliu', 233: 'dany', 234: 'pl', 235: 'ludoviko', 236: 'saasmath', 237: 'bravesentry', 238: 'fanty', 239: 'prophete', 240: 'delapouite', 241: 'ingenius', 242: 'rafieyan', 243: 'cruzedu', 244: 'dess', 245: 'rpietri', 246: 'andresevargas', 247: 'artfanster', 248: 'avoidingrealwork', 249: 'turnips', 250: 'maxence', 251: 'keder', 252: 'siggg', 253: 'raspakrusto', 254: 'shiawase', 255: 'theocracy', 256: 'eccles', 257: 'drnm', 258: 'kitanokuma', 259: 'oschwimmer', 260: 'th ...
# 571

# %%
print(output_lang.name)
print(output_lang.word2index)
print(output_lang.word2count)
print(output_lang.index2word)
print(output_lang.n_words)
# Out:
# fra
# {'j': 2, 'ai': 3, 'ans': 4, '.': 5, 'je': 6, 'vais': 7, 'bien': 8, 'ca': 9, 'va': 10, 'suis': 11, 'tom': 12, 'gras': 13, 'gros': 14, 'en': 15, 'forme': 16, 'touche': 17, '!': 18, 'touchee': 19, 'malade': 20, 'triste': 21, 'un': 22, 'coup': 23, 'de': 24, 'cafard': 25, 'malheureux': 26, 'timide': 27, 'mouille': 28, 'mouillee': 29, 'il': 30, 'est': 31, 'revenu': 32, 'me': 33, 'revoila': 34, 'chauve': 35, 'occupe': 36, 'occupee': 37, 'calme': 38, 'froid': 39, 'detendu': 40, 'detendue': 41, 'sourd': 42, 'sourde': 43, 'fini': 44, 'juste': 45, 'la': 46, 'peau': 47, 'claire': 48, 'le': 49, 'teint': 50, 'clair': 51, 'rapide': 52, 'tout': 53, 'libre': 54, 'disponible': 55, 'repu': 56, 'rassasie': 57, 'partie': 58, 'content': 59, 'chez': 60, 'moi': 61, 'retard': 62, 'paresseux': 63, 'faineant': 64, 'paresseuse': 65, 'faineante': 66, 'paume': 67, 'perdue': 68, 'porte': 69, 'riche': 70, 'securite': 71, 'certain': 72, 'sur': 73, 'sure': 74, 'grande': 75, 'mince': 76, 'ordonne': 77, 'ordonnee': 78, 'laid': 79, 'laide': 80, 'faible': 81, 'nous': 82, 'allons': 83, 'vieux': 84, 'dj': 85, 'bon': 86, 'a': 87, 'sexy': 88, 'ici': 89, 'flic': 90, 'homme': 91, 'vie': 92, 'vivant': 93, 'vivante': 94, 'seule': 95, 'seul': 96, 'enerve': 97, 'colere': 98, 'arme': 99, 'armee': 100, 'reveille': 101, 'aveugle': 102, 'courageux': 103, 'courageuse': 104, 'brave': 105, 'fauche': 106, 'decroche': 107, 'propre': 108, 'fou': 109, 'folle': 110, 'gueri': 111, 'guerie': 112, 'sale': 113, 'tete': 114, 'qui': 115, 'tourne': 116, 'saoul': 117, 'soul': 118, 'ivre': 119, 'meurs': 120, 'avance': 121, 'premier': 122, 'difficile': 123, 'tatillon': 124, 'tatillonne': 125, 'pars': 126, 'maintenant': 127, 'tire': 128, 'y': 129, 'loyal': 130, 'loyale': 131, 'veinard': 132, 'veinarde': 133, 'du': 134, 'pot': 135, 'chanceux': 136, 'chanceuse': 137, 'train': 138, 'mentir': 139, 'nu': 140, 'nue': 141, 'trouve': 142, 'poil': 143, 'dans': 144, 'besoin': 145, 'tranquille': 146, 'prete': 147, 'pret': 148, 'raison': 149, 'petite': 150, 'sobre': 151, 'excuse': 152, 'desole': 153, 'excusez': 154, 'desolee': 155, 'coincee': 156, 'fatigue': 157, 'dur': 158, 'dure': 159, 'cuire': 160, 'toi': 161, 'vous': 162, 'elle': 163, 'chaude': 164, 'tres': 165, 'attirante': 166, 'avons': 167, 'chaud': 168, 'sommes': 169, 'tristes': 170, 'timides': 171, 'tu': 172, 'vas': 173, 'chat': 174, 'faire': 175, 'gentil': 176, 'pauvre': 177, 'suisse': 178, 'helvete': 179, 'ruine': 180, 'intelligent': 181, 'humain': 182, 'une': 183, 'fille': 184, 'heros': 185, 'menteur': 186, 'jumeau': 187, 'amuse': 188, 'amusee': 189, 'm': 190, 'cuis': 191, 'mieux': 192, 'parti': 193, 'pris': 194, 'paie': 195, 'c': 196, 'grassouillet': 197, 'grassouillette': 198, 'arrive': 199, 'direct': 200, 'directe': 201, 'mange': 202, 'connu': 203, 'connue': 204, 'plus': 205, 'flasque': 206, 'cupide': 207, 'gourmand': 208, 'gourmande': 209, 'cache': 210, 'honnete': 211, 'humble': 212, 'faim': 213, 'immunise': 214, 'immunisee': 215, 'au': 216, 'lit': 217, 'alite': 218, 'alitee': 219, 'l': 220, 'interieur': 221, 'rigole': 222, 'sens': 223, 'perdre': 224, 'demenager': 225, 'normal': 226, 'normale': 227, 'payer': 228, 'creve': 229, 'repose': 230, 'reposee': 231, 'ruinee': 232, 'remue': 233, 'remuee': 234, 'celibataire': 235, 'maigrichon': 236, 'maigrichonne': 237, 'sommeil': 238, 'sournois': 239, 'sournoise': 240, 'tellement': 241, 'grosse': 242, 'trempee': 243, 'strict': 244, 'stricte': 245, 'fort': 246, 'forte': 247, 'trente': 248, 'essaye': 249, 'essaie': 250, 'affaiblie': 251, 'vieille': 252, 'gentille': 253, 'des': 254, 'hommes': 255, 'retour': 256, 'garcons': 257, 'occupes': 258, 'occupees': 259, 'calmes': 260, 'termine': 261, 'quittes': 262, 'egalite': 263, 'faineantes': 264, 'perdus': 265, 'perdues': 266, 'riches': 267, 'on': 268, 'foutu': 269, 'foutus': 270, 'faibles': 271, 'es': 272, 'vilain': 273, 'grand': 274, 'etes': 275, 'grands': 276, 'grandes': 277, 't': 278, 'marrante': 279, 'marrant': 280, 'bizarre': 281, 'bizarres': 282, 'vieill ...
# {'j': 623, 'ai': 453, 'ans': 72, '.': 13608, 'je': 5180, 'vais': 414, 'bien': 147, 'ca': 227, 'va': 74, 'suis': 3589, 'tom': 202, 'gras': 5, 'gros': 24, 'en': 1060, 'forme': 23, 'touche': 3, '!': 215, 'touchee': 2, 'malade': 41, 'triste': 16, 'un': 1069, 'coup': 12, 'de': 1952, 'cafard': 1, 'malheureux': 6, 'timide': 25, 'mouille': 2, 'mouillee': 2, 'il': 1434, 'est': 2033, 'revenu': 2, 'me': 337, 'revoila': 1, 'chauve': 3, 'occupe': 65, 'occupee': 47, 'calme': 6, 'froid': 23, 'detendu': 2, 'detendue': 3, 'sourd': 3, 'sourde': 4, 'fini': 59, 'juste': 89, 'la': 750, 'peau': 2, 'claire': 1, 'le': 634, 'teint': 1, 'clair': 1, 'rapide': 18, 'tout': 201, 'libre': 25, 'disponible': 8, 'repu': 1, 'rassasie': 3, 'partie': 46, 'content': 89, 'chez': 78, 'moi': 284, 'retard': 64, 'paresseux': 13, 'faineant': 3, 'paresseuse': 4, 'faineante': 2, 'paume': 2, 'perdue': 4, 'porte': 37, 'riche': 29, 'securite': 49, 'certain': 37, 'sur': 231, 'sure': 58, 'grande': 46, 'mince': 8, 'ordonne': 4, 'ordonnee': 3, 'laid': 4, 'laide': 2, 'faible': 9, 'nous': 1591, 'allons': 103, 'vieux': 81, 'dj': 2, 'bon': 151, 'a': 1168, 'sexy': 1, 'ici': 231, 'flic': 3, 'homme': 72, 'vie': 29, 'vivant': 8, 'vivante': 4, 'seule': 40, 'seul': 50, 'enerve': 2, 'colere': 47, 'arme': 4, 'armee': 4, 'reveille': 2, 'aveugle': 9, 'courageux': 13, 'courageuse': 10, 'brave': 8, 'fauche': 3, 'decroche': 1, 'propre': 12, 'fou': 31, 'folle': 9, 'gueri': 1, 'guerie': 1, 'sale': 8, 'tete': 14, 'qui': 92, 'tourne': 7, 'saoul': 11, 'soul': 1, 'ivre': 8, 'meurs': 5, 'avance': 12, 'premier': 12, 'difficile': 23, 'tatillon': 3, 'tatillonne': 3, 'pars': 24, 'maintenant': 115, 'tire': 7, 'y': 131, 'loyal': 1, 'loyale': 1, 'veinard': 5, 'veinarde': 4, 'du': 227, 'pot': 2, 'chanceux': 20, 'chanceuse': 13, 'train': 197, 'mentir': 16, 'nu': 2, 'nue': 2, 'trouve': 24, 'poil': 1, 'dans': 178, 'besoin': 26, 'tranquille': 4, 'prete': 31, 'pret': 65, 'raison': 66, 'petite': 16, 'sobre': 1, 'excuse': 4, 'desole': 133, 'excusez': 4, 'desolee': 87, 'coincee': 4, 'fatigue': 101, 'dur': 24, 'dure': 10, 'cuire': 4, 'toi': 223, 'vous': 2342, 'elle': 688, 'chaude': 3, 'tres': 650, 'attirante': 10, 'avons': 80, 'chaud': 4, 'sommes': 920, 'tristes': 1, 'timides': 4, 'tu': 1593, 'vas': 37, 'chat': 2, 'faire': 193, 'gentil': 21, 'pauvre': 15, 'suisse': 1, 'helvete': 1, 'ruine': 2, 'intelligent': 36, 'humain': 1, 'une': 519, 'fille': 65, 'heros': 13, 'menteur': 27, 'jumeau': 2, 'amuse': 10, 'amusee': 1, 'm': 174, 'cuis': 2, 'mieux': 37, 'parti': 9, 'pris': 7, 'paie': 4, 'c': 529, 'grassouillet': 1, 'grassouillette': 1, 'arrive': 14, 'direct': 4, 'directe': 5, 'mange': 13, 'connu': 10, 'connue': 7, 'plus': 407, 'flasque': 1, 'cupide': 2, 'gourmand': 1, 'gourmande': 1, 'cache': 5, 'honnete': 13, 'humble': 3, 'faim': 61, 'immunise': 1, 'immunisee': 1, 'au': 156, 'lit': 13, 'alite': 2, 'alitee': 1, 'l': 432, 'interieur': 10, 'rigole': 3, 'sens': 40, 'perdre': 31, 'demenager': 4, 'normal': 14, 'normale': 9, 'payer': 5, 'creve': 8, 'repose': 1, 'reposee': 1, 'ruinee': 1, 'remue': 1, 'remuee': 1, 'celibataire': 14, 'maigrichon': 6, 'maigrichonne': 6, 'sommeil': 23, 'sournois': 4, 'sournoise': 3, 'tellement': 94, 'grosse': 9, 'trempee': 2, 'strict': 2, 'stricte': 2, 'fort': 190, 'forte': 14, 'trente': 16, 'essaye': 34, 'essaie': 25, 'affaiblie': 1, 'vieille': 35, 'gentille': 22, 'des': 377, 'hommes': 3, 'retour': 9, 'garcons': 3, 'occupes': 18, 'occupees': 11, 'calmes': 4, 'termine': 33, 'quittes': 1, 'egalite': 1, 'faineantes': 1, 'perdus': 2, 'perdues': 2, 'riches': 12, 'on': 126, 'foutu': 1, 'foutus': 1, 'faibles': 5, 'es': 1253, 'vilain': 3, 'grand': 90, 'etes': 1486, 'grands': 11, 'grandes': 9, 't': 177, 'marrante': 6, 'marrant': 10, 'bizarre': 11, 'bizarres': 3, 'vieilles': 7, 'huit': 7, 'hai': 1, 'mechant': 10, 'jeune': 79, 'beau': 20, 'mec': 13, 'gosse': 1, 'type': 16, 'binoclard': 2, 'flemmard': 2, 'endormi': 8, 'd': 481, 'arriver': 7, 'simule': 1, 'blinde': 1, 'pete': 2, 'thune': 2, 'plein': 23, 'aux': 58 ...
# {0: 'SOS', 1: 'EOS', 2: 'j', 3: 'ai', 4: 'ans', 5: '.', 6: 'je', 7: 'vais', 8: 'bien', 9: 'ca', 10: 'va', 11: 'suis', 12: 'tom', 13: 'gras', 14: 'gros', 15: 'en', 16: 'forme', 17: 'touche', 18: '!', 19: 'touchee', 20: 'malade', 21: 'triste', 22: 'un', 23: 'coup', 24: 'de', 25: 'cafard', 26: 'malheureux', 27: 'timide', 28: 'mouille', 29: 'mouillee', 30: 'il', 31: 'est', 32: 'revenu', 33: 'me', 34: 'revoila', 35: 'chauve', 36: 'occupe', 37: 'occupee', 38: 'calme', 39: 'froid', 40: 'detendu', 41: 'detendue', 42: 'sourd', 43: 'sourde', 44: 'fini', 45: 'juste', 46: 'la', 47: 'peau', 48: 'claire', 49: 'le', 50: 'teint', 51: 'clair', 52: 'rapide', 53: 'tout', 54: 'libre', 55: 'disponible', 56: 'repu', 57: 'rassasie', 58: 'partie', 59: 'content', 60: 'chez', 61: 'moi', 62: 'retard', 63: 'paresseux', 64: 'faineant', 65: 'paresseuse', 66: 'faineante', 67: 'paume', 68: 'perdue', 69: 'porte', 70: 'riche', 71: 'securite', 72: 'certain', 73: 'sur', 74: 'sure', 75: 'grande', 76: 'mince', 77: 'ordonne', 78: 'ordonnee', 79: 'laid', 80: 'laide', 81: 'faible', 82: 'nous', 83: 'allons', 84: 'vieux', 85: 'dj', 86: 'bon', 87: 'a', 88: 'sexy', 89: 'ici', 90: 'flic', 91: 'homme', 92: 'vie', 93: 'vivant', 94: 'vivante', 95: 'seule', 96: 'seul', 97: 'enerve', 98: 'colere', 99: 'arme', 100: 'armee', 101: 'reveille', 102: 'aveugle', 103: 'courageux', 104: 'courageuse', 105: 'brave', 106: 'fauche', 107: 'decroche', 108: 'propre', 109: 'fou', 110: 'folle', 111: 'gueri', 112: 'guerie', 113: 'sale', 114: 'tete', 115: 'qui', 116: 'tourne', 117: 'saoul', 118: 'soul', 119: 'ivre', 120: 'meurs', 121: 'avance', 122: 'premier', 123: 'difficile', 124: 'tatillon', 125: 'tatillonne', 126: 'pars', 127: 'maintenant', 128: 'tire', 129: 'y', 130: 'loyal', 131: 'loyale', 132: 'veinard', 133: 'veinarde', 134: 'du', 135: 'pot', 136: 'chanceux', 137: 'chanceuse', 138: 'train', 139: 'mentir', 140: 'nu', 141: 'nue', 142: 'trouve', 143: 'poil', 144: 'dans', 145: 'besoin', 146: 'tranquille', 147: 'prete', 148: 'pret', 149: 'raison', 150: 'petite', 151: 'sobre', 152: 'excuse', 153: 'desole', 154: 'excusez', 155: 'desolee', 156: 'coincee', 157: 'fatigue', 158: 'dur', 159: 'dure', 160: 'cuire', 161: 'toi', 162: 'vous', 163: 'elle', 164: 'chaude', 165: 'tres', 166: 'attirante', 167: 'avons', 168: 'chaud', 169: 'sommes', 170: 'tristes', 171: 'timides', 172: 'tu', 173: 'vas', 174: 'chat', 175: 'faire', 176: 'gentil', 177: 'pauvre', 178: 'suisse', 179: 'helvete', 180: 'ruine', 181: 'intelligent', 182: 'humain', 183: 'une', 184: 'fille', 185: 'heros', 186: 'menteur', 187: 'jumeau', 188: 'amuse', 189: 'amusee', 190: 'm', 191: 'cuis', 192: 'mieux', 193: 'parti', 194: 'pris', 195: 'paie', 196: 'c', 197: 'grassouillet', 198: 'grassouillette', 199: 'arrive', 200: 'direct', 201: 'directe', 202: 'mange', 203: 'connu', 204: 'connue', 205: 'plus', 206: 'flasque', 207: 'cupide', 208: 'gourmand', 209: 'gourmande', 210: 'cache', 211: 'honnete', 212: 'humble', 213: 'faim', 214: 'immunise', 215: 'immunisee', 216: 'au', 217: 'lit', 218: 'alite', 219: 'alitee', 220: 'l', 221: 'interieur', 222: 'rigole', 223: 'sens', 224: 'perdre', 225: 'demenager', 226: 'normal', 227: 'normale', 228: 'payer', 229: 'creve', 230: 'repose', 231: 'reposee', 232: 'ruinee', 233: 'remue', 234: 'remuee', 235: 'celibataire', 236: 'maigrichon', 237: 'maigrichonne', 238: 'sommeil', 239: 'sournois', 240: 'sournoise', 241: 'tellement', 242: 'grosse', 243: 'trempee', 244: 'strict', 245: 'stricte', 246: 'fort', 247: 'forte', 248: 'trente', 249: 'essaye', 250: 'essaie', 251: 'affaiblie', 252: 'vieille', 253: 'gentille', 254: 'des', 255: 'hommes', 256: 'retour', 257: 'garcons', 258: 'occupes', 259: 'occupees', 260: 'calmes', 261: 'termine', 262: 'quittes', 263: 'egalite', 264: 'faineantes', 265: 'perdus', 266: 'perdues', 267: 'riches', 268: 'on', 269: 'foutu', 270: 'foutus', 271: 'faibles', 272: 'es', 273: 'vilain', 274: 'grand', 275: 'etes', 276: 'grands', 277: 'grandes', 278: 't', 279: 'marrante', 280: 'marrant', 281: 'bizarre', 282: ...
# 5033

# %%
'''
 -----------------------------------------------Preparing Training Data----------------------------------------
To train, for each pair we will need an input tensor (indexes of the words in the input sentence) and target tensor (indexes of the words in
the target sentence). While creating these vectors we will append the EOS token to both sequences.
'''

def indexesFromSentence(lang, sentence):
  return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
  indexes = indexesFromSentence(lang, sentence)
  indexes.append(EOS_token)
  return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
  input_tensor = tensorFromSentence(input_lang, pair[0])
  target_tensor = tensorFromSentence(output_lang, pair[1])
  return (input_tensor, target_tensor)

# %% [markdown]
# **Modelling, Training and Prediction**
# =================

# %% [markdown]
# ## **Defining Seq2Seq Model**

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Encoder

# %%
class EncoderRNN(nn.Module):
  def __init__(self, input_size, hidden_size):
    super(EncoderRNN, self).__init__()

    #initializing parameters
    self.input_size = input_size
    self.hidden_size = hidden_size

    #initializing layers

    #input layer
    self.embedding = nn.Embedding(input_size, hidden_size)

    #single hidden layer of Gated RNN
    self.gru = nn.GRU(hidden_size, hidden_size)
    # use this is you want to use stacked Gated RNN instead of just a single Gated RNN layer
    #self.gru = nn.GRU(hidden_size, hidden_size, n_layers) 

    # no output layer

  def forward(self, input, hidden):
    embedded = self.embedding(input).view(1, 1, -1)
    output = embedded
    output, hidden = self.gru(output, hidden)
    return output, hidden

  def initHidden(self):
    return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ### Decoder

# %% [markdown]
# #### M1 - Decoder without attention

# %%
'''
----------------------------------------- Simple Decoder ------------------------------------
In this decoder we use only last output of the encoder as the context vector.
This context vector is used as the initial hidden state of the decoder.

At every step of decoding, the decoder is given an input token and
hidden state. The initial input token is the start-of-string ``<SOS>``
token, and the first hidden state is the context vector (the encoder's
last hidden state).
'''

class DecoderRNN(nn.Module):
  def __init__(self, hidden_size, output_size):
    super(DecoderRNN, self).__init__()
    self.hidden_size = hidden_size

    #input layer
    self.embedding = nn.Embedding(output_size, hidden_size)

    # Single hidden layer of Gated RNN
    self.gru = nn.GRU(hidden_size, hidden_size)
        
    #output layer
    self.out = nn.Linear(hidden_size, output_size)  # adding the optional linear layer - refer RNN in timeseries notes for more details
    self.softmax = nn.LogSoftmax(dim=1) # adding the optional softmax layer - refer RNN in timeseries notes for more details

  def forward(self, input, hidden):
    output = self.embedding(input).view(1, 1, -1)
    output = F.relu(output)
    output, hidden = self.gru(output, hidden)
    output = self.softmax(self.out(output[0]))
    return output, hidden

  def initHidden(self):
    return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# #### M2 - Decoder with attention

# %%
'''
------------------------------------------------------Attention Decoder---------------------------------------

Instead of using a simple decoder as defined above, we want to use the attention mechanism 

If only the context vector is passed between the encoder and decoder,that single vector carries the burden of encoding the entire sentence.
Attention allows the decoder network to "focus" on a different part of the encoder's outputs for every step of the decoder's own outputs. First
we calculate a set of *attention weights*. These will be multiplied by the encoder output vectors to create a weighted combination. The result
(called ``attn_applied`` in the code) should contain information about that specific part of the input sequence, and thus help the decoder
choose the right output words.

Calculating the attention weights is done with another feed-forward layer ``attn``, using the decoder's input and hidden state as inputs.
Because there are sentences of all sizes in the training data, to actually create and train this layer we have to choose a maximum
sentence length (input length, for encoder outputs) that it can apply to. Sentences of the maximum length will use all the attention weights,
while shorter sentences will only use the first few.
'''

class AttnDecoderRNN(nn.Module):
  def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
    super(AttnDecoderRNN, self).__init__()
        
    # Define parameters
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.dropout_p = dropout_p
    self.max_length = max_length

    # Define layers

    #input layer
    self.embedding = nn.Embedding(self.output_size, self.hidden_size)

    # attention layer
    self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
    self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
    self.dropout = nn.Dropout(self.dropout_p)

    # single hidden layer of Gated RNN
    self.gru = nn.GRU(self.hidden_size, self.hidden_size)

    # output layer
    self.out = nn.Linear(self.hidden_size, self.output_size)

  def forward(self, input, hidden, encoder_outputs):
    # Note: we run this one step at a time

    # Get the embedding of the current input word (last output word)
    embedded = self.embedding(input).view(1, 1, -1)
    embedded = self.dropout(embedded)
        
    # Calculate attention from current RNN state and all encoder outputs; apply to encoder outputs
    attn_weights = F.softmax(self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
    attn_applied = torch.bmm(attn_weights.unsqueeze(0),encoder_outputs.unsqueeze(0))
        
    # Combine embedded input word and last context, run through RNN
    output = torch.cat((embedded[0], attn_applied[0]), 1)
    output = self.attn_combine(output).unsqueeze(0)

    output = F.relu(output)
    output, hidden = self.gru(output, hidden)

    output = F.log_softmax(self.out(output[0]), dim=1)
    return output, hidden, attn_weights

  def initHidden(self):
    return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## **Training Seq2Seq Model**

# %%
"""
"Teacher forcing" is the concept of using the real target outputs as
each next input, instead of using the decoder's guess as the next input.
Using teacher forcing causes it to converge faster but `when the trained
network is exploited, it may exhibit
instability <http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf>`__.

You can observe outputs of teacher-forced networks that read with
coherent grammar but wander far from the correct translation -
intuitively it has learned to represent the output grammar and can "pick
up" the meaning once the teacher tells it the first few words, but it
has not properly learned how to create the sentence from the translation
in the first place.

Because of the freedom PyTorch's autograd gives us, we can randomly
choose to use teacher forcing or not with a simple if statement. Turn
``teacher_forcing_ratio`` up to use more of it.
"""
teacher_forcing_ratio = 0.5

# %%
'''
To train we run the input sentence through the encoder, and keep track
of every output and the latest hidden state. Then the decoder is given
the ``<SOS>`` token as its first input, and the last hidden state of the
encoder as its first hidden state.
'''

def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
  encoder_hidden = encoder.initHidden()

  encoder_optimizer.zero_grad()
  decoder_optimizer.zero_grad()

  input_length = input_tensor.size(0)
  target_length = target_tensor.size(0)

  encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

  loss = 0

  for ei in range(input_length):
    encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
    encoder_outputs[ei] = encoder_output[0, 0]

  decoder_input = torch.tensor([[SOS_token]], device=device)

  decoder_hidden = encoder_hidden

  use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

  if use_teacher_forcing:
    # Teacher forcing: Feed the target as the next input
    for di in range(target_length):
      decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
      loss += criterion(decoder_output, target_tensor[di])
      decoder_input = target_tensor[di]  # Teacher forcing

  else:
    # Without teacher forcing: use its own predictions as the next input
    for di in range(target_length):
      decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
      topv, topi = decoder_output.topk(1)
      decoder_input = topi.squeeze().detach()  # detach from history as input

      loss += criterion(decoder_output, target_tensor[di])
      if decoder_input.item() == EOS_token:
        break

  loss.backward()

  encoder_optimizer.step()
  decoder_optimizer.step()

  return loss.item() / target_length

# %%
'''
Defining some helper functions to print time elapsed and estimate time remaining given the current time and progress %
'''

import time
import math

def asMinutes(s):
  m = math.floor(s / 60)
  s -= m * 60
  return '%dm %ds' % (m, s)


def timeSince(since, percent):
  now = time.time()
  s = now - since
  es = s / (percent)
  rs = es - s
  return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

'''
Plotting results using matplotlib
using the array of loss values``plot_losses`` saved while training.
'''
import matplotlib.pyplot as plt
# %matplotlib inline

plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
  plt.figure()
  fig, ax = plt.subplots()
  # this locator puts ticks at regular intervals
  loc = ticker.MultipleLocator(base=0.2)
  ax.yaxis.set_major_locator(loc)
  plt.plot(points)

# %%
'''
The whole training process looks like this:
-  Start a timer
-  Initialize optimizers and criterion
-  Create set of training pairs
-  Start empty losses array for plotting

Then we call ``train`` many times and occasionally print the progress (%
of examples, time so far, estimated time) and average loss.
'''

def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
      training_pair = training_pairs[iter - 1]
      input_tensor = training_pair[0]
      target_tensor = training_pair[1]

      loss = train(input_tensor, target_tensor, encoder,decoder, encoder_optimizer, decoder_optimizer, criterion)
      print_loss_total += loss
      plot_loss_total += loss

      if iter % print_every == 0:
        print_loss_avg = print_loss_total / print_every
        print_loss_total = 0
        print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),iter, iter / n_iters * 100, print_loss_avg))

      if iter % plot_every == 0:
        plot_loss_avg = plot_loss_total / plot_every
        plot_losses.append(plot_loss_avg)
        plot_loss_total = 0

    showPlot(plot_losses)

# %%
'''
With all these helper functions in place (it looks like extra work, but
it makes it easier to run multiple experiments) we can actually
initialize a network and start training.

Remember that the input sentences were heavily filtered. For this small
dataset we can use relatively small networks of 256 hidden nodes and a
single GRU layer. After about 40 minutes on a MacBook CPU we'll get some
reasonable results.

.. Note::
   If you run this notebook you can train, interrupt the kernel,
   evaluate, and continue training later. Comment out the lines where the
   encoder and decoder are initialized and run ``trainIters`` again.
'''

hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 75000, print_every=5000)

# %% [markdown]
# ## **Evaluation**

# %% [markdown]
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
'''
We can evaluate random sentences from the training set and print out the
input, target, and output to make some subjective quality judgements:
'''
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
evaluateRandomly(encoder1, attn_decoder1)

# %% [markdown]
# ## **Visualizing Attention**

# %% [markdown]
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run ``plt.matshow(attentions)`` to see attention output
# displayed as a matrix, with the columns being input steps and rows being
# output steps:

# %%
output_words, attentions = evaluate(encoder1, attn_decoder1, "je suis trop froid .")
plt.matshow(attentions.numpy())

# %% [markdown]
# For a better viewing experience we will do the extra work of adding axes
# and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
  # Set up figure with colorbar
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(attentions.numpy(), cmap='bone')
  fig.colorbar(cax)

  # Set up axes
  ax.set_xticklabels([''] + input_sentence.split(' ') +['<EOS>'], rotation=90)
  ax.set_yticklabels([''] + output_words)

  # Show label at every tick
  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
  plt.show()

# %%
def evaluateAndShowAttention(input_sentence):
  output_words, attentions = evaluate(encoder1, attn_decoder1, input_sentence)
  print('input =', input_sentence)
  print('output =', ' '.join(output_words))
  showAttention(input_sentence, output_words, attentions)

# %%
evaluateAndShowAttention("elle a cinq ans de moins que moi .")

# %%
evaluateAndShowAttention("elle est trop petit .")

# %%
evaluateAndShowAttention("je ne crains pas de mourir .")

# %%
evaluateAndShowAttention("c est un jeune directeur plein de talent .")
