# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/NLP/blob/main/Preprocessing/Word-Tokenization.ipynb)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Word Tokenization Using NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize
# for word tokenization you need the 'punkt' package from NLTK data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = "The quick brown fox, and an Oxford comma"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', ',', 'and', 'an', 'Oxford', 'comma']

# %%
from nltk.tokenize import word_tokenize
text = "How about currencies (like £100,000.00) and dates (like 19th September)"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['How', 'about', 'currencies', '(', 'like', '£100,000.00', ')', 'and', 'dates', '(', 'like', '19th', 'September', ')']

# %%
path = "/content/drive/MyDrive/001 My Skills/002 CS Engineering   Automated Math (BPHC)/004 Data Science (DS)   Artificial Intelligence (AI)/005 Textual Data (Unstructured Data) (Sequential Data)/001 Mono Lingual Language /001 English/000 Text Preprocessing/000.1 Tokenization/002 Word Tokenization   Word Segmentation/98-0.txt"
with open(path,'r') as f:
  lines = f.read()

lines = lines[2728:] #filtering out ToC etc

# %%
tokens = word_tokenize(lines)
tokens
# Out:
# ['CHAPTER',
#  'I',
#  '.',
#  'The',
#  'Period',
#  'It',
#  'was',
#  'the',
#  'best',
#  'of',
#  'times',
#  ',',
#  'it',
#  'was',
#  'the',
#  'worst',
#  'of',
#  'times',
#  ',',
#  'it',
#  'was',
#  'the',
#  'age',
#  'of',
#  'wisdom',
#  ',',
#  'it',
#  'was',
#  'the',
#  'age',
#  'of',
#  'foolishness',
#  ',',
#  'it',
#  'was',
#  'the',
#  'epoch',
#  'of',
#  'belief',
#  ',',
#  'it',
#  'was',
#  'the',
#  'epoch',
#  'of',
#  'incredulity',
#  ',',
#  'it',
#  'was',
#  'the',
#  'season',
#  'of',
#  'Light',
#  ',',
#  'it',
#  'was',
#  'the',
#  'season',
#  'of',
#  'Darkness',
#  ',',
#  'it',
#  'was',
#  'the',
#  'spring',
#  'of',
#  'hope',
#  ',',
#  'it',
#  'was',
#  'the',
#  'winter',
#  'of',
#  'despair',
#  ',',
#  'we',
#  'had',
#  'everything',
#  'before',
#  'us',
#  ',',
#  'we',
#  'had',
#  'nothing',
#  'before',
#  'us',
#  ',',
#  'we',
#  'were',
#  'all',
#  'going',
#  'direct',
#  'to',
#  'Heaven',
#  ',',
#  'we',
# ...

# %%
fdist1 = nltk.FreqDist(tokens)
type(fdist1)
# Out:
# nltk.probability.FreqDist

# %%
## Creating FreqDist for whole BoW, keeping the 20 most common tokens
all_fdist = fdist1.most_common(200)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)
plt.xticks(rotation=30);

# %%
fdist1, type(fdist1)
# Out:
# (FreqDist({'CHAPTER': 45,
#            'I': 1961,
#            '.': 5066,
#            'The': 628,
#            'Period': 1,
#            'It': 333,
#            'was': 1762,
#            'the': 7567,
#            'best': 40,
#            'of': 4091,
#            'times': 50,
#            ',': 13271,
#            'it': 1705,
#            'worst': 17,
#            'age': 18,
#            'wisdom': 2,
#            'foolishness': 1,
#            'epoch': 2,
#            'belief': 6,
#            'incredulity': 1,
#            'season': 7,
#            'Light': 3,
#            'Darkness': 5,
#            'spring': 5,
#            'hope': 81,
#            'winter': 11,
#            'despair': 5,
#            'we': 126,
#            'had': 1296,
#            'everything': 23,
#            'before': 223,
#            'us': 108,
#            'nothing': 129,
#            'were': 657,
#            'all': 524,
#            'going': 86,
#            'direct': 6,
#            'to': 3507,
# ...

# %%
fdist1.most_common(50)
# Out:
# [(',', 13271),
#  ('the', 7567),
#  ('.', 5066),
#  ('and', 4903),
#  ('of', 4091),
#  ('to', 3507),
#  ('“', 2892),
#  ('a', 2858),
#  ('”', 2767),
#  ('in', 2529),
#  ('I', 1961),
#  ('his', 1938),
#  ('that', 1830),
#  ('was', 1762),
#  ('it', 1705),
#  ('he', 1457),
#  ('with', 1316),
#  ('had', 1296),
#  ('you', 1202),
#  ('’', 1162),
#  (';', 1108),
#  ('as', 1058),
#  ('her', 998),
#  ('at', 992),
#  ('him', 959),
#  ('!', 955),
#  ('for', 919),
#  ('?', 913),
#  ('on', 888),
#  ('not', 870),
#  ('is', 777),
#  ('be', 764),
#  ('have', 728),
#  ('--', 722),
#  ('said', 660),
#  ('s', 658),
#  ('were', 657),
#  ('The', 628),
#  ('Mr.', 606),
#  ('my', 577),
#  ('by', 575),
#  ('this', 533),
#  ('all', 524),
#  ('so', 523),
#  ('from', 510),
#  ('me', 501),
#  ('but', 485),
#  ('they', 459),
#  ('no', 446),
#  ('there', 439)]

# %% [markdown]
# ## Tokenizing Tweet Data Using NLTK

# %%
text = "Tweet about #NLProc @ABCD :)"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Tweet', 'about', '#', 'NLProc', '@', 'ABCD', ':', ')']

# %%
text = "Tweet about #NLProc @ABCD :)"
tokenizer = TweetTokenizer()
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9b76b0175cf7> in <module>()
#       1 text = "Tweet about #NLProc @ABCD :)"
# ----> 2 tokenizer = TweetTokenizer()
#       3 tokens = tokenizer.tokenize(text)
#       4 print(tokens)
#
# NameError: name 'TweetTokenizer' is not defined

# %%
# !pip install tweet-preprocessor
#https://github.com/s/preprocessor

# %%
import preprocessor as p
tweet = "@tedcruz And, #HandOverTheServer she wiped clean + 30k deleted emails, explains dereliction of duty/lies re #Benghazi,etc #tcot"
tokens = p.tokenize(tweet)
print(tokens)
# Out:
# $MENTION$ And, $HASHTAG$ she wiped clean + $NUMBER$k deleted emails, explains dereliction of duty/lies re $HASHTAG$,etc $HASHTAG$

# %% [markdown]
# # Word Tokenization Using Regex

# %%
text = 'That U.S.A. poster-print costs $12.40...'
pattern = r'''(?x)     # set flag to allow verbose regexps
                (?:[A-Z]\.)+       # abbreviations, e.g. U.S.A.
                | \w+(?:-\w+)*       # words with optional internal hyphens
                | \$?\d+(?:\.\d+)?%? # currency and percentages, e.g. $12.40, 82%
                | \.\.\.             # ellipsis
                | [][.,;"'?():-_`]   # these are separate tokens; includes ], [
                '''

print("regex tokenizer output: ", nltk.regexp_tokenize(text, pattern))

print("nltk word_tokenize output: ",nltk.word_tokenize(text))
# Out:
# regex tokenizer output:  ['That', 'U.S.A.', 'poster-print', 'costs', '$12.40', '...']
# nltk word_tokenize output:  ['That', 'U.S.A.', 'poster-print', 'costs', '$', '12.40', '...']

# %% [markdown]
# # Word Tokenization Using String Manipulation

# %%
text = "The quick brown fox jumped over the lazy dog"
tokens = text.split()
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog']
