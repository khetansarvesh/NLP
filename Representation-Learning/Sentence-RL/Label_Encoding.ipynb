# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/NLP/blob/main/Representation-Learning/Sentence-RL/Label_Encoding.ipynb)

# %% [markdown]
# ## Label Encoding using scikit -learn Library

# %%
p = 'dog bites man.man bites dog.dog eats meat.man eats food'
sentences = p.split('.')
sentences
# Out:
# ['dog bites man', 'man bites dog', 'dog eats meat', 'man eats food']

# %%
tokens = list()
for sent in sentences:
  tokens.append(sent.split())
tokens
# Out:
# [['dog', 'bites', 'man'],
#  ['man', 'bites', 'dog'],
#  ['dog', 'eats', 'meat'],
#  ['man', 'eats', 'food']]

# %%
values = tokens[0]+tokens[1]+tokens[2]+tokens[3]
print("The data: ",values)
# Out:
# The data:  ['dog', 'bites', 'man', 'man', 'bites', 'dog', 'dog', 'eats', 'meat', 'man', 'eats', 'food']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
integer_encoded = label_encoder.fit_transform(values)

# %%
print("Label Encoded:",integer_encoded)
# Out:
# Label Encoded: [1 0 4 4 0 1 1 2 5 4 2 3]
