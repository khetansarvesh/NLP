# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/NLP/blob/main/Representation-Learning/SubWord-RL/FastText.ipynb)

# %% [markdown]
# # **Domain Specific Pretrained FastText Using Gensim Library**

# %%
# genism also exposes fastText which has been trained on some data already for us, you can use this directly if the data which it has been trained on is same as the data you are working with

# Trained on wikipedia data --->
import gensim.downloader as api
model = api.load('fasttext-wiki-news-subwords-300')

# %%
# say you want to use the above already trained models but also train on the data you are working with, so is that possible??? YES
